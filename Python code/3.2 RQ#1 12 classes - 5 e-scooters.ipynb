# %% [markdown]
# # Preliminary operations

# %% [markdown]
# We import the libraries and the drive environment.

# %%
# !pip install folium
# !pip install geopandas
# !pip install keras-tuner --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.8 MB/s eta 0:00:00
# Collecting fiona>=1.8.19 (from geopandas)
#   Downloading Fiona-1.9.4.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 43.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Collecting pyproj>=3.0.1 (from geopandas)
#   Downloading pyproj-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 58.9 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Collecting click-plugins>=1.0 (from fiona>=1.8.19->geopandas)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.19->geopandas)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.22.4)
# Installing collected packages: pyproj, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 geopandas-0.13.2 pyproj-3.5.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.27.1)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %%
# Utility
from google.colab import drive
import pandas as pd
import numpy as np
from shutil import copyfile, copy
import datetime
import urllib.request
import os
import json
import matplotlib.pyplot as plt

# Geo
import folium
import geopandas as gpd

# Scikit-learn
from sklearn.metrics import classification_report, confusion_matrix, top_k_accuracy_score
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# Keras
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Input, Dropout
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import regularizers
import keras_tuner
from kerastuner.tuners import RandomSearch, GridSearch

seq_len = 5
n_feats = 5
# Out:
# <ipython-input-2-b3ec6d248bb3>:29: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch, GridSearch

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Loading data

# %%
df = pd.read_csv('/content/gdrive/MyDrive/DSLSC/motoscooter_movimento_new.csv')

# %%
df.columns
# Out:
# Index(['provider_id', 'lat', 'lng', 'created_at', 'distance', 'placename',
#        'placelat', 'placelon', 'lat&lng', 'prevObservation', 'nextObservation',
#        'nextCreated_at', 'nextDistance', 'nextTimeDiff', 'prevCreated_at',
#        'prevDistance', 'prevTimeDiff', 'samePlace', 'type'],
#       dtype='object')

# %%
df['created_at'] =  pd.to_datetime(df['created_at'], format = '%Y%m%d %H:%M:%S')
df['nextCreated_at'] =  pd.to_datetime(df['nextCreated_at'], format = '%Y%m%d %H:%M:%S')
df['prevCreated_at'] =  pd.to_datetime(df['prevCreated_at'], format = '%Y%m%d %H:%M:%S')
# Remove waiting long e-scooters
df = df[df['type'] != 'waiting long']

# %% [markdown]
# Now we order the dataframe by provider and we order each provider by time. This way, we will have sequences of consecutive pick-up/drop-off synchronized for each provider_id.

# %%
groups = df.groupby('provider_id')
ordered_df = []
for name, group in groups:
  ordered_df.append((pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True))

# %%
combined_df = pd.concat(ordered_df)

# %%
combined_df
# Out:
#     provider_id      lat      lng          created_at    distance  placename  \
# 0           2.0  45.4599  9.20633 2019-12-06 01:25:20  143.437209      356.0
# 1           2.0  45.4622  9.19374 2019-12-06 01:40:22  214.500848      354.0
# 2           2.0  45.4621  9.19375 2019-12-06 18:40:20  205.745441      354.0
# 3           2.0  45.4411  9.18597 2019-12-06 19:40:24   95.513288      204.0
# 4           2.0  45.4411  9.18597 2019-12-06 20:10:24   95.513288      204.0
# ..          ...      ...      ...                 ...         ...        ...
# 41       1754.0  45.4567  9.14835 2019-12-07 06:55:08   73.915845      307.0
# 42       1754.0  45.4567  9.14835 2019-12-07 18:55:14   73.915845      307.0
# 43       1754.0  45.4565  9.14819 2019-12-07 19:10:08   57.395490      307.0
# 44       1754.0  45.4565  9.14819 2019-12-08 14:25:08   57.395490      307.0
# 45       1754.0  45.4567  9.14828 2019-12-08 14:40:08   75.265120      307.0
#
#     placelat  placelon             lat&lng     prevObservation  \
# 0   45.46075   9.20495  (45.4599, 9.20633)                 NaN
# 1   45.46075   9.19555  (45.4622, 9.19374)  (45.4599, 9.20633)
# 2   45.46075   9.19555  (45.4621, 9.19375)  (45.4621, 9.19375)
# 3   45.44195   9.18615  (45.4411, 9.18597)  (45.4621, 9.19375)
# 4   45.44195   9.18615  (45.4411, 9.18597)  (45.4411, 9.18597)
# ..       ...       ...                 ...                 ...
# 41  45.45605   9.14855  (45.4567, 9.14835)  (45.4566, 9.14827)
# 42  45.45605   9.14855  (45.4567, 9.14835)  (45.4567, 9.14835)
# 43  45.45605   9.14855  (45.4565, 9.14819)  (45.4567, 9.14835)
# 44  45.45605   9.14855  (45.4565, 9.14819)  (45.4565, 9.14819)
# 45  45.45605   9.14855  (45.4567, 9.14828)  (45.4565, 9.14819)
#
#        nextObservation      nextCreated_at  nextDistance  nextTimeDiff  \
# 0   (45.4622, 9.19374) 2019-12-06 01:40:22   1017.327131     15.033333
# 1   (45.4621, 9.19375) 2019-12-06 01:55:23     11.141565     15.016667
# 2   (45.4411, 9.18597) 2019-12-06 19:40:24   2411.994485     60.066667
# 3   (45.4411, 9.18597) 2019-12-06 19:55:25      0.000000     15.016667
# 4   (45.4721, 9.18426) 2019-12-06 20:55:22   3447.956963     44.966667
# ..                 ...                 ...           ...           ...
# 41  (45.4567, 9.14835) 2019-12-07 07:10:09      0.000000     15.016667
# 42  (45.4565, 9.14819) 2019-12-07 19:10:08     25.509056     14.900000
# 43  (45.4565, 9.14819) 2019-12-07 19:25:09      0.000000     15.016667
# 44  (45.4567, 9.14828) 2019-12-08 14:40:08     23.316224     15.000000
# 45  (45.4567, 9.14832) 2019-12-08 14:55:10      3.128709     15.033333
#
#         prevCreated_at  prevDistance  prevTimeDiff  samePlace  \
# 0                  NaT      0.000000      0.000000        0.0
# 1  2019-12-06 01:25:20   1017.327131     15.033333        0.0
# 2  2019-12-06 18:25:21      0.000000     14.983333        0.0
# 3  2019-12-06 18:40:20   2411.994485     60.066667        0.0
# 4  2019-12-06 19:55:25      0.000000     14.983333        0.0
# ..                 ...           ...           ...        ...
# 41 2019-12-07 06:25:08     12.754525     30.000000        0.0
# 42 2019-12-07 18:40:08      0.000000     15.100000        0.0
# 43 2019-12-07 18:55:14     25.509056     14.900000        0.0
# 44 2019-12-08 14:10:10      0.000000     14.966667        0.0
# 45 2019-12-08 14:25:08     23.316224     15.000000        0.0
#
#                     type
# 0   first seen / pick-up
# 1               drop-off
# 2        pick-up outlier
# 3       drop-off outlier
# 4                pick-up
# ..                   ...
# 41              drop-off
# 42               pick-up
# 43              drop-off
# 44               pick-up
# 45              drop-off
#
# [81568 rows x 19 columns]

# %% [markdown]
# The sorting done above allows us to correctly associate, for each sample, the pick-up points with the drop-off points.

# %%
pickup = ['first seen / pick-up', 'pick-up', 'pick-up outlier']
dropoff = ['last seen / drop-off', 'drop-off', 'drop-off outlier']
# Create 2 different dataframes: one for pick-up and one for drop-off
df_p = combined_df[combined_df['type'].isin(pickup)]
df_d = combined_df[combined_df['type'].isin(dropoff)]

# %% [markdown]
# The 2 dataframes are ordered by provider_id and each provider_id is ordered by time. They are syncrhonized, so that for example the first row is both the pick-up point and the drop-off point of the same scooter, in respectively df_p and df_d.

# %%
df_p = df_p[['provider_id', 'created_at', 'placename', 'placelon', 'placelat']].reset_index(drop = True)
df_d = df_d[['created_at', 'placename', 'placelon', 'placelat']].reset_index(drop = True)
# The placename and the coordinates of the drop-off observation are our target
df_p['target'] = df_d['placename']
df_p['target_lon'] = df_d['placelon']
df_p['target_lat'] = df_d['placelat']
df = df_p.copy()

# %% [markdown]
# We also may create a variable indicating if it's saturday or sunday.

# %%
df['is_weekend'] = df['created_at'].apply(lambda x: 1 if x.weekday() >= 5 else 0)

# %%
df
# Out:
#        provider_id          created_at  placename  placelon  placelat  target  \
# 0              2.0 2019-12-06 01:25:20      356.0   9.20495  45.46075   354.0
# 1              2.0 2019-12-06 18:40:20      354.0   9.19555  45.46075   204.0
# 2              2.0 2019-12-06 20:10:24      204.0   9.18615  45.44195   426.0
# 3              2.0 2019-12-07 00:25:20      426.0   9.18615  45.47015   503.0
# 4              2.0 2019-12-07 08:40:16      503.0   9.20025  45.47955   503.0
# ...            ...                 ...        ...       ...       ...     ...
# 40779       1754.0 2019-12-07 01:55:08      307.0   9.14855  45.45605   307.0
# 40780       1754.0 2019-12-07 02:40:09      307.0   9.14855  45.45605   307.0
# 40781       1754.0 2019-12-07 06:25:08      307.0   9.14855  45.45605   307.0
# 40782       1754.0 2019-12-07 18:55:14      307.0   9.14855  45.45605   307.0
# 40783       1754.0 2019-12-08 14:25:08      307.0   9.14855  45.45605   307.0
#
#        target_lon  target_lat  is_weekend
# 0         9.19555    45.46075           0
# 1         9.18615    45.44195           0
# 2         9.18615    45.47015           0
# 3         9.20025    45.47955           1
# 4         9.20025    45.47955           1
# ...           ...         ...         ...
# 40779     9.14855    45.45605           1
# 40780     9.14855    45.45605           1
# 40781     9.14855    45.45605           1
# 40782     9.14855    45.45605           1
# 40783     9.14855    45.45605           1
#
# [40784 rows x 9 columns]

# %% [markdown]
# # Zone prediction \#1 (5 e-scooters)

# %% [markdown]
# The goal of this task is to build a prediction model in order to know in advance the drop-off zone of a sequence of scooters (with probability attached). Here we perform a classification task on 12 rectangular zones of Milan, i.e. with a medium level of granularity.

# %% [markdown]
# ## Pre-processing

# %%
gdf = gpd.GeoDataFrame(df, crs = 'EPSG:4326', geometry = gpd.points_from_xy(df.placelon, df.placelat))

# %%
milan_nil = gpd.read_file("/content/gdrive/MyDrive/DSLSC/NIL_E0.zip")

# %%
# Ensuring the crs is the same
if gdf.crs != milan_nil.crs:
  milan_nil = milan_nil.to_crs(gdf.crs)

# %%
# Spatial join between the zones and scooters GeoDataFrames
zones_with_scooters_gdf = gpd.sjoin(milan_nil, gdf, predicate = 'contains')
# Group the GeoDataFrame by zone ID and count the number of scooters in each zone
scooter_counts_by_zone = zones_with_scooters_gdf.groupby('NIL').size()
# Get the IDs of the zones with scooters
zones_with_scooters_ids = scooter_counts_by_zone.index
# Filter the zones GeoDataFrame in order to remove the zones without scooters
zones_gdf = milan_nil[milan_nil['NIL'].isin(zones_with_scooters_ids)]
zones_gdf = zones_gdf.reset_index(drop = True)

# %%
zones_gdf['City'] = 'Milan'
city = zones_gdf.to_crs(epsg = 4326).dissolve(by = 'City')

# %%
# Plot the quarters polygons
ax = city.plot(edgecolor = 'k', facecolor = 'none', figsize = (15, 10))
gdf.plot(ax = ax, color = "blue")
ax.set_title('E-scooter positions within Milan\n')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

ax.annotate('0', (9.1498, 45.495), color = 'red', fontsize = 16, weight = 'bold')
ax.annotate('1', (9.1683, 45.495), color = 'red', fontsize = 16, weight = 'bold')
ax.annotate('2', (9.1874, 45.495), color = 'red', fontsize = 16, weight = 'bold')
ax.annotate('3', (9.211, 45.495), color = 'red', fontsize = 16, weight = 'bold')
ax.annotate('4', (9.1498, 45.4715), color = 'red', fontsize = 16, weight = 'bold')
ax.annotate('5', (9.1683, 45.4715), color = 'red', fontsize = 16, weight = 'bold')
ax.annotate('6', (9.1874, 45.4715), color = 'red', fontsize = 16, weight = 'bold')
ax.annotate('7', (9.211, 45.4715), color = 'red', fontsize = 16, weight = 'bold')
ax.annotate('8', (9.1498, 45.4482), color = 'red', fontsize = 16, weight = 'bold')
ax.annotate('9', (9.1683, 45.4482), color = 'red', fontsize = 16, weight = 'bold')
ax.annotate('10', (9.1863, 45.4482), color = 'red', fontsize = 16, weight = 'bold')
ax.annotate('11', (9.21, 45.4482), color = 'red', fontsize = 16, weight = 'bold')

ax.axhline(y = 45.505, color = 'red', linewidth = 2)
ax.axhline(y = 45.44, color = 'red', linewidth = 2)
ax.axvline(x = 9.135, color = 'red', linewidth = 2)
ax.axvline(x = 9.225, color = 'red', linewidth = 2)

ax.axhline(y = 45.482, color = 'red', linestyle = '--', linewidth = 0.8)
ax.axhline(y = 45.463, color = 'red', linestyle = '--', linewidth = 0.8)
ax.axvline(x = 9.160, color = 'red', linestyle = '--', linewidth = 0.8)
ax.axvline(x = 9.179, color = 'red', linestyle = '--', linewidth = 0.8)
ax.axvline(x = 9.198, color = 'red', linestyle = '--', linewidth = 0.8)

# Set the axis limits
ax.set_xlim(9.105, 9.24)
ax.set_ylim(45.425, 45.515)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()

plt.savefig('Milan zones.png', bbox_inches = 'tight', dpi = 300)

# %%
for i in range(0, len(gdf)):
  if(9.13 <= gdf['target_lon'][i] <= 9.16):
    # Zone 0
    if(45.482 <= gdf['target_lat'][i] <= 45.505):
      gdf['target'][i] = 0
    # Zone 1
    if(45.463 <= gdf['target_lat'][i] < 45.482):
      gdf['target'][i] = 1
    # Zone 2
    if(45.44 <= gdf['target_lat'][i] < 45.463):
      gdf['target'][i] = 2
  if(9.16 < gdf['target_lon'][i] <= 9.179):
    # Zone 3
    if(45.482 <= gdf['target_lat'][i] <= 45.505):
      gdf['target'][i] = 3
    # Zone 4
    if(45.463 <= gdf['target_lat'][i] < 45.482):
      gdf['target'][i] = 4
    # Zone 5
    if(45.44 <= gdf['target_lat'][i] < 45.463):
      gdf['target'][i] = 5
  if(9.179 < gdf['target_lon'][i] <= 9.198):
    # Zone 6
    if(45.482 <= gdf['target_lat'][i] <= 45.505):
      gdf['target'][i] = 6
    # Zone 7
    if(45.463 <= gdf['target_lat'][i] < 45.482):
      gdf['target'][i] = 7
    # Zone 8
    if(45.44 <= gdf['target_lat'][i] < 45.463):
      gdf['target'][i] = 8
  if(9.198 < gdf['target_lon'][i] <= 9.24):
    # Zone 9
    if(45.482 <= gdf['target_lat'][i] <= 45.505):
      gdf['target'][i] = 9
    # Zone 10
    if(45.463 <= gdf['target_lat'][i] < 45.482):
      gdf['target'][i] = 10
    # Zone 11
    if(45.44 <= gdf['target_lat'][i] < 45.463):
      gdf['target'][i] = 11
# Out:
# <ipython-input-21-23a51bf74846>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 8
# <ipython-input-21-23a51bf74846>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 7
# <ipython-input-21-23a51bf74846>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 10
# <ipython-input-21-23a51bf74846>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 9
# <ipython-input-21-23a51bf74846>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 3
# <ipython-input-21-23a51bf74846>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 2
# <ipython-input-21-23a51bf74846>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 1
# <ipython-input-21-23a51bf74846>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 0
# <ipython-input-21-23a51bf74846>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 5
# <ipython-input-21-23a51bf74846>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 6
# <ipython-input-21-23a51bf74846>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 4
# <ipython-input-21-23a51bf74846>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf['target'][i] = 11

# %%
df = gdf[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend', 'target']]

# %%
df
# Out:
#        provider_id          created_at  placelon  placelat  is_weekend  target
# 0              2.0 2019-12-06 01:25:20   9.20495  45.46075           0     8.0
# 1              2.0 2019-12-06 18:40:20   9.19555  45.46075           0     8.0
# 2              2.0 2019-12-06 20:10:24   9.18615  45.44195           0     7.0
# 3              2.0 2019-12-07 00:25:20   9.18615  45.47015           1    10.0
# 4              2.0 2019-12-07 08:40:16   9.20025  45.47955           1    10.0
# ...            ...                 ...       ...       ...         ...     ...
# 40779       1754.0 2019-12-07 01:55:08   9.14855  45.45605           1     2.0
# 40780       1754.0 2019-12-07 02:40:09   9.14855  45.45605           1     2.0
# 40781       1754.0 2019-12-07 06:25:08   9.14855  45.45605           1     2.0
# 40782       1754.0 2019-12-07 18:55:14   9.14855  45.45605           1     2.0
# 40783       1754.0 2019-12-08 14:25:08   9.14855  45.45605           1     2.0
#
# [40784 rows x 6 columns]

# %% [markdown]
# Now we group the dataset by target and then we order each target sequence by time.

# %%
# We group the dataframe by target and discard samples in a way that there are only multiple of seq_len
groups = df.groupby('target')
ordered_df = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len == 0):
    ordered_df.append(df_)
  else:
    df_ = df_[:-((len(df_))%seq_len)]
    ordered_df.append(df_)

# %%
combined_df = pd.concat(ordered_df)

# %%
combined_df
# Out:
#       provider_id          created_at  placelon  placelat  is_weekend  target
# 0          1024.0 2019-12-02 00:10:29   9.15795  45.48895           0     0.0
# 1          1243.0 2019-12-02 00:10:29   9.15795  45.49365           0     0.0
# 2           982.0 2019-12-02 00:10:29   9.15795  45.48425           0     0.0
# 3          1010.0 2019-12-02 00:25:29   9.15325  45.49365           0     0.0
# 4           957.0 2019-12-02 00:25:29   9.15795  45.48895           0     0.0
# ...           ...                 ...       ...       ...         ...     ...
# 4650       1024.0 2019-12-08 23:40:13   9.21435  45.45135           1    11.0
# 4651       1128.0 2019-12-08 23:40:13   9.21435  45.45135           1    11.0
# 4652        917.0 2019-12-08 23:40:16   9.20025  45.45605           1    11.0
# 4653       1384.0 2019-12-08 23:40:16   9.20495  45.45605           1    11.0
# 4654       1142.0 2019-12-08 23:40:16   9.20025  45.45605           1    11.0
#
# [40760 rows x 6 columns]

# %%
df = combined_df.reset_index(drop = True)

# %% [markdown]
# ## Preparation

# %%
encoder_id = LabelEncoder()
df['provider_id'] = encoder_id.fit_transform(df['provider_id'])

# %%
# Converting datetime in unixtime (int)
dates = pd.to_datetime(df['created_at'])
df['created_at'] = dates.astype(int) // 10**9
min_time = min(df['created_at'])
df['created_at'] = df['created_at'] - min_time
#df['created_at'] = df['created_at'] % 86400

# %%
# Test-set = monday
test = df[df['created_at'] < 1575331200 - min_time]
train = df.drop(test.index)
test.reset_index(drop = True, inplace = True)
train.reset_index(drop = True, inplace = True)

# %%
max_test = max(test['created_at'])
train['created_at'] = train['created_at'] - max_test
max_train = max(train['created_at'])
test['created_at'] = test['created_at'] + max_train
# Out:
# <ipython-input-31-1feb4cdfc222>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['created_at'] = test['created_at'] + max_train

# %%
train_test_ordered = pd.concat([train, test], ignore_index = True)

# %%
scaler_0 = MinMaxScaler()
scaler_1 = MinMaxScaler()
scaler_2 = MinMaxScaler()
scaler_3 = MinMaxScaler()

df['provider_id'] = scaler_0.fit_transform(np.array(df['provider_id']).reshape(-1, 1))
train_test_ordered['created_at'] = scaler_1.fit_transform(np.array(train_test_ordered['created_at']).reshape(-1, 1))

train['provider_id'] = scaler_0.transform(np.array(train['provider_id']).reshape(-1, 1))
train['created_at'] = scaler_1.transform(np.array(train['created_at']).reshape(-1, 1))
train['placelon'] = scaler_2.fit_transform(np.array(train['placelon']).reshape(-1, 1))
train['placelat'] = scaler_3.fit_transform(np.array(train['placelat']).reshape(-1, 1))

test['provider_id'] = scaler_0.transform(np.array(test['provider_id']).reshape(-1, 1))
test['created_at'] = scaler_1.transform(np.array(test['created_at']).reshape(-1, 1))
test['placelon'] = scaler_2.transform(np.array(test['placelon']).reshape(-1, 1))
test['placelat'] = scaler_3.transform(np.array(test['placelat']).reshape(-1, 1))
# Out:
# <ipython-input-33-c99ba37fc144>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['provider_id'] = scaler_0.transform(np.array(test['provider_id']).reshape(-1, 1))
# <ipython-input-33-c99ba37fc144>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['created_at'] = scaler_1.transform(np.array(test['created_at']).reshape(-1, 1))
# <ipython-input-33-c99ba37fc144>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['placelon'] = scaler_2.transform(np.array(test['placelon']).reshape(-1, 1))
# <ipython-input-33-c99ba37fc144>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['placelat'] = scaler_3.transform(np.array(test['placelat']).reshape(-1, 1))

# %% [markdown]
# Now we create the validation set, selecting the last 10% of each target. Moreover, we save the array with training + validation for further retraining.

# %%
X = train.copy(deep = True)

# %%
val = pd.DataFrame(columns = train.columns)

for i in range(0, 12):
  to_pick = int((len(train[train['target'] == i]))*0.1)
  rows = train[train['target'] == i].tail(to_pick)
  train = train.drop(rows.index)
  val = pd.concat([val, rows], ignore_index = True)

train.reset_index(drop = True, inplace = True)

# %%
# Now we have to fix the lengths of train, val and test, in the same way as before
groups = train.groupby('target')
ordered_df_train = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_train.append(df_)

groups = val.groupby('target')
ordered_df_val = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_val.append(df_)
    
groups = test.groupby('target')
ordered_df_test = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_test.append(df_)

# Training + validation
groups = X.groupby('target')
ordered_df_X = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_X.append(df_)

# %%
train = pd.concat(ordered_df_train).reset_index(drop = True)
val = pd.concat(ordered_df_val).reset_index(drop = True)
test = pd.concat(ordered_df_test).reset_index(drop = True)
X = pd.concat(ordered_df_X).reset_index(drop = True)

# %%
train
# Out:
#        provider_id  created_at  placelon  placelat  is_weekend  target
# 0         0.710681    0.000000  0.055556  0.692308           0     0.0
# 1         0.726661    0.000033  0.166667  0.846154           0     0.0
# 2         0.658537    0.000035  0.222222  0.692308           0     0.0
# 3         0.105971    0.000037  0.111111  0.769231           0     0.0
# 4         0.729184    0.000037  0.111111  0.769231           0     0.0
# ...            ...         ...       ...       ...         ...     ...
# 31560     0.691337    0.793680  0.722222  0.307692           1    11.0
# 31561     0.881413    0.795161  0.888889  0.846154           1    11.0
# 31562     0.585366    0.795163  0.888889  0.230769           1    11.0
# 31563     0.618167    0.795165  0.833333  0.000000           1    11.0
# 31564     0.515559    0.795165  0.833333  0.000000           1    11.0
#
# [31565 rows x 6 columns]

# %%
val
# Out:
#       provider_id  created_at  placelon  placelat is_weekend  target
# 0        0.830950    0.681603  0.111111  0.692308          1     0.0
# 1        0.550042    0.683103  0.055556  0.692308          1     0.0
# 2        0.506308    0.684576  0.500000  0.230769          1     0.0
# 3        0.518923    0.684579  0.444444  0.615385          1     0.0
# 4        0.765349    0.684584  0.222222  0.692308          1     0.0
# ...           ...         ...       ...       ...        ...     ...
# 3470     0.766190    0.857942  0.944444  0.153846          1    11.0
# 3471     0.638352    0.857942  0.888889  0.153846          1    11.0
# 3472     0.792262    0.857947  0.777778  0.230769          1    11.0
# 3473     0.502103    0.857947  0.722222  0.230769          1    11.0
# 3474     0.648444    0.857947  0.722222  0.230769          1    11.0
#
# [3475 rows x 6 columns]

# %%
test
# Out:
#       provider_id  created_at  placelon  placelat  is_weekend  target
# 0        0.571068    0.857994  0.222222  0.769231           0     0.0
# 1        0.703953    0.857994  0.222222  0.846154           0     0.0
# 2        0.543314    0.857994  0.222222  0.692308           0     0.0
# 3        0.562658    0.859488  0.166667  0.846154           0     0.0
# 4        0.529857    0.859488  0.222222  0.769231           0     0.0
# ...           ...         ...       ...       ...         ...     ...
# 5630     0.719092    0.998469  0.833333  0.153846           0    11.0
# 5631     0.608915    0.999960  0.888889  0.076923           0    11.0
# 5632     0.682086    0.999962  0.944444  0.153846           0    11.0
# 5633     0.657696    0.999962  0.888889  0.153846           0    11.0
# 5634     0.687132    0.999962  0.888889  0.153846           0    11.0
#
# [5635 rows x 6 columns]

# %%
X
# Out:
#        provider_id  created_at  placelon  placelat  is_weekend  target
# 0         0.710681    0.000000  0.055556  0.692308           0     0.0
# 1         0.726661    0.000033  0.166667  0.846154           0     0.0
# 2         0.658537    0.000035  0.222222  0.692308           0     0.0
# 3         0.105971    0.000037  0.111111  0.769231           0     0.0
# 4         0.729184    0.000037  0.111111  0.769231           0     0.0
# ...            ...         ...       ...       ...         ...     ...
# 35065     0.536585    0.857939  0.888889  0.307692           1    11.0
# 35066     0.684609    0.857940  0.833333  0.000000           1    11.0
# 35067     0.731707    0.857940  0.888889  0.076923           1    11.0
# 35068     0.766190    0.857942  0.944444  0.153846           1    11.0
# 35069     0.571068    0.857942  0.888889  0.153846           1    11.0
#
# [35070 rows x 6 columns]

# %%
X_train = np.array((train[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)
y_train = np.array((train['target'])).reshape(-1, seq_len)

X_val = np.array((val[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)
y_val = np.array((val['target'])).reshape(-1, seq_len)

X_test = np.array((test[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)
y_test = np.array((test['target'])).reshape(-1, seq_len)

y = np.array((X['target'])).reshape(-1, seq_len)
X = np.array((X[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)

# %%
y_train = to_categorical(y_train)[:, 0, :]
y_val = to_categorical(y_val)[:, 0, :]
y_test = to_categorical(y_test)[:, 0, :]
y = to_categorical(y)[:, 0, :]

# %%
X_val = np.asarray(X_val).astype('float32')
y_val = np.asarray(y_val).astype('float32')

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
print(X.shape)
print(y.shape)
# Out:
# (6313, 5, 5)
# (6313, 12)
# (695, 5, 5)
# (695, 12)
# (1127, 5, 5)
# (1127, 12)
# (7014, 5, 5)
# (7014, 12)

# %% [markdown]
# ## Model selection

# %% [markdown]
# We use a RNN LSTM for this task. In this section we start from a basic network and select the best model iteratively.

# %% [markdown]
# ### Model 0

# %%
model0 = Sequential()
model0.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True))
model0.add(LSTM(32, return_sequences = False))
model0.add(Dense(32))
model0.add(Dense(12, activation = 'softmax'))
model0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 16)             1408
#
#  lstm_1 (LSTM)               (None, 32)                6272
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 9,132
# Trainable params: 9,132
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = Adam(learning_rate = 0.0001)
model0.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history0 = model0.fit(X_train, y_train, epochs = 100, batch_size = 16, validation_data = (X_val, y_val))

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history0.history['loss'])
plt.plot(history0.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history0.history['accuracy'])
plt.plot(history0.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model0 = Sequential()
model0.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True))
model0.add(LSTM(32, return_sequences = False))
model0.add(Dense(32))
model0.add(Dense(12, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.0001)
model0.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history0 = model0.fit(X, y, epochs = 100, batch_size = 16)
# Out:
# Epoch 1/100
# 439/439 [==============================] - 10s 9ms/step - loss: 2.4479 - accuracy: 0.1162
# Epoch 2/100
# 439/439 [==============================] - 4s 10ms/step - loss: 2.2796 - accuracy: 0.1651
# Epoch 3/100
# 439/439 [==============================] - 5s 12ms/step - loss: 1.8144 - accuracy: 0.3450
# Epoch 4/100
# 439/439 [==============================] - 5s 11ms/step - loss: 1.3674 - accuracy: 0.5446
# Epoch 5/100
# 439/439 [==============================] - 5s 12ms/step - loss: 1.1295 - accuracy: 0.6541
# Epoch 6/100
# 439/439 [==============================] - 7s 15ms/step - loss: 1.0391 - accuracy: 0.6865
# Epoch 7/100
# 439/439 [==============================] - 4s 10ms/step - loss: 0.9935 - accuracy: 0.6948
# Epoch 8/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.9625 - accuracy: 0.7053
# Epoch 9/100
# 439/439 [==============================] - 6s 14ms/step - loss: 0.9398 - accuracy: 0.7044
# Epoch 10/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.9196 - accuracy: 0.7117
# Epoch 11/100
# 439/439 [==============================] - 8s 19ms/step - loss: 0.9028 - accuracy: 0.7136
# Epoch 12/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.8884 - accuracy: 0.7193
# Epoch 13/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.8765 - accuracy: 0.7223
# Epoch 14/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.8652 - accuracy: 0.7260
# Epoch 15/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.8539 - accuracy: 0.7251
# Epoch 16/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.8444 - accuracy: 0.7288
# Epoch 17/100
# 439/439 [==============================] - 8s 17ms/step - loss: 0.8343 - accuracy: 0.7337
# Epoch 18/100
# 439/439 [==============================] - 5s 10ms/step - loss: 0.8270 - accuracy: 0.7342
# Epoch 19/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.8198 - accuracy: 0.7372
# Epoch 20/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.8106 - accuracy: 0.7399
# Epoch 21/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.8058 - accuracy: 0.7392
# Epoch 22/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7990 - accuracy: 0.7428
# Epoch 23/100
# 439/439 [==============================] - 4s 10ms/step - loss: 0.7935 - accuracy: 0.7442
# Epoch 24/100
# 439/439 [==============================] - 6s 13ms/step - loss: 0.7894 - accuracy: 0.7429
# Epoch 25/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7835 - accuracy: 0.7464
# Epoch 26/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7796 - accuracy: 0.7494
# Epoch 27/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.7749 - accuracy: 0.7481
# Epoch 28/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.7699 - accuracy: 0.7551
# Epoch 29/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.7685 - accuracy: 0.7492
# Epoch 30/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.7628 - accuracy: 0.7504
# Epoch 31/100
# 439/439 [==============================] - 4s 10ms/step - loss: 0.7606 - accuracy: 0.7543
# Epoch 32/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7571 - accuracy: 0.7536
# Epoch 33/100
# 439/439 [==============================] - 4s 10ms/step - loss: 0.7543 - accuracy: 0.7549
# Epoch 34/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.7513 - accuracy: 0.7538
# Epoch 35/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7497 - accuracy: 0.7558
# Epoch 36/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7461 - accuracy: 0.7613
# Epoch 37/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.7428 - accuracy: 0.7581
# Epoch 38/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7415 - accuracy: 0.7579
# Epoch 39/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7398 - accuracy: 0.7612
# Epoch 40/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.7370 - accuracy: 0.7610
# Epoch 41/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.7336 - accuracy: 0.7610
# Epoch 42/100
# 439/439 [==============================] - 4s 10ms/step - loss: 0.7322 - accuracy: 0.7619
# Epoch 43/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.7309 - accuracy: 0.7606
# Epoch 44/100
# 439/439 [==============================] - 6s 13ms/step - loss: 0.7276 - accuracy: 0.7640
# Epoch 45/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7240 - accuracy: 0.7632
# Epoch 46/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7249 - accuracy: 0.7649
# Epoch 47/100
# 439/439 [==============================] - 6s 13ms/step - loss: 0.7225 - accuracy: 0.7632
# Epoch 48/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7206 - accuracy: 0.7639
# Epoch 49/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7182 - accuracy: 0.7658
# Epoch 50/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.7151 - accuracy: 0.7652
# Epoch 51/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.7135 - accuracy: 0.7658
# Epoch 52/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7109 - accuracy: 0.7656
# Epoch 53/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7093 - accuracy: 0.7692
# Epoch 54/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.7068 - accuracy: 0.7685
# Epoch 55/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7038 - accuracy: 0.7695
# Epoch 56/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7033 - accuracy: 0.7703
# Epoch 57/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.7008 - accuracy: 0.7692
# Epoch 58/100
# 439/439 [==============================] - 4s 10ms/step - loss: 0.6993 - accuracy: 0.7690
# Epoch 59/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6972 - accuracy: 0.7690
# Epoch 60/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6960 - accuracy: 0.7723
# Epoch 61/100
# 439/439 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.7695
# Epoch 62/100
# 439/439 [==============================] - 5s 10ms/step - loss: 0.6926 - accuracy: 0.7723
# Epoch 63/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6890 - accuracy: 0.7725
# Epoch 64/100
# 439/439 [==============================] - 6s 13ms/step - loss: 0.6891 - accuracy: 0.7706
# Epoch 65/100
# 439/439 [==============================] - 4s 10ms/step - loss: 0.6859 - accuracy: 0.7726
# Epoch 66/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6847 - accuracy: 0.7716
# Epoch 67/100
# 439/439 [==============================] - 6s 13ms/step - loss: 0.6837 - accuracy: 0.7737
# Epoch 68/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6803 - accuracy: 0.7767
# Epoch 69/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6788 - accuracy: 0.7743
# Epoch 70/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.6769 - accuracy: 0.7760
# Epoch 71/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.6756 - accuracy: 0.7750
# Epoch 72/100
# 439/439 [==============================] - 5s 10ms/step - loss: 0.6737 - accuracy: 0.7779
# Epoch 73/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.6723 - accuracy: 0.7784
# Epoch 74/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.6703 - accuracy: 0.7760
# Epoch 75/100
# 439/439 [==============================] - 4s 10ms/step - loss: 0.6704 - accuracy: 0.7750
# Epoch 76/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6674 - accuracy: 0.7797
# Epoch 77/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6664 - accuracy: 0.7762
# Epoch 78/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6652 - accuracy: 0.7770
# Epoch 79/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6640 - accuracy: 0.7794
# Epoch 80/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.6622 - accuracy: 0.7783
# Epoch 81/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6607 - accuracy: 0.7780
# Epoch 82/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6590 - accuracy: 0.7820
# Epoch 83/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6583 - accuracy: 0.7819
# Epoch 84/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6570 - accuracy: 0.7824
# Epoch 85/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.6568 - accuracy: 0.7846
# Epoch 86/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6552 - accuracy: 0.7813
# Epoch 87/100
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6532 - accuracy: 0.7812
# Epoch 88/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6527 - accuracy: 0.7841
# Epoch 89/100
# 439/439 [==============================] - 7s 16ms/step - loss: 0.6511 - accuracy: 0.7839
# Epoch 90/100
# 439/439 [==============================] - 8s 19ms/step - loss: 0.6497 - accuracy: 0.7844
# Epoch 91/100
# 439/439 [==============================] - 8s 17ms/step - loss: 0.6495 - accuracy: 0.7812
# Epoch 92/100
# 439/439 [==============================] - 8s 19ms/step - loss: 0.6477 - accuracy: 0.7850
# Epoch 93/100
# 439/439 [==============================] - 8s 18ms/step - loss: 0.6466 - accuracy: 0.7850
# Epoch 94/100
# 439/439 [==============================] - 5s 10ms/step - loss: 0.6460 - accuracy: 0.7830
# Epoch 95/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6470 - accuracy: 0.7831
# Epoch 96/100
# 439/439 [==============================] - 4s 10ms/step - loss: 0.6440 - accuracy: 0.7843
# Epoch 97/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.6447 - accuracy: 0.7847
# Epoch 98/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6430 - accuracy: 0.7850
# Epoch 99/100
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6418 - accuracy: 0.7849
# Epoch 100/100
# 439/439 [==============================] - 5s 12ms/step - loss: 0.6407 - accuracy: 0.7870

# %%
model0.save('/content/gdrive/MyDrive/DSLSC/Models_1/Model0_5.h5')

# %% [markdown]
# ### Keras tuner \#1

# %%
#!rm -rf /content/best_hyperparams_1

# %% [markdown]
# Now we use the keras tuner in order to find the best units combination.

# %%
# 16 different combinations
def build_model_1(hp):
  model = Sequential()
  model.add(LSTM(units = hp.Int('units_lstm_1', min_value = 16, max_value = 32, step = 16),
                  input_shape = (seq_len, n_feats),
                  return_sequences = True))
  model.add(LSTM(units = hp.Int('units_lstm_2', min_value = 32, max_value = 64, step = 32),
                  return_sequences = False))
  model.add(Dense(units = hp.Int('units_dense', min_value = 32, max_value = 64, step = 32)))
  model.add(Dense(12, activation = 'softmax'))
  
  optimizer = Adam(learning_rate = hp.Choice('learning_rate', values = [0.001, 0.0001]))
  model.compile(optimizer =  optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
tuner_1 = GridSearch(
  build_model_1,
  objective = 'val_loss',
  executions_per_trial = 1,
  directory = '/content',
  project_name = 'best_hyperparams_1'
)

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
# Grid search
tuner_1.search(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
# Retrieve best hyperparameters and final model
best_hp = tuner_1.get_best_hyperparameters()[0]
best_model = tuner_1.hypermodel.build(best_hp)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 5, 32)             4864
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 14,636
# Trainable params: 14,636
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's try this model.

# %% [markdown]
# ### Model 1

# %%
model1 = Sequential()
model1.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model1.add(LSTM(32, return_sequences = False))
model1.add(Dense(32))
model1.add(Dense(12, activation = 'softmax'))
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 5, 32)             4864
#
#  lstm_5 (LSTM)               (None, 32)                8320
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 14,636
# Trainable params: 14,636
# Non-trainable params: 0
# _________________________________________________________________

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
optimizer = Adam(learning_rate = 0.001)
model1.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history1 = model1.fit(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model1 = Sequential()
model1.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model1.add(LSTM(32, return_sequences = False))
model1.add(Dense(32))
model1.add(Dense(12, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.001)
model1.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history1 = model1.fit(X, y, epochs = 75, batch_size = 16)
# Out:
# Epoch 1/75
# 439/439 [==============================] - 9s 9ms/step - loss: 1.3175 - accuracy: 0.5553
# Epoch 2/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.8511 - accuracy: 0.7161
# Epoch 3/75
# 439/439 [==============================] - 5s 12ms/step - loss: 0.7890 - accuracy: 0.7345
# Epoch 4/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7519 - accuracy: 0.7474
# Epoch 5/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7285 - accuracy: 0.7491
# Epoch 6/75
# 439/439 [==============================] - 4s 10ms/step - loss: 0.7086 - accuracy: 0.7593
# Epoch 7/75
# 439/439 [==============================] - 6s 15ms/step - loss: 0.6885 - accuracy: 0.7648
# Epoch 8/75
# 439/439 [==============================] - 8s 18ms/step - loss: 0.6720 - accuracy: 0.7689
# Epoch 9/75
# 439/439 [==============================] - 9s 20ms/step - loss: 0.6658 - accuracy: 0.7720
# Epoch 10/75
# 439/439 [==============================] - 7s 16ms/step - loss: 0.6620 - accuracy: 0.7702
# Epoch 11/75
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6486 - accuracy: 0.7786
# Epoch 12/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6282 - accuracy: 0.7814
# Epoch 13/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6135 - accuracy: 0.7908
# Epoch 14/75
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6021 - accuracy: 0.7924
# Epoch 15/75
# 439/439 [==============================] - 4s 10ms/step - loss: 0.5861 - accuracy: 0.7988
# Epoch 16/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5779 - accuracy: 0.8005
# Epoch 17/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5614 - accuracy: 0.8075
# Epoch 18/75
# 439/439 [==============================] - 5s 12ms/step - loss: 0.5501 - accuracy: 0.8141
# Epoch 19/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5321 - accuracy: 0.8184
# Epoch 20/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5276 - accuracy: 0.8214
# Epoch 21/75
# 439/439 [==============================] - 5s 11ms/step - loss: 0.5120 - accuracy: 0.8271
# Epoch 22/75
# 439/439 [==============================] - 4s 10ms/step - loss: 0.5012 - accuracy: 0.8295
# Epoch 23/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4913 - accuracy: 0.8326
# Epoch 24/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4684 - accuracy: 0.8432
# Epoch 25/75
# 439/439 [==============================] - 5s 12ms/step - loss: 0.4533 - accuracy: 0.8459
# Epoch 26/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4495 - accuracy: 0.8474
# Epoch 27/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4348 - accuracy: 0.8526
# Epoch 28/75
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4259 - accuracy: 0.8584
# Epoch 29/75
# 439/439 [==============================] - 5s 10ms/step - loss: 0.4200 - accuracy: 0.8604
# Epoch 30/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4063 - accuracy: 0.8613
# Epoch 31/75
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4023 - accuracy: 0.8640
# Epoch 32/75
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3961 - accuracy: 0.8680
# Epoch 33/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3815 - accuracy: 0.8737
# Epoch 34/75
# 439/439 [==============================] - 4s 8ms/step - loss: 0.3766 - accuracy: 0.8721
# Epoch 35/75
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3703 - accuracy: 0.8748
# Epoch 36/75
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3583 - accuracy: 0.8791
# Epoch 37/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3543 - accuracy: 0.8788
# Epoch 38/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3396 - accuracy: 0.8798
# Epoch 39/75
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3374 - accuracy: 0.8814
# Epoch 40/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3271 - accuracy: 0.8874
# Epoch 41/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3253 - accuracy: 0.8867
# Epoch 42/75
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3194 - accuracy: 0.8905
# Epoch 43/75
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3097 - accuracy: 0.8935
# Epoch 44/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3119 - accuracy: 0.8882
# Epoch 45/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3004 - accuracy: 0.8954
# Epoch 46/75
# 439/439 [==============================] - 5s 12ms/step - loss: 0.2897 - accuracy: 0.8992
# Epoch 47/75
# 439/439 [==============================] - 4s 8ms/step - loss: 0.2869 - accuracy: 0.8968
# Epoch 48/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.2883 - accuracy: 0.9009
# Epoch 49/75
# 439/439 [==============================] - 4s 10ms/step - loss: 0.2785 - accuracy: 0.9045
# Epoch 50/75
# 439/439 [==============================] - 5s 11ms/step - loss: 0.2698 - accuracy: 0.9038
# Epoch 51/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.2635 - accuracy: 0.9088
# Epoch 52/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.2544 - accuracy: 0.9159
# Epoch 53/75
# 439/439 [==============================] - 5s 12ms/step - loss: 0.2544 - accuracy: 0.9103
# Epoch 54/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.2505 - accuracy: 0.9105
# Epoch 55/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.2460 - accuracy: 0.9129
# Epoch 56/75
# 439/439 [==============================] - 7s 15ms/step - loss: 0.2386 - accuracy: 0.9177
# Epoch 57/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.2310 - accuracy: 0.9222
# Epoch 58/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.2279 - accuracy: 0.9207
# Epoch 59/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.2231 - accuracy: 0.9219
# Epoch 60/75
# 439/439 [==============================] - 5s 11ms/step - loss: 0.2157 - accuracy: 0.9271
# Epoch 61/75
# 439/439 [==============================] - 4s 8ms/step - loss: 0.2078 - accuracy: 0.9296
# Epoch 62/75
# 439/439 [==============================] - 4s 8ms/step - loss: 0.2058 - accuracy: 0.9279
# Epoch 63/75
# 439/439 [==============================] - 5s 10ms/step - loss: 0.1983 - accuracy: 0.9310
# Epoch 64/75
# 439/439 [==============================] - 4s 10ms/step - loss: 0.1998 - accuracy: 0.9290
# Epoch 65/75
# 439/439 [==============================] - 4s 8ms/step - loss: 0.1946 - accuracy: 0.9311
# Epoch 66/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.1845 - accuracy: 0.9354
# Epoch 67/75
# 439/439 [==============================] - 5s 12ms/step - loss: 0.1803 - accuracy: 0.9400
# Epoch 68/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.1758 - accuracy: 0.9391
# Epoch 69/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.1729 - accuracy: 0.9413
# Epoch 70/75
# 439/439 [==============================] - 4s 10ms/step - loss: 0.1734 - accuracy: 0.9393
# Epoch 71/75
# 439/439 [==============================] - 5s 11ms/step - loss: 0.1580 - accuracy: 0.9457
# Epoch 72/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.1564 - accuracy: 0.9468
# Epoch 73/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.1479 - accuracy: 0.9497
# Epoch 74/75
# 439/439 [==============================] - 5s 11ms/step - loss: 0.1560 - accuracy: 0.9450
# Epoch 75/75
# 439/439 [==============================] - 4s 9ms/step - loss: 0.1457 - accuracy: 0.9512

# %%
model1.save('/content/gdrive/MyDrive/DSLSC/Models_1/Model1_5.h5')

# %% [markdown]
# ### Keras tuner \#2

# %%
#!rm -rf /content/best_hyperparams_2

# %% [markdown]
# Now we use the keras tuner in order to find the best dropout combination.

# %%
# 12 different combinations
def build_model_2(hp):
  model = Sequential()
  model.add(LSTM(units = 32, input_shape = (seq_len, n_feats), return_sequences = True))
  model.add(Dropout(hp.Float('dropout_lstm_1', min_value = 0.0, max_value = 0.2, step = 0.2)))
  model.add(LSTM(units = 32, return_sequences = False))
  model.add(Dropout(hp.Float('dropout_lstm_2', min_value = 0.0, max_value = 0.2, step = 0.2)))
  model.add(Dense(units = 32))
  model.add(Dropout(hp.Float('dropout_dense', min_value = 0.0, max_value = 0.4, step = 0.2)))
  model.add(Dense(12, activation = 'softmax'))
  
  optimizer = Adam(learning_rate = 0.001)
  model.compile(optimizer =  optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
tuner_2 = GridSearch(
  build_model_2,
  objective = 'val_loss',
  executions_per_trial = 1,
  directory = '/content',
  project_name = 'best_hyperparams_2'
)

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
# Grid search
tuner_2.search(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
# Retrieve best hyperparameters and final model
best_hp = tuner_2.get_best_hyperparameters()[0]
best_model = tuner_2.hypermodel.build(best_hp)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 5, 32)             4864
#
#  dropout_3 (Dropout)         (None, 5, 32)             0
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 14,636
# Trainable params: 14,636
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's try this model.

# %% [markdown]
# ### Model 2

# %%
model2 = Sequential()
model2.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model2.add(Dropout(0.2))
model2.add(LSTM(32, return_sequences = False))
model2.add(Dropout(0.2))
model2.add(Dense(32))
model2.add(Dropout(0.4))
model2.add(Dense(12, activation = 'softmax'))
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 5, 32)             4864
#
#  dropout_6 (Dropout)         (None, 5, 32)             0
#
#  lstm_5 (LSTM)               (None, 32)                8320
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 14,636
# Trainable params: 14,636
# Non-trainable params: 0
# _________________________________________________________________

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
optimizer = Adam(learning_rate = 0.001)
model2.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history2 = model2.fit(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model2 = Sequential()
model2.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model2.add(Dropout(0.2))
model2.add(LSTM(32, return_sequences = False))
model2.add(Dropout(0.2))
model2.add(Dense(32))
model2.add(Dropout(0.4))
model2.add(Dense(12, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.001)
model2.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history2 = model2.fit(X, y, epochs = 125, batch_size = 16)
# Out:
# Epoch 1/125
# 439/439 [==============================] - 9s 9ms/step - loss: 1.7244 - accuracy: 0.3708
# Epoch 2/125
# 439/439 [==============================] - 5s 12ms/step - loss: 1.1146 - accuracy: 0.5988
# Epoch 3/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.9829 - accuracy: 0.6537
# Epoch 4/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.9166 - accuracy: 0.6822
# Epoch 5/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.8888 - accuracy: 0.6913
# Epoch 6/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.8494 - accuracy: 0.7144
# Epoch 7/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.8280 - accuracy: 0.7184
# Epoch 8/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.8179 - accuracy: 0.7313
# Epoch 9/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.7875 - accuracy: 0.7301
# Epoch 10/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7957 - accuracy: 0.7270
# Epoch 11/125
# 439/439 [==============================] - 9s 21ms/step - loss: 0.7705 - accuracy: 0.7360
# Epoch 12/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.7528 - accuracy: 0.7408
# Epoch 13/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7458 - accuracy: 0.7471
# Epoch 14/125
# 439/439 [==============================] - 5s 13ms/step - loss: 0.7374 - accuracy: 0.7559
# Epoch 15/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.7227 - accuracy: 0.7563
# Epoch 16/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.6990 - accuracy: 0.7632
# Epoch 17/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.6783 - accuracy: 0.7769
# Epoch 18/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6733 - accuracy: 0.7754
# Epoch 19/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6460 - accuracy: 0.7906
# Epoch 20/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6395 - accuracy: 0.7911
# Epoch 21/125
# 439/439 [==============================] - 5s 10ms/step - loss: 0.6308 - accuracy: 0.7908
# Epoch 22/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6120 - accuracy: 0.7973
# Epoch 23/125
# 439/439 [==============================] - 6s 14ms/step - loss: 0.6171 - accuracy: 0.7993
# Epoch 24/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.5950 - accuracy: 0.8020
# Epoch 25/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5848 - accuracy: 0.8090
# Epoch 26/125
# 439/439 [==============================] - 5s 10ms/step - loss: 0.5828 - accuracy: 0.8087
# Epoch 27/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.5778 - accuracy: 0.8137
# Epoch 28/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.5629 - accuracy: 0.8167
# Epoch 29/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.5637 - accuracy: 0.8168
# Epoch 30/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.5610 - accuracy: 0.8152
# Epoch 31/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5562 - accuracy: 0.8178
# Epoch 32/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5568 - accuracy: 0.8222
# Epoch 33/125
# 439/439 [==============================] - 6s 15ms/step - loss: 0.5364 - accuracy: 0.8262
# Epoch 34/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5304 - accuracy: 0.8282
# Epoch 35/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5277 - accuracy: 0.8279
# Epoch 36/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.5312 - accuracy: 0.8249
# Epoch 37/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.5272 - accuracy: 0.8318
# Epoch 38/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5115 - accuracy: 0.8363
# Epoch 39/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.5132 - accuracy: 0.8352
# Epoch 40/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.4970 - accuracy: 0.8447
# Epoch 41/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4984 - accuracy: 0.8399
# Epoch 42/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4918 - accuracy: 0.8399
# Epoch 43/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.4918 - accuracy: 0.8372
# Epoch 44/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4873 - accuracy: 0.8459
# Epoch 45/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4867 - accuracy: 0.8473
# Epoch 46/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.4704 - accuracy: 0.8489
# Epoch 47/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4770 - accuracy: 0.8483
# Epoch 48/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4771 - accuracy: 0.8476
# Epoch 49/125
# 439/439 [==============================] - 8s 17ms/step - loss: 0.4575 - accuracy: 0.8561
# Epoch 50/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4700 - accuracy: 0.8527
# Epoch 51/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4575 - accuracy: 0.8541
# Epoch 52/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.4523 - accuracy: 0.8530
# Epoch 53/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.4449 - accuracy: 0.8571
# Epoch 54/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4598 - accuracy: 0.8563
# Epoch 55/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4415 - accuracy: 0.8624
# Epoch 56/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.4412 - accuracy: 0.8641
# Epoch 57/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4297 - accuracy: 0.8617
# Epoch 58/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4287 - accuracy: 0.8600
# Epoch 59/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.4197 - accuracy: 0.8683
# Epoch 60/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4238 - accuracy: 0.8658
# Epoch 61/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4346 - accuracy: 0.8643
# Epoch 62/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.4193 - accuracy: 0.8680
# Epoch 63/125
# 439/439 [==============================] - 5s 10ms/step - loss: 0.4250 - accuracy: 0.8657
# Epoch 64/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4030 - accuracy: 0.8750
# Epoch 65/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4087 - accuracy: 0.8715
# Epoch 66/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.4130 - accuracy: 0.8725
# Epoch 67/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4108 - accuracy: 0.8708
# Epoch 68/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4075 - accuracy: 0.8710
# Epoch 69/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3964 - accuracy: 0.8764
# Epoch 70/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3963 - accuracy: 0.8767
# Epoch 71/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3964 - accuracy: 0.8743
# Epoch 72/125
# 439/439 [==============================] - 6s 14ms/step - loss: 0.3901 - accuracy: 0.8768
# Epoch 73/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3869 - accuracy: 0.8792
# Epoch 74/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3837 - accuracy: 0.8737
# Epoch 75/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3742 - accuracy: 0.8804
# Epoch 76/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3828 - accuracy: 0.8808
# Epoch 77/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3814 - accuracy: 0.8775
# Epoch 78/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3637 - accuracy: 0.8864
# Epoch 79/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3694 - accuracy: 0.8824
# Epoch 80/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3782 - accuracy: 0.8812
# Epoch 81/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3790 - accuracy: 0.8834
# Epoch 82/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.3817 - accuracy: 0.8764
# Epoch 83/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3580 - accuracy: 0.8896
# Epoch 84/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3554 - accuracy: 0.8884
# Epoch 85/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3681 - accuracy: 0.8831
# Epoch 86/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3644 - accuracy: 0.8834
# Epoch 87/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3539 - accuracy: 0.8915
# Epoch 88/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3537 - accuracy: 0.8862
# Epoch 89/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3554 - accuracy: 0.8849
# Epoch 90/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3360 - accuracy: 0.8942
# Epoch 91/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3563 - accuracy: 0.8899
# Epoch 92/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.3470 - accuracy: 0.8894
# Epoch 93/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3465 - accuracy: 0.8898
# Epoch 94/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3584 - accuracy: 0.8864
# Epoch 95/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3474 - accuracy: 0.8912
# Epoch 96/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3373 - accuracy: 0.8918
# Epoch 97/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3434 - accuracy: 0.8882
# Epoch 98/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3385 - accuracy: 0.8904
# Epoch 99/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3313 - accuracy: 0.8936
# Epoch 100/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3340 - accuracy: 0.8944
# Epoch 101/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3270 - accuracy: 0.8965
# Epoch 102/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3357 - accuracy: 0.8939
# Epoch 103/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3370 - accuracy: 0.8915
# Epoch 104/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3407 - accuracy: 0.8918
# Epoch 105/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3272 - accuracy: 0.8989
# Epoch 106/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3246 - accuracy: 0.8969
# Epoch 107/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3189 - accuracy: 0.9003
# Epoch 108/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3255 - accuracy: 0.8954
# Epoch 109/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3207 - accuracy: 0.9009
# Epoch 110/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3191 - accuracy: 0.8949
# Epoch 111/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3149 - accuracy: 0.8982
# Epoch 112/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3194 - accuracy: 0.8976
# Epoch 113/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3188 - accuracy: 0.8988
# Epoch 114/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.2997 - accuracy: 0.9021
# Epoch 115/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.3183 - accuracy: 0.8985
# Epoch 116/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3202 - accuracy: 0.8983
# Epoch 117/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3142 - accuracy: 0.8985
# Epoch 118/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3108 - accuracy: 0.8992
# Epoch 119/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3005 - accuracy: 0.9016
# Epoch 120/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3028 - accuracy: 0.9039
# Epoch 121/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3039 - accuracy: 0.9012
# Epoch 122/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.2946 - accuracy: 0.9055
# Epoch 123/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.2951 - accuracy: 0.9029
# Epoch 124/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.2934 - accuracy: 0.9092
# Epoch 125/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.2890 - accuracy: 0.9059

# %%
model2.save('/content/gdrive/MyDrive/DSLSC/Models_1/Model2_5.h5')

# %% [markdown]
# ### Keras tuner \#3

# %%
#!rm -rf /content/best_hyperparams_3

# %% [markdown]
# Now we use the keras tuner in order to find the best regularizers combination.

# %%
# 64 different combinations
def build_model_3(hp):
  model = Sequential()
  model.add(LSTM(units = 32, input_shape = (seq_len, n_feats), return_sequences = True, 
                 kernel_regularizer = regularizers.l2(hp.Choice('kernel_regularizer_lstm_1', values = [0.0, 0.01])),
                 bias_regularizer = regularizers.l2(hp.Choice('bias_regularizer_lstm_1', values = [0.0, 0.01]))))
  model.add(Dropout(0.2))
  model.add(LSTM(units = 32, return_sequences = False,
                 kernel_regularizer = regularizers.l2(hp.Choice('kernel_regularizer_lstm_2', values = [0.0, 0.01])),
                 bias_regularizer = regularizers.l2(hp.Choice('bias_regularizer_lstm_2', values = [0.0, 0.01]))))
  model.add(Dropout(0.2))
  model.add(Dense(units = 32,
                  kernel_regularizer = regularizers.l2(hp.Choice('kernel_regularizer_dense', values = [0.0, 0.01])),
                  bias_regularizer = regularizers.l2(hp.Choice('bias_regularizer_dense', values = [0.0, 0.01]))))
  model.add(Dropout(0.4))
  model.add(Dense(12, activation = 'softmax'))
  
  optimizer = Adam(learning_rate = 0.001)
  model.compile(optimizer =  optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
tuner_3 = GridSearch(
  build_model_3,
  objective = 'val_loss',
  executions_per_trial = 1,
  directory = '/content',
  project_name = 'best_hyperparams_3'
)

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
# Grid search
tuner_3.search(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
# Retrieve best hyperparameters and final model
best_hp = tuner_3.get_best_hyperparameters()[0]
best_model = tuner_3.hypermodel.build(best_hp)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 5, 32)             4864
#
#  dropout_3 (Dropout)         (None, 5, 32)             0
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 14,636
# Trainable params: 14,636
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's try this model.

# %% [markdown]
# ### Model 3

# %%
model3 = Sequential()
model3.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model3.add(Dropout(0.2))
model3.add(LSTM(32, return_sequences = False))
model3.add(Dropout(0.2))
model3.add(Dense(32, bias_regularizer = regularizers.l2(0.01)))
model3.add(Dropout(0.4))
model3.add(Dense(12, activation = 'softmax'))
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 5, 32)             4864
#
#  dropout_6 (Dropout)         (None, 5, 32)             0
#
#  lstm_5 (LSTM)               (None, 32)                8320
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 14,636
# Trainable params: 14,636
# Non-trainable params: 0
# _________________________________________________________________

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
optimizer = Adam(learning_rate = 0.001)
model3.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history3 = model3.fit(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history3.history['accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model3 = Sequential()
model3.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model3.add(Dropout(0.2))
model3.add(LSTM(32, return_sequences = False))
model3.add(Dropout(0.2))
model3.add(Dense(32, bias_regularizer = regularizers.l2(0.01)))
model3.add(Dropout(0.4))
model3.add(Dense(12, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.001)
model3.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history3 = model3.fit(X, y, epochs = 125, batch_size = 16)
# Out:
# Epoch 1/125
# 439/439 [==============================] - 9s 9ms/step - loss: 1.6814 - accuracy: 0.3854
# Epoch 2/125
# 439/439 [==============================] - 5s 10ms/step - loss: 1.1097 - accuracy: 0.6082
# Epoch 3/125
# 439/439 [==============================] - 6s 14ms/step - loss: 0.9880 - accuracy: 0.6558
# Epoch 4/125
# 439/439 [==============================] - 7s 17ms/step - loss: 0.9166 - accuracy: 0.6856
# Epoch 5/125
# 439/439 [==============================] - 6s 14ms/step - loss: 0.8826 - accuracy: 0.6936
# Epoch 6/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.8560 - accuracy: 0.7149
# Epoch 7/125
# 439/439 [==============================] - 5s 10ms/step - loss: 0.8186 - accuracy: 0.7236
# Epoch 8/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.8237 - accuracy: 0.7274
# Epoch 9/125
# 439/439 [==============================] - 6s 14ms/step - loss: 0.8022 - accuracy: 0.7250
# Epoch 10/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.7878 - accuracy: 0.7328
# Epoch 11/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.7754 - accuracy: 0.7419
# Epoch 12/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7598 - accuracy: 0.7481
# Epoch 13/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7507 - accuracy: 0.7502
# Epoch 14/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.7417 - accuracy: 0.7519
# Epoch 15/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.7266 - accuracy: 0.7582
# Epoch 16/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.7099 - accuracy: 0.7643
# Epoch 17/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6796 - accuracy: 0.7763
# Epoch 18/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.6554 - accuracy: 0.7849
# Epoch 19/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6406 - accuracy: 0.7913
# Epoch 20/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6292 - accuracy: 0.7901
# Epoch 21/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.6206 - accuracy: 0.7990
# Epoch 22/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6035 - accuracy: 0.7995
# Epoch 23/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.6027 - accuracy: 0.7995
# Epoch 24/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.5990 - accuracy: 0.8041
# Epoch 25/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.5982 - accuracy: 0.8054
# Epoch 26/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.5816 - accuracy: 0.8118
# Epoch 27/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.5842 - accuracy: 0.8147
# Epoch 28/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.5746 - accuracy: 0.8107
# Epoch 29/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5690 - accuracy: 0.8174
# Epoch 30/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5516 - accuracy: 0.8164
# Epoch 31/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.5511 - accuracy: 0.8234
# Epoch 32/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5465 - accuracy: 0.8258
# Epoch 33/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5461 - accuracy: 0.8226
# Epoch 34/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.5343 - accuracy: 0.8289
# Epoch 35/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.5308 - accuracy: 0.8238
# Epoch 36/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5421 - accuracy: 0.8306
# Epoch 37/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5355 - accuracy: 0.8278
# Epoch 38/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.5302 - accuracy: 0.8313
# Epoch 39/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5095 - accuracy: 0.8342
# Epoch 40/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.5160 - accuracy: 0.8333
# Epoch 41/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.5148 - accuracy: 0.8333
# Epoch 42/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.5126 - accuracy: 0.8342
# Epoch 43/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4997 - accuracy: 0.8386
# Epoch 44/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.5036 - accuracy: 0.8385
# Epoch 45/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.5022 - accuracy: 0.8432
# Epoch 46/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4945 - accuracy: 0.8437
# Epoch 47/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4796 - accuracy: 0.8493
# Epoch 48/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.4759 - accuracy: 0.8476
# Epoch 49/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4718 - accuracy: 0.8493
# Epoch 50/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.4749 - accuracy: 0.8492
# Epoch 51/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.4820 - accuracy: 0.8483
# Epoch 52/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.4735 - accuracy: 0.8480
# Epoch 53/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.4628 - accuracy: 0.8526
# Epoch 54/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.4739 - accuracy: 0.8489
# Epoch 55/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4514 - accuracy: 0.8534
# Epoch 56/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4545 - accuracy: 0.8608
# Epoch 57/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.4512 - accuracy: 0.8600
# Epoch 58/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.4493 - accuracy: 0.8610
# Epoch 59/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4548 - accuracy: 0.8556
# Epoch 60/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4461 - accuracy: 0.8586
# Epoch 61/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.4327 - accuracy: 0.8623
# Epoch 62/125
# 439/439 [==============================] - 7s 15ms/step - loss: 0.4447 - accuracy: 0.8603
# Epoch 63/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4296 - accuracy: 0.8628
# Epoch 64/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.4326 - accuracy: 0.8661
# Epoch 65/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4292 - accuracy: 0.8667
# Epoch 66/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4307 - accuracy: 0.8668
# Epoch 67/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.4314 - accuracy: 0.8626
# Epoch 68/125
# 439/439 [==============================] - 5s 10ms/step - loss: 0.4229 - accuracy: 0.8654
# Epoch 69/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4118 - accuracy: 0.8695
# Epoch 70/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4095 - accuracy: 0.8688
# Epoch 71/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.4075 - accuracy: 0.8703
# Epoch 72/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4045 - accuracy: 0.8731
# Epoch 73/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4021 - accuracy: 0.8733
# Epoch 74/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.4003 - accuracy: 0.8750
# Epoch 75/125
# 439/439 [==============================] - 5s 10ms/step - loss: 0.4048 - accuracy: 0.8721
# Epoch 76/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.4035 - accuracy: 0.8744
# Epoch 77/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3990 - accuracy: 0.8713
# Epoch 78/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3996 - accuracy: 0.8724
# Epoch 79/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3833 - accuracy: 0.8807
# Epoch 80/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3871 - accuracy: 0.8751
# Epoch 81/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3830 - accuracy: 0.8801
# Epoch 82/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3991 - accuracy: 0.8764
# Epoch 83/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3782 - accuracy: 0.8857
# Epoch 84/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3772 - accuracy: 0.8752
# Epoch 85/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3788 - accuracy: 0.8788
# Epoch 86/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3823 - accuracy: 0.8817
# Epoch 87/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3699 - accuracy: 0.8825
# Epoch 88/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3831 - accuracy: 0.8800
# Epoch 89/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3743 - accuracy: 0.8862
# Epoch 90/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3643 - accuracy: 0.8888
# Epoch 91/125
# 439/439 [==============================] - 5s 10ms/step - loss: 0.3604 - accuracy: 0.8832
# Epoch 92/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3635 - accuracy: 0.8877
# Epoch 93/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3595 - accuracy: 0.8875
# Epoch 94/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3575 - accuracy: 0.8852
# Epoch 95/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3638 - accuracy: 0.8892
# Epoch 96/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3605 - accuracy: 0.8848
# Epoch 97/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3578 - accuracy: 0.8885
# Epoch 98/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3606 - accuracy: 0.8859
# Epoch 99/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3529 - accuracy: 0.8871
# Epoch 100/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3428 - accuracy: 0.8918
# Epoch 101/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3426 - accuracy: 0.8942
# Epoch 102/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3308 - accuracy: 0.8945
# Epoch 103/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3354 - accuracy: 0.8944
# Epoch 104/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3486 - accuracy: 0.8872
# Epoch 105/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3322 - accuracy: 0.8939
# Epoch 106/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3383 - accuracy: 0.8916
# Epoch 107/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3382 - accuracy: 0.8922
# Epoch 108/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3305 - accuracy: 0.8938
# Epoch 109/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3411 - accuracy: 0.8906
# Epoch 110/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3388 - accuracy: 0.8948
# Epoch 111/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3371 - accuracy: 0.8918
# Epoch 112/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3247 - accuracy: 0.8993
# Epoch 113/125
# 439/439 [==============================] - 6s 13ms/step - loss: 0.3255 - accuracy: 0.8961
# Epoch 114/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3100 - accuracy: 0.9003
# Epoch 115/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3236 - accuracy: 0.8996
# Epoch 116/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3131 - accuracy: 0.9008
# Epoch 117/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3246 - accuracy: 0.8948
# Epoch 118/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3130 - accuracy: 0.9035
# Epoch 119/125
# 439/439 [==============================] - 5s 12ms/step - loss: 0.3159 - accuracy: 0.9021
# Epoch 120/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3214 - accuracy: 0.8991
# Epoch 121/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3095 - accuracy: 0.9011
# Epoch 122/125
# 439/439 [==============================] - 4s 10ms/step - loss: 0.3101 - accuracy: 0.9009
# Epoch 123/125
# 439/439 [==============================] - 5s 11ms/step - loss: 0.3114 - accuracy: 0.9008
# Epoch 124/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3044 - accuracy: 0.9033
# Epoch 125/125
# 439/439 [==============================] - 4s 9ms/step - loss: 0.3157 - accuracy: 0.8999

# %%
model3.save('/content/gdrive/MyDrive/DSLSC/Models_1/Model3_5.h5')

# %% [markdown]
# ### Model 4

# %% [markdown]
# Now we may try increasing the batch_size to 32.

# %%
model4 = Sequential()
model4.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model4.add(Dropout(0.2))
model4.add(LSTM(32, return_sequences = False))
model4.add(Dropout(0.2))
model4.add(Dense(32, bias_regularizer = regularizers.l2(0.01)))
model4.add(Dropout(0.4))
model4.add(Dense(12, activation = 'softmax'))
model4.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 5, 32)             4864
#
#  dropout_12 (Dropout)        (None, 5, 32)             0
#
#  lstm_9 (LSTM)               (None, 32)                8320
#
#  dropout_13 (Dropout)        (None, 32)                0
#
#  dense_8 (Dense)             (None, 32)                1056
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  dense_9 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 14,636
# Trainable params: 14,636
# Non-trainable params: 0
# _________________________________________________________________

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
optimizer = Adam(learning_rate = 0.001)
model4.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history4 = model4.fit(X_train, y_train, epochs = 200, batch_size = 32, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history4.history['accuracy'])
plt.plot(history4.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model4 = Sequential()
model4.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model4.add(Dropout(0.2))
model4.add(LSTM(32, return_sequences = False))
model4.add(Dropout(0.2))
model4.add(Dense(32, bias_regularizer = regularizers.l2(0.01)))
model4.add(Dropout(0.4))
model4.add(Dense(12, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.001)
model4.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history4 = model4.fit(X, y, epochs = 150, batch_size = 32)
# Out:
# Epoch 1/150
# 220/220 [==============================] - 6s 9ms/step - loss: 1.9169 - accuracy: 0.3072
# Epoch 2/150
# 220/220 [==============================] - 2s 10ms/step - loss: 1.2884 - accuracy: 0.5291
# Epoch 3/150
# 220/220 [==============================] - 2s 9ms/step - loss: 1.1032 - accuracy: 0.6099
# Epoch 4/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.9870 - accuracy: 0.6468
# Epoch 5/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.9402 - accuracy: 0.6759
# Epoch 6/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.8968 - accuracy: 0.6965
# Epoch 7/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.8785 - accuracy: 0.7019
# Epoch 8/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.8483 - accuracy: 0.7154
# Epoch 9/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.8293 - accuracy: 0.7283
# Epoch 10/150
# 220/220 [==============================] - 2s 11ms/step - loss: 0.8211 - accuracy: 0.7260
# Epoch 11/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.8104 - accuracy: 0.7358
# Epoch 12/150
# 220/220 [==============================] - 2s 11ms/step - loss: 0.8085 - accuracy: 0.7240
# Epoch 13/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.7839 - accuracy: 0.7449
# Epoch 14/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.7715 - accuracy: 0.7374
# Epoch 15/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.7705 - accuracy: 0.7418
# Epoch 16/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.7556 - accuracy: 0.7462
# Epoch 17/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.7469 - accuracy: 0.7551
# Epoch 18/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.7432 - accuracy: 0.7499
# Epoch 19/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.7337 - accuracy: 0.7563
# Epoch 20/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.7161 - accuracy: 0.7669
# Epoch 21/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.7094 - accuracy: 0.7703
# Epoch 22/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.6949 - accuracy: 0.7710
# Epoch 23/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.6831 - accuracy: 0.7750
# Epoch 24/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.6676 - accuracy: 0.7834
# Epoch 25/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.6566 - accuracy: 0.7834
# Epoch 26/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.6623 - accuracy: 0.7833
# Epoch 27/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.6247 - accuracy: 0.7960
# Epoch 28/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.6294 - accuracy: 0.7973
# Epoch 29/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.6241 - accuracy: 0.7975
# Epoch 30/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.6138 - accuracy: 0.7974
# Epoch 31/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.6043 - accuracy: 0.7985
# Epoch 32/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.6104 - accuracy: 0.8064
# Epoch 33/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.6021 - accuracy: 0.8048
# Epoch 34/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.5872 - accuracy: 0.8108
# Epoch 35/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.5895 - accuracy: 0.8075
# Epoch 36/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.5943 - accuracy: 0.8050
# Epoch 37/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.5762 - accuracy: 0.8135
# Epoch 38/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.5654 - accuracy: 0.8157
# Epoch 39/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.5579 - accuracy: 0.8188
# Epoch 40/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.5639 - accuracy: 0.8202
# Epoch 41/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.5544 - accuracy: 0.8165
# Epoch 42/150
# 220/220 [==============================] - 2s 11ms/step - loss: 0.5476 - accuracy: 0.8239
# Epoch 43/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.5546 - accuracy: 0.8218
# Epoch 44/150
# 220/220 [==============================] - 3s 11ms/step - loss: 0.5437 - accuracy: 0.8258
# Epoch 45/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.5384 - accuracy: 0.8286
# Epoch 46/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.5447 - accuracy: 0.8248
# Epoch 47/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.5263 - accuracy: 0.8296
# Epoch 48/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.5261 - accuracy: 0.8299
# Epoch 49/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.5309 - accuracy: 0.8301
# Epoch 50/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.5233 - accuracy: 0.8330
# Epoch 51/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.5175 - accuracy: 0.8386
# Epoch 52/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.5058 - accuracy: 0.8403
# Epoch 53/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.5054 - accuracy: 0.8348
# Epoch 54/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4987 - accuracy: 0.8395
# Epoch 55/150
# 220/220 [==============================] - 2s 11ms/step - loss: 0.5010 - accuracy: 0.8379
# Epoch 56/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.4950 - accuracy: 0.8427
# Epoch 57/150
# 220/220 [==============================] - 2s 11ms/step - loss: 0.4993 - accuracy: 0.8452
# Epoch 58/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4858 - accuracy: 0.8473
# Epoch 59/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4925 - accuracy: 0.8439
# Epoch 60/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4831 - accuracy: 0.8486
# Epoch 61/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.4723 - accuracy: 0.8533
# Epoch 62/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.4741 - accuracy: 0.8477
# Epoch 63/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.4770 - accuracy: 0.8512
# Epoch 64/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4808 - accuracy: 0.8512
# Epoch 65/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.4623 - accuracy: 0.8579
# Epoch 66/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4608 - accuracy: 0.8559
# Epoch 67/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4767 - accuracy: 0.8520
# Epoch 68/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.4665 - accuracy: 0.8530
# Epoch 69/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.4625 - accuracy: 0.8607
# Epoch 70/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.4447 - accuracy: 0.8556
# Epoch 71/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.4468 - accuracy: 0.8567
# Epoch 72/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4530 - accuracy: 0.8576
# Epoch 73/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4509 - accuracy: 0.8574
# Epoch 74/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.4451 - accuracy: 0.8640
# Epoch 75/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.4393 - accuracy: 0.8593
# Epoch 76/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.4458 - accuracy: 0.8640
# Epoch 77/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.4267 - accuracy: 0.8677
# Epoch 78/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.4366 - accuracy: 0.8648
# Epoch 79/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.4417 - accuracy: 0.8647
# Epoch 80/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4188 - accuracy: 0.8721
# Epoch 81/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.4378 - accuracy: 0.8607
# Epoch 82/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.4226 - accuracy: 0.8694
# Epoch 83/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.4226 - accuracy: 0.8691
# Epoch 84/150
# 220/220 [==============================] - 2s 11ms/step - loss: 0.4242 - accuracy: 0.8658
# Epoch 85/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.4162 - accuracy: 0.8684
# Epoch 86/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.4201 - accuracy: 0.8677
# Epoch 87/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.4216 - accuracy: 0.8705
# Epoch 88/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.4192 - accuracy: 0.8677
# Epoch 89/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4097 - accuracy: 0.8728
# Epoch 90/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4076 - accuracy: 0.8735
# Epoch 91/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4049 - accuracy: 0.8750
# Epoch 92/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.4211 - accuracy: 0.8723
# Epoch 93/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.3945 - accuracy: 0.8762
# Epoch 94/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.3979 - accuracy: 0.8744
# Epoch 95/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3974 - accuracy: 0.8738
# Epoch 96/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3901 - accuracy: 0.8791
# Epoch 97/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3983 - accuracy: 0.8711
# Epoch 98/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.3930 - accuracy: 0.8767
# Epoch 99/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.4001 - accuracy: 0.8743
# Epoch 100/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.3908 - accuracy: 0.8808
# Epoch 101/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.3918 - accuracy: 0.8760
# Epoch 102/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3974 - accuracy: 0.8800
# Epoch 103/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3814 - accuracy: 0.8787
# Epoch 104/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.3804 - accuracy: 0.8808
# Epoch 105/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3859 - accuracy: 0.8804
# Epoch 106/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.3846 - accuracy: 0.8778
# Epoch 107/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.3786 - accuracy: 0.8865
# Epoch 108/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.3863 - accuracy: 0.8778
# Epoch 109/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3782 - accuracy: 0.8828
# Epoch 110/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3830 - accuracy: 0.8828
# Epoch 111/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3752 - accuracy: 0.8844
# Epoch 112/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.3743 - accuracy: 0.8824
# Epoch 113/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.3639 - accuracy: 0.8852
# Epoch 114/150
# 220/220 [==============================] - 2s 11ms/step - loss: 0.3668 - accuracy: 0.8889
# Epoch 115/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.3526 - accuracy: 0.8885
# Epoch 116/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3714 - accuracy: 0.8844
# Epoch 117/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3663 - accuracy: 0.8824
# Epoch 118/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3603 - accuracy: 0.8914
# Epoch 119/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.3607 - accuracy: 0.8872
# Epoch 120/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.3584 - accuracy: 0.8874
# Epoch 121/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3615 - accuracy: 0.8887
# Epoch 122/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3602 - accuracy: 0.8848
# Epoch 123/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3574 - accuracy: 0.8875
# Epoch 124/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3551 - accuracy: 0.8918
# Epoch 125/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.3433 - accuracy: 0.8938
# Epoch 126/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.3565 - accuracy: 0.8885
# Epoch 127/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3500 - accuracy: 0.8906
# Epoch 128/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.3608 - accuracy: 0.8871
# Epoch 129/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.3454 - accuracy: 0.8919
# Epoch 130/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3516 - accuracy: 0.8872
# Epoch 131/150
# 220/220 [==============================] - 2s 11ms/step - loss: 0.3572 - accuracy: 0.8894
# Epoch 132/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.3413 - accuracy: 0.8919
# Epoch 133/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.3494 - accuracy: 0.8916
# Epoch 134/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3461 - accuracy: 0.8904
# Epoch 135/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.3337 - accuracy: 0.8965
# Epoch 136/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3330 - accuracy: 0.8921
# Epoch 137/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3385 - accuracy: 0.8939
# Epoch 138/150
# 220/220 [==============================] - 3s 13ms/step - loss: 0.3352 - accuracy: 0.8928
# Epoch 139/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.3279 - accuracy: 0.8964
# Epoch 140/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.3438 - accuracy: 0.8954
# Epoch 141/150
# 220/220 [==============================] - 2s 9ms/step - loss: 0.3405 - accuracy: 0.8973
# Epoch 142/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3301 - accuracy: 0.8966
# Epoch 143/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3258 - accuracy: 0.8981
# Epoch 144/150
# 220/220 [==============================] - 2s 11ms/step - loss: 0.3245 - accuracy: 0.8946
# Epoch 145/150
# 220/220 [==============================] - 3s 14ms/step - loss: 0.3288 - accuracy: 0.8951
# Epoch 146/150
# 220/220 [==============================] - 3s 12ms/step - loss: 0.3230 - accuracy: 0.8972
# Epoch 147/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3340 - accuracy: 0.8954
# Epoch 148/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3238 - accuracy: 0.8976
# Epoch 149/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3182 - accuracy: 0.9015
# Epoch 150/150
# 220/220 [==============================] - 2s 10ms/step - loss: 0.3186 - accuracy: 0.8949

# %%
model4.save('/content/gdrive/MyDrive/DSLSC/Models_1/Model4_5.h5')

# %% [markdown]
# ## Testing

# %% [markdown]
# Finally, we load our models in order to evaluate them on the test-set.

# %% [markdown]
# ### Model 0

# %%
model0 = load_model('/content/gdrive/MyDrive/DSLSC/Models_1/Model0_5.h5')

# %%
y_pred = model0.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 36/36 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.74      0.84        73
#            1       0.93      0.85      0.89        78
#            2       0.91      0.74      0.82        94
#            3       0.68      0.82      0.75        57
#            4       0.52      0.60      0.56        53
#            5       0.54      0.64      0.59        72
#            6       0.89      0.75      0.82       106
#            7       0.65      0.72      0.69       115
#            8       0.67      0.60      0.63       110
#            9       0.82      0.88      0.85       127
#           10       0.73      0.79      0.76       122
#           11       0.77      0.82      0.79       120
#
#     accuracy                           0.75      1127
#    macro avg       0.76      0.75      0.75      1127
# weighted avg       0.77      0.75      0.76      1127

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.906832298136646
# 0.9511978704525288

# %% [markdown]
# ### Model 1

# %%
model1 = load_model('/content/gdrive/MyDrive/DSLSC/Models_1/Model1_5.h5')

# %%
y_pred = model1.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 36/36 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93        73
#            1       0.90      0.95      0.92        78
#            2       0.86      0.91      0.89        94
#            3       0.72      0.88      0.79        57
#            4       0.90      0.51      0.65        53
#            5       0.75      0.72      0.74        72
#            6       0.87      0.92      0.89       106
#            7       0.69      0.77      0.73       115
#            8       0.73      0.85      0.78       110
#            9       0.95      0.84      0.89       127
#           10       0.84      0.77      0.80       122
#           11       0.87      0.86      0.86       120
#
#     accuracy                           0.83      1127
#    macro avg       0.84      0.82      0.82      1127
# weighted avg       0.84      0.83      0.83      1127

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.9210292812777284
# 0.9529724933451642

# %% [markdown]
# ### Model 2

# %%
model2 = load_model('/content/gdrive/MyDrive/DSLSC/Models_1/Model2_5.h5')

# %%
y_pred = model2.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 36/36 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        73
#            1       0.88      0.96      0.92        78
#            2       0.86      0.93      0.89        94
#            3       0.91      0.89      0.90        57
#            4       0.79      0.70      0.74        53
#            5       0.75      0.72      0.74        72
#            6       0.98      0.90      0.94       106
#            7       0.87      0.81      0.84       115
#            8       0.85      0.68      0.76       110
#            9       0.92      0.94      0.93       127
#           10       0.81      0.84      0.83       122
#           11       0.74      0.90      0.82       120
#
#     accuracy                           0.86      1127
#    macro avg       0.86      0.85      0.85      1127
# weighted avg       0.86      0.86      0.86      1127

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.9370008873114463
# 0.9627329192546584

# %% [markdown]
# ### Model 3

# %%
model3 = load_model('/content/gdrive/MyDrive/DSLSC/Models_1/Model3_5.h5')

# %%
y_pred = model3.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 36/36 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97        73
#            1       0.94      0.97      0.96        78
#            2       0.92      0.88      0.90        94
#            3       0.91      0.93      0.92        57
#            4       0.75      0.72      0.73        53
#            5       0.76      0.71      0.73        72
#            6       0.94      0.90      0.92       106
#            7       0.84      0.79      0.82       115
#            8       0.81      0.79      0.80       110
#            9       0.89      0.96      0.92       127
#           10       0.82      0.87      0.84       122
#           11       0.84      0.88      0.86       120
#
#     accuracy                           0.87      1127
#    macro avg       0.87      0.86      0.86      1127
# weighted avg       0.87      0.87      0.87      1127

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.940550133096717
# 0.9671694764862466

# %% [markdown]
# ### Model 4

# %%
model4 = load_model('/content/gdrive/MyDrive/DSLSC/Models_1/Model4_5.h5')

# %%
y_pred = model4.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 36/36 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96        73
#            1       0.95      0.92      0.94        78
#            2       0.86      0.93      0.89        94
#            3       0.94      0.89      0.92        57
#            4       0.84      0.60      0.70        53
#            5       0.72      0.74      0.73        72
#            6       0.96      0.93      0.95       106
#            7       0.85      0.81      0.83       115
#            8       0.83      0.83      0.83       110
#            9       0.92      0.95      0.94       127
#           10       0.83      0.87      0.85       122
#           11       0.83      0.87      0.85       120
#
#     accuracy                           0.87      1127
#    macro avg       0.87      0.86      0.86      1127
# weighted avg       0.87      0.87      0.87      1127

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.9370008873114463
# 0.9609582963620231
