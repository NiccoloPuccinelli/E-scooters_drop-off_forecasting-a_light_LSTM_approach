# %% [markdown]
# # Preliminary operations

# %% [markdown]
# We import the libraries and the drive environment.

# %%
# !pip install folium
# !pip install geopandas
# !pip install keras-tuner --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.8 MB/s eta 0:00:00
# Collecting fiona>=1.8.19 (from geopandas)
#   Downloading Fiona-1.9.4.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 75.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Collecting pyproj>=3.0.1 (from geopandas)
#   Downloading pyproj-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 101.6 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Collecting click-plugins>=1.0 (from fiona>=1.8.19->geopandas)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.19->geopandas)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.22.4)
# Installing collected packages: pyproj, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 geopandas-0.13.2 pyproj-3.5.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.27.1)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %%
# Utility
from google.colab import drive
import pandas as pd
import numpy as np
from shutil import copyfile, copy
import datetime
import urllib.request
import os
import json
import matplotlib.pyplot as plt

# Geo
import folium
import geopandas as gpd

# Scikit-learn
from sklearn.metrics import classification_report, confusion_matrix, top_k_accuracy_score
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# Keras
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Input, Dropout
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import regularizers
import keras_tuner
from kerastuner.tuners import RandomSearch, GridSearch

seq_len = 10
n_feats = 5
# Out:
# <ipython-input-2-2f46aed8cb2d>:29: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch, GridSearch

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Loading data

# %%
df = pd.read_csv('/content/gdrive/MyDrive/DSLSC/motoscooter_movimento_new.csv')

# %%
df.columns
# Out:
# Index(['provider_id', 'lat', 'lng', 'created_at', 'distance', 'placename',
#        'placelat', 'placelon', 'lat&lng', 'prevObservation', 'nextObservation',
#        'nextCreated_at', 'nextDistance', 'nextTimeDiff', 'prevCreated_at',
#        'prevDistance', 'prevTimeDiff', 'samePlace', 'type'],
#       dtype='object')

# %%
df['created_at'] =  pd.to_datetime(df['created_at'], format = '%Y%m%d %H:%M:%S')
df['nextCreated_at'] =  pd.to_datetime(df['nextCreated_at'], format = '%Y%m%d %H:%M:%S')
df['prevCreated_at'] =  pd.to_datetime(df['prevCreated_at'], format = '%Y%m%d %H:%M:%S')
# Remove waiting long e-scooters
df = df[df['type'] != 'waiting long']

# %% [markdown]
# Now we order the dataframe by provider and we order each provider by time. This way, we will have sequences of consecutive pick-up/drop-off synchronized for each provider_id.

# %%
groups = df.groupby('provider_id')
ordered_df = []
for name, group in groups:
  ordered_df.append((pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True))

# %%
combined_df = pd.concat(ordered_df)

# %%
combined_df
# Out:
#     provider_id      lat      lng          created_at    distance  placename  \
# 0           2.0  45.4599  9.20633 2019-12-06 01:25:20  143.437209      356.0
# 1           2.0  45.4622  9.19374 2019-12-06 01:40:22  214.500848      354.0
# 2           2.0  45.4621  9.19375 2019-12-06 18:40:20  205.745441      354.0
# 3           2.0  45.4411  9.18597 2019-12-06 19:40:24   95.513288      204.0
# 4           2.0  45.4411  9.18597 2019-12-06 20:10:24   95.513288      204.0
# ..          ...      ...      ...                 ...         ...        ...
# 41       1754.0  45.4567  9.14835 2019-12-07 06:55:08   73.915845      307.0
# 42       1754.0  45.4567  9.14835 2019-12-07 18:55:14   73.915845      307.0
# 43       1754.0  45.4565  9.14819 2019-12-07 19:10:08   57.395490      307.0
# 44       1754.0  45.4565  9.14819 2019-12-08 14:25:08   57.395490      307.0
# 45       1754.0  45.4567  9.14828 2019-12-08 14:40:08   75.265120      307.0
#
#     placelat  placelon             lat&lng     prevObservation  \
# 0   45.46075   9.20495  (45.4599, 9.20633)                 NaN
# 1   45.46075   9.19555  (45.4622, 9.19374)  (45.4599, 9.20633)
# 2   45.46075   9.19555  (45.4621, 9.19375)  (45.4621, 9.19375)
# 3   45.44195   9.18615  (45.4411, 9.18597)  (45.4621, 9.19375)
# 4   45.44195   9.18615  (45.4411, 9.18597)  (45.4411, 9.18597)
# ..       ...       ...                 ...                 ...
# 41  45.45605   9.14855  (45.4567, 9.14835)  (45.4566, 9.14827)
# 42  45.45605   9.14855  (45.4567, 9.14835)  (45.4567, 9.14835)
# 43  45.45605   9.14855  (45.4565, 9.14819)  (45.4567, 9.14835)
# 44  45.45605   9.14855  (45.4565, 9.14819)  (45.4565, 9.14819)
# 45  45.45605   9.14855  (45.4567, 9.14828)  (45.4565, 9.14819)
#
#        nextObservation      nextCreated_at  nextDistance  nextTimeDiff  \
# 0   (45.4622, 9.19374) 2019-12-06 01:40:22   1017.327131     15.033333
# 1   (45.4621, 9.19375) 2019-12-06 01:55:23     11.141565     15.016667
# 2   (45.4411, 9.18597) 2019-12-06 19:40:24   2411.994485     60.066667
# 3   (45.4411, 9.18597) 2019-12-06 19:55:25      0.000000     15.016667
# 4   (45.4721, 9.18426) 2019-12-06 20:55:22   3447.956963     44.966667
# ..                 ...                 ...           ...           ...
# 41  (45.4567, 9.14835) 2019-12-07 07:10:09      0.000000     15.016667
# 42  (45.4565, 9.14819) 2019-12-07 19:10:08     25.509056     14.900000
# 43  (45.4565, 9.14819) 2019-12-07 19:25:09      0.000000     15.016667
# 44  (45.4567, 9.14828) 2019-12-08 14:40:08     23.316224     15.000000
# 45  (45.4567, 9.14832) 2019-12-08 14:55:10      3.128709     15.033333
#
#         prevCreated_at  prevDistance  prevTimeDiff  samePlace  \
# 0                  NaT      0.000000      0.000000        0.0
# 1  2019-12-06 01:25:20   1017.327131     15.033333        0.0
# 2  2019-12-06 18:25:21      0.000000     14.983333        0.0
# 3  2019-12-06 18:40:20   2411.994485     60.066667        0.0
# 4  2019-12-06 19:55:25      0.000000     14.983333        0.0
# ..                 ...           ...           ...        ...
# 41 2019-12-07 06:25:08     12.754525     30.000000        0.0
# 42 2019-12-07 18:40:08      0.000000     15.100000        0.0
# 43 2019-12-07 18:55:14     25.509056     14.900000        0.0
# 44 2019-12-08 14:10:10      0.000000     14.966667        0.0
# 45 2019-12-08 14:25:08     23.316224     15.000000        0.0
#
#                     type
# 0   first seen / pick-up
# 1               drop-off
# 2        pick-up outlier
# 3       drop-off outlier
# 4                pick-up
# ..                   ...
# 41              drop-off
# 42               pick-up
# 43              drop-off
# 44               pick-up
# 45              drop-off
#
# [81568 rows x 19 columns]

# %% [markdown]
# The sorting done above allows us to correctly associate, for each sample, the pick-up points with the drop-off points.

# %%
pickup = ['first seen / pick-up', 'pick-up', 'pick-up outlier']
dropoff = ['last seen / drop-off', 'drop-off', 'drop-off outlier']
# Create 2 different dataframes: one for pick-up and one for drop-off
df_p = combined_df[combined_df['type'].isin(pickup)]
df_d = combined_df[combined_df['type'].isin(dropoff)]

# %% [markdown]
# The 2 dataframes are ordered by provider_id and each provider_id is ordered by time. They are syncrhonized, so that for example the first row is both the pick-up point and the drop-off point of the same scooter, in respectively df_p and df_d.

# %%
df_p = df_p[['provider_id', 'created_at', 'placename', 'placelon', 'placelat']].reset_index(drop = True)
df_d = df_d[['created_at', 'placename', 'placelon', 'placelat']].reset_index(drop = True)
# The placename and the coordinates of the drop-off observation are our target
df_p['target'] = df_d['placename']
df_p['target_lon'] = df_d['placelon']
df_p['target_lat'] = df_d['placelat']
df = df_p.copy()

# %% [markdown]
# We also may create a variable indicating if it's saturday or sunday.

# %%
df['is_weekend'] = df['created_at'].apply(lambda x: 1 if x.weekday() >= 5 else 0)

# %%
df
# Out:
#        provider_id          created_at  placename  placelon  placelat  target  \
# 0              2.0 2019-12-06 01:25:20      356.0   9.20495  45.46075   354.0
# 1              2.0 2019-12-06 18:40:20      354.0   9.19555  45.46075   204.0
# 2              2.0 2019-12-06 20:10:24      204.0   9.18615  45.44195   426.0
# 3              2.0 2019-12-07 00:25:20      426.0   9.18615  45.47015   503.0
# 4              2.0 2019-12-07 08:40:16      503.0   9.20025  45.47955   503.0
# ...            ...                 ...        ...       ...       ...     ...
# 40779       1754.0 2019-12-07 01:55:08      307.0   9.14855  45.45605   307.0
# 40780       1754.0 2019-12-07 02:40:09      307.0   9.14855  45.45605   307.0
# 40781       1754.0 2019-12-07 06:25:08      307.0   9.14855  45.45605   307.0
# 40782       1754.0 2019-12-07 18:55:14      307.0   9.14855  45.45605   307.0
# 40783       1754.0 2019-12-08 14:25:08      307.0   9.14855  45.45605   307.0
#
#        target_lon  target_lat  is_weekend
# 0         9.19555    45.46075           0
# 1         9.18615    45.44195           0
# 2         9.18615    45.47015           0
# 3         9.20025    45.47955           1
# 4         9.20025    45.47955           1
# ...           ...         ...         ...
# 40779     9.14855    45.45605           1
# 40780     9.14855    45.45605           1
# 40781     9.14855    45.45605           1
# 40782     9.14855    45.45605           1
# 40783     9.14855    45.45605           1
#
# [40784 rows x 9 columns]

# %% [markdown]
# # Zone prediction \#2 (10 e-scooters)

# %% [markdown]
# The goal of this task is to build a prediction model in order to know in advance the drop-off zone of a sequence of scooters (with probability attached). Here we perform a classification task on all the Milan NIL, i.e. with a higher level of granularity.

# %% [markdown]
# ## Pre-processing

# %%
gdf = gpd.GeoDataFrame(df, crs = 'EPSG:4326', geometry = gpd.points_from_xy(df.placelon, df.placelat))

# %%
milan_nil = gpd.read_file("/content/gdrive/MyDrive/DSLSC/NIL_E0.zip")

# %%
# Ensuring the crs is the same
if gdf.crs != milan_nil.crs:
  milan_nil = milan_nil.to_crs(gdf.crs)

# %%
# Spatial join between the zones and scooters GeoDataFrames
zones_with_scooters_gdf = gpd.sjoin(milan_nil, gdf, predicate = 'contains')
# Group the GeoDataFrame by zone ID and count the number of scooters in each zone
scooter_counts_by_zone = zones_with_scooters_gdf.groupby('NIL').size()
# Get the IDs of the zones with scooters
zones_with_scooters_ids = scooter_counts_by_zone.index
# Filter the zones GeoDataFrame in order to remove the zones without scooters
zones_gdf = milan_nil[milan_nil['NIL'].isin(zones_with_scooters_ids)]
zones_gdf = zones_gdf.reset_index(drop = True)

# %%
city = zones_gdf.copy()
city['newNIL'] = zones_gdf['NIL']
for i in range(len(city)):
  if(city['NIL'][i] == 'BOVISA'):
    city['NIL'][i] = 'FARINI'
    city['newNIL'][i] = 'FARINI'
  elif(city['NIL'][i] == 'CITTA\' STUDI'):
    city['NIL'][i] = 'BUENOS AIRES - VENEZIA'
    city['newNIL'][i] = 'BUENOS AIRES - VENEZIA'
  elif(city['NIL'][i] == 'GIARDINI PORTA VENEZIA'):
    city['NIL'][i] = 'GUASTALLA'
    city['newNIL'][i] = 'GUASTALLA'
  elif(city['NIL'][i] == 'QT 8'):
    city['NIL'][i] = 'VILLAPIZZONE - S. SIRO'
    city['newNIL'][i] = 'VILLAPIZZONE - S. SIRO'
  elif(city['NIL'][i] == 'S. SIRO'):
    city['NIL'][i] = 'VILLAPIZZONE - S. SIRO'
    city['newNIL'][i] = 'VILLAPIZZONE - S. SIRO'
  elif(city['NIL'][i] == 'VILLAPIZZONE'):
    city['NIL'][i] = 'VILLAPIZZONE - S. SIRO'
    city['newNIL'][i] = 'VILLAPIZZONE - S. SIRO'
city = city.to_crs(epsg = 4326).dissolve(by = 'newNIL')
# Out:
# <ipython-input-19-7f105467482f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['NIL'][i] = 'VILLAPIZZONE - S. SIRO'
# <ipython-input-19-7f105467482f>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['newNIL'][i] = 'VILLAPIZZONE - S. SIRO'
# <ipython-input-19-7f105467482f>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['NIL'][i] = 'VILLAPIZZONE - S. SIRO'
# <ipython-input-19-7f105467482f>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['newNIL'][i] = 'VILLAPIZZONE - S. SIRO'
# <ipython-input-19-7f105467482f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['NIL'][i] = 'BUENOS AIRES - VENEZIA'
# <ipython-input-19-7f105467482f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['newNIL'][i] = 'BUENOS AIRES - VENEZIA'
# <ipython-input-19-7f105467482f>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['NIL'][i] = 'VILLAPIZZONE - S. SIRO'
# <ipython-input-19-7f105467482f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['newNIL'][i] = 'VILLAPIZZONE - S. SIRO'
# <ipython-input-19-7f105467482f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['NIL'][i] = 'FARINI'
# <ipython-input-19-7f105467482f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['newNIL'][i] = 'FARINI'
# <ipython-input-19-7f105467482f>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['NIL'][i] = 'GUASTALLA'
# <ipython-input-19-7f105467482f>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['newNIL'][i] = 'GUASTALLA'

# %%
# Plot the quarters polygons
ax = city.plot(edgecolor = 'k', facecolor = 'none', figsize = (15, 10))
gdf.plot(ax = ax, color = "blue")
ax.set_title('E-scooter positions within Milan NILs\n')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Loop over the quarters polygons and add the name as text
for idx, row in city.iterrows():
  ax.annotate(text = row['NIL'], xy = row['geometry'].centroid.coords[0], ha = 'center', fontsize = 8)

# Set the axis limits
ax.set_xlim(9.105, 9.24)
ax.set_ylim(45.425, 45.515)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()

plt.savefig('Milan NILs.png', bbox_inches = 'tight', dpi = 300)

# %%
zones_with_scooters_gdf.reset_index(drop = True, inplace = True)

# %%
zones_with_scooters_gdf['NIL'].unique()
# Out:
# array(['QT 8', 'S. SIRO', 'GHISOLFA', 'GIAMBELLINO', 'S. CRISTOFORO',
#        'TIBALDI', 'EX OM - MORIVIONE', 'FARINI', 'UMBRIA - MOLISE',
#        "CITTA' STUDI", 'SELINUNTE', 'GUASTALLA', 'BRERA', 'DUOMO',
#        'SCALO ROMANA', 'MAGENTA - S. VITTORE', 'VILLAPIZZONE', 'BOVISA',
#        'DERGANO', 'PORTELLO', 'TRE TORRI', 'PARCO SEMPIONE',
#        'GIARDINI PORTA VENEZIA', 'TORTONA', 'NAVIGLI', 'XXII MARZO',
#        'BUENOS AIRES - VENEZIA', 'CENTRALE', 'GRECO', 'LORETO',
#        'MACIACHINI - MAGGIOLINA', 'ISOLA', 'SARPI',
#        'DE ANGELI - MONTE ROSA', 'WASHINGTON', 'BANDE NERE',
#        'PORTA ROMANA', 'VIGENTINA', 'TICINESE', 'PAGANO',
#        'GARIBALDI REPUBBLICA'], dtype=object)

# %%
keyList = list(zones_with_scooters_gdf['NIL'].unique())
place_dict = {key: [] for key in keyList}
for i in range(0, len(zones_with_scooters_gdf)):
  if not isinstance(zones_with_scooters_gdf['placename'][i], str):
    place_dict[zones_with_scooters_gdf['NIL'][i]].append(zones_with_scooters_gdf['placename'][i])

# %%
for key, value in place_dict.items():
  value = list(set(value))
  place_dict[key] = value

# %%
for i in range(0, len(df)):
  for key, value in place_dict.items():
    if df['target'][i] in value:
      df['target'][i] = key
      break
# Out:
# <ipython-input-25-b555a8282ce4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][i] = key

# %%
df = df[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend', 'target']].reset_index(drop = True)

# %%
df
# Out:
#        provider_id          created_at  placelon  placelat  is_weekend  \
# 0              2.0 2019-12-06 01:25:20   9.20495  45.46075           0
# 1              2.0 2019-12-06 18:40:20   9.19555  45.46075           0
# 2              2.0 2019-12-06 20:10:24   9.18615  45.44195           0
# 3              2.0 2019-12-07 00:25:20   9.18615  45.47015           1
# 4              2.0 2019-12-07 08:40:16   9.20025  45.47955           1
# ...            ...                 ...       ...       ...         ...
# 40779       1754.0 2019-12-07 01:55:08   9.14855  45.45605           1
# 40780       1754.0 2019-12-07 02:40:09   9.14855  45.45605           1
# 40781       1754.0 2019-12-07 06:25:08   9.14855  45.45605           1
# 40782       1754.0 2019-12-07 18:55:14   9.14855  45.45605           1
# 40783       1754.0 2019-12-08 14:25:08   9.14855  45.45605           1
#
#            target
# 0           DUOMO
# 1         TIBALDI
# 2           BRERA
# 3        CENTRALE
# 4        CENTRALE
# ...           ...
# 40779  BANDE NERE
# 40780  BANDE NERE
# 40781  BANDE NERE
# 40782  BANDE NERE
# 40783  BANDE NERE
#
# [40784 rows x 6 columns]

# %% [markdown]
# Let's check the zones with few e-scooters and aggregate them to the nearest zone.

# %%
groups = df.groupby('target')
for name, group in groups:
  if(len(group) < 100):
    print(name)
# Out:
# BOVISA
# CITTA' STUDI
# GIARDINI PORTA VENEZIA
# QT 8

# %%
for i in range(len(df)):
  if(df['target'][i] == 'BOVISA'):
    df['target'][i] = 'FARINI'
  elif(df['target'][i] == 'CITTA\' STUDI'):
    df['target'][i] = 'BUENOS AIRES - VENEZIA'
  elif(df['target'][i] == 'GIARDINI PORTA VENEZIA'):
    df['target'][i] = 'GUASTALLA'
  elif(df['target'][i] == 'QT 8'):
    df['target'][i] = 'VILLAPIZZONE'
# Out:
# <ipython-input-29-0e99215fbd33>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][i] = 'GUASTALLA'
# <ipython-input-29-0e99215fbd33>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][i] = 'VILLAPIZZONE'
# <ipython-input-29-0e99215fbd33>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][i] = 'FARINI'
# <ipython-input-29-0e99215fbd33>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][i] = 'BUENOS AIRES - VENEZIA'

# %%
# We discard samples in a way that there are only multiple of seq_len
ordered_df = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len == 0):
    ordered_df.append(df_)
  else:
    df_ = df_[:-((len(df_))%seq_len)]
    ordered_df.append(df_)

# %%
combined_df = pd.concat(ordered_df)

# %%
combined_df
# Out:
#       provider_id          created_at  placelon  placelat  is_weekend  \
# 0          1342.0 2019-12-02 00:10:11   9.13915  45.46545           0
# 1          1285.0 2019-12-02 00:25:11   9.13915  45.46545           0
# 2          1342.0 2019-12-02 00:40:09   9.13915  45.46545           0
# 3          1373.0 2019-12-02 00:40:09   9.14385  45.46545           0
# 4          1098.0 2019-12-02 00:40:09   9.14385  45.46545           0
# ...           ...                 ...       ...       ...         ...
# 1495       1246.0 2019-12-08 23:25:10   9.21435  45.45605           1
# 1496       1395.0 2019-12-08 23:25:10   9.21905  45.45605           1
# 1497       1066.0 2019-12-08 23:25:11   9.22375  45.46075           1
# 1498       1070.0 2019-12-08 23:25:11   9.21435  45.46545           1
# 1499       1262.0 2019-12-08 23:25:13   9.20965  45.46075           1
#
#           target
# 0     BANDE NERE
# 1     BANDE NERE
# 2     BANDE NERE
# 3     BANDE NERE
# 4     BANDE NERE
# ...          ...
# 1495  XXII MARZO
# 1496  XXII MARZO
# 1497  XXII MARZO
# 1498  XXII MARZO
# 1499  XXII MARZO
#
# [40630 rows x 6 columns]

# %%
df = combined_df.reset_index(drop = True)

# %% [markdown]
# ## Preparation

# %%
encoder_id = LabelEncoder()
df['provider_id'] = encoder_id.fit_transform(df['provider_id'])

# %%
encoder_target = LabelEncoder()
df['target'] = encoder_id.fit_transform(df['target'])

# %%
# Converting datetime in unixtime (int)
dates = pd.to_datetime(df['created_at'])
df['created_at'] = dates.astype(int) // 10**9
min_time = min(df['created_at'])
df['created_at'] = df['created_at'] - min_time
#df['created_at'] = df['created_at'] % 86400

# %%
# Test-set = monday
test = df[df['created_at'] < 1575331200 - min_time]
train = df.drop(test.index)
test.reset_index(drop = True, inplace = True)
train.reset_index(drop = True, inplace = True)

# %%
max_test = max(test['created_at'])
train['created_at'] = train['created_at'] - max_test
max_train = max(train['created_at'])
test['created_at'] = test['created_at'] + max_train

# %%
train_test_ordered = pd.concat([train, test], ignore_index = True)

# %%
scaler_0 = MinMaxScaler()
scaler_1 = MinMaxScaler()
scaler_2 = MinMaxScaler()
scaler_3 = MinMaxScaler()

df['provider_id'] = scaler_0.fit_transform(np.array(df['provider_id']).reshape(-1, 1))
train_test_ordered['created_at'] = scaler_1.fit_transform(np.array(train_test_ordered['created_at']).reshape(-1, 1))

train['provider_id'] = scaler_0.transform(np.array(train['provider_id']).reshape(-1, 1))
train['created_at'] = scaler_1.transform(np.array(train['created_at']).reshape(-1, 1))
train['placelon'] = scaler_2.fit_transform(np.array(train['placelon']).reshape(-1, 1))
train['placelat'] = scaler_3.fit_transform(np.array(train['placelat']).reshape(-1, 1))

test['provider_id'] = scaler_0.transform(np.array(test['provider_id']).reshape(-1, 1))
test['created_at'] = scaler_1.transform(np.array(test['created_at']).reshape(-1, 1))
test['placelon'] = scaler_2.transform(np.array(test['placelon']).reshape(-1, 1))
test['placelat'] = scaler_3.transform(np.array(test['placelat']).reshape(-1, 1))

# %% [markdown]
# Now we create the validation set, selecting the last 10% of each target. Moreover, we save the array with training + validation for further retraining.

# %%
X = train.copy(deep = True)

# %%
val = pd.DataFrame(columns = train.columns)

for i in range(0, 36):
  to_pick = int((len(train[train['target'] == i]))*0.1)
  rows = train[train['target'] == i].tail(to_pick)
  train = train.drop(rows.index)
  val = pd.concat([val, rows], ignore_index = True)

train.reset_index(drop = True, inplace = True)

# %%
# Now we have to fix the lengths of train, val and test, in the same way as before
groups = train.groupby('target')
ordered_df_train = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_train.append(df_)

groups = val.groupby('target')
ordered_df_val = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_val.append(df_)
    
groups = test.groupby('target')
ordered_df_test = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_test.append(df_)

# Training + validation
groups = X.groupby('target')
ordered_df_X = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_X.append(df_)

# %%
train = pd.concat(ordered_df_train).reset_index(drop = True)
val = pd.concat(ordered_df_val).reset_index(drop = True)
test = pd.concat(ordered_df_test).reset_index(drop = True)
X = pd.concat(ordered_df_X).reset_index(drop = True)

# %%
train
# Out:
#        provider_id  created_at  placelon  placelat  is_weekend  target
# 0         0.851852    0.000000  0.000000  0.384615           0       0
# 1         0.702862    0.000000  0.000000  0.384615           0       0
# 2         0.684343    0.000000  0.111111  0.307692           0       0
# 3         0.515993    0.000000  0.000000  0.384615           0       0
# 4         0.702862    0.001495  0.000000  0.384615           0       0
# ...            ...         ...       ...       ...         ...     ...
# 31315     0.676768    0.769751  0.944444  0.769231           1      35
# 31316     0.585017    0.771243  0.888889  0.230769           1      35
# 31317     0.597643    0.771248  0.888889  0.076923           1      35
# 31318     0.993266    0.771248  0.833333  0.384615           1      35
# 31319     0.511785    0.772729  0.111111  0.307692           1      35
#
# [31320 rows x 6 columns]

# %%
val
# Out:
#       provider_id  created_at  placelon  placelat is_weekend target
# 0        0.791246    0.759279  0.000000  0.307692          1      0
# 1        0.511785    0.759279  0.111111  0.307692          1      0
# 2        0.826599    0.759279  0.000000  0.384615          1      0
# 3        0.766835    0.760773  0.111111  0.307692          1      0
# 4        0.671717    0.765256  0.111111  0.230769          1      0
# ...           ...         ...       ...       ...        ...    ...
# 3315     0.706229    0.853448  0.888889  0.230769          1     35
# 3316     0.535354    0.853452  0.833333  0.307692          1     35
# 3317     0.706229    0.856433  0.888889  0.230769          1     35
# 3318     0.797138    0.856433  0.944444  0.230769          1     35
# 3319     0.601010    0.856434  0.888889  0.384615          1     35
#
# [3320 rows x 6 columns]

# %%
test
# Out:
#       provider_id  created_at  placelon  placelat  is_weekend  target
# 0        0.765152    0.857965  0.000000  0.384615           0       0
# 1        0.730640    0.859460  0.000000  0.384615           0       0
# 2        0.765152    0.860951  0.000000  0.384615           0       0
# 3        0.785354    0.860951  0.055556  0.384615           0       0
# 4        0.619529    0.860951  0.055556  0.384615           0       0
# ...           ...         ...       ...       ...         ...     ...
# 5475     0.717172    0.996976  0.777778  0.538462           0      35
# 5476     0.521886    0.998467  0.888889  0.384615           0      35
# 5477     0.780303    0.999965  0.888889  0.384615           0      35
# 5478     0.737374    0.999965  0.833333  0.384615           0      35
# 5479     0.690236    0.999965  0.833333  0.384615           0      35
#
# [5480 rows x 6 columns]

# %%
X
# Out:
#        provider_id  created_at  placelon  placelat  is_weekend  target
# 0         0.851852    0.000000  0.000000  0.384615           0       0
# 1         0.702862    0.000000  0.000000  0.384615           0       0
# 2         0.684343    0.000000  0.111111  0.307692           0       0
# 3         0.515993    0.000000  0.000000  0.384615           0       0
# 4         0.702862    0.001495  0.000000  0.384615           0       0
# ...            ...         ...       ...       ...         ...     ...
# 34805     0.797138    0.851950  0.888889  0.230769           1      35
# 34806     0.671717    0.851950  0.888889  0.384615           1      35
# 34807     0.004209    0.851954  0.833333  0.307692           1      35
# 34808     0.716330    0.851955  0.777778  0.153846           1      35
# 34809     0.671717    0.853447  0.888889  0.384615           1      35
#
# [34810 rows x 6 columns]

# %%
X_train = np.array((train[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)
y_train = np.array((train['target'])).reshape(-1, seq_len)

X_val = np.array((val[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)
y_val = np.array((val['target'])).reshape(-1, seq_len)

X_test = np.array((test[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)
y_test = np.array((test['target'])).reshape(-1, seq_len)

y = np.array((X['target'])).reshape(-1, seq_len)
X = np.array((X[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)

# %%
y_train = to_categorical(y_train)[:, 0, :]
y_val = to_categorical(y_val)[:, 0, :]
y_test = to_categorical(y_test)[:, 0, :]
y = to_categorical(y)[:, 0, :]

# %%
X_val = np.asarray(X_val).astype('float32')
y_val = np.asarray(y_val).astype('float32')

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
print(X.shape)
print(y.shape)
# Out:
# (3132, 10, 5)
# (3132, 36)
# (332, 10, 5)
# (332, 36)
# (548, 10, 5)
# (548, 36)
# (3481, 10, 5)
# (3481, 36)

# %% [markdown]
# ## Model selection

# %% [markdown]
# We use a RNN LSTM for this task. In this section we start from a basic network and select the best model iteratively.

# %% [markdown]
# ### Model 0

# %%
model0 = Sequential()
model0.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True))
model0.add(LSTM(32, return_sequences = False))
model0.add(Dense(32))
model0.add(Dense(36, activation = 'softmax'))
model0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 16)            1408
#
#  lstm_1 (LSTM)               (None, 32)                6272
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 36)                1188
#
# =================================================================
# Total params: 9,924
# Trainable params: 9,924
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = Adam(learning_rate = 0.0001)
model0.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history0 = model0.fit(X_train, y_train, epochs = 100, batch_size = 16, validation_data = (X_val, y_val))

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history0.history['loss'])
plt.plot(history0.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history0.history['accuracy'])
plt.plot(history0.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model0 = Sequential()
model0.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True))
model0.add(LSTM(32, return_sequences = False))
model0.add(Dense(32))
model0.add(Dense(36, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.0001)
model0.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history0 = model0.fit(X, y, epochs = 100, batch_size = 16)
# Out:
# Epoch 1/100
# 218/218 [==============================] - 12s 33ms/step - loss: 3.5457 - accuracy: 0.0592
# Epoch 2/100
# 218/218 [==============================] - 5s 25ms/step - loss: 3.4225 - accuracy: 0.0750
# Epoch 3/100
# 218/218 [==============================] - 7s 33ms/step - loss: 3.3223 - accuracy: 0.0902
# Epoch 4/100
# 218/218 [==============================] - 5s 25ms/step - loss: 3.1844 - accuracy: 0.1275
# Epoch 5/100
# 218/218 [==============================] - 5s 21ms/step - loss: 2.9532 - accuracy: 0.1658
# Epoch 6/100
# 218/218 [==============================] - 4s 17ms/step - loss: 2.7436 - accuracy: 0.2235
# Epoch 7/100
100
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0058 - accuracy: 0.6777
# Epoch 82/100
# 218/218 [==============================] - 3s 16ms/step - loss: 1.0086 - accuracy: 0.6757
# Epoch 83/100
# 218/218 [==============================] - 4s 19ms/step - loss: 1.0032 - accuracy: 0.6800
# Epoch 84/100
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0015 - accuracy: 0.6751
# Epoch 85/100
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9961 - accuracy: 0.6820
# Epoch 86/100
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9958 - accuracy: 0.6783
# Epoch 87/100
# 218/218 [==============================] - 4s 19ms/step - loss: 0.9940 - accuracy: 0.6771
# Epoch 88/100
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9912 - accuracy: 0.6731
# Epoch 89/100
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9864 - accuracy: 0.6820
# Epoch 90/100
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9844 - accuracy: 0.6828
# Epoch 91/100
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9815 - accuracy: 0.6831
# Epoch 92/100
# 218/218 [==============================] - 4s 19ms/step - loss: 0.9852 - accuracy: 0.6803
# Epoch 93/100
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9785 - accuracy: 0.6794
# Epoch 94/100
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9782 - accuracy: 0.6828
# Epoch 95/100
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9751 - accuracy: 0.6851
# Epoch 96/100
# 218/218 [==============================] - 4s 18ms/step - loss: 0.9744 - accuracy: 0.6820
# Epoch 97/100
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9686 - accuracy: 0.6840
# Epoch 98/100
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9669 - accuracy: 0.6843
# Epoch 99/100
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9648 - accuracy: 0.6880
# Epoch 100/100
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9662 - accuracy: 0.6803

# %%
model0.save('/content/gdrive/MyDrive/DSLSC/Models_2/Model0_10.h5')

# %% [markdown]
# ### Keras tuner \#1

# %%
#!rm -rf /content/best_hyperparams_1

# %% [markdown]
# Now we use the keras tuner in order to find the best units combination.

# %%
# 16 different combinations
def build_model_1(hp):
  model = Sequential()
  model.add(LSTM(units = hp.Int('units_lstm_1', min_value = 16, max_value = 32, step = 16),
                 input_shape = (seq_len, n_feats),
                 return_sequences = True))
  model.add(LSTM(units = hp.Int('units_lstm_2', min_value = 32, max_value = 64, step = 32),
                 return_sequences = False))
  model.add(Dense(units = hp.Int('units_dense', min_value = 32, max_value = 64, step = 32)))
  model.add(Dense(36, activation = 'softmax'))
  
  optimizer = Adam(learning_rate = hp.Choice('learning_rate', values = [0.001, 0.0001]))
  model.compile(optimizer =  optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
tuner_1 = GridSearch(
  build_model_1,
  objective = 'val_loss',
  executions_per_trial = 1,
  directory = '/content',
  project_name = 'best_hyperparams_1'
)

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
# Grid search
tuner_1.search(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
# Retrieve best hyperparameters and final model
best_hp = tuner_1.get_best_hyperparameters()[0]
best_model = tuner_1.hypermodel.build(best_hp)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 10, 16)            1408
#
#  lstm_3 (LSTM)               (None, 32)                6272
#
#  dense_2 (Dense)             (None, 64)                2112
#
#  dense_3 (Dense)             (None, 36)                2340
#
# =================================================================
# Total params: 12,132
# Trainable params: 12,132
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's try this model.

# %% [markdown]
# ### Model 1

# %%
model1 = Sequential()
model1.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True))
model1.add(LSTM(32, return_sequences = False))
model1.add(Dense(64))
model1.add(Dense(36, activation = 'softmax'))
model1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 10, 16)            1408
#
#  lstm_7 (LSTM)               (None, 32)                6272
#
#  dense_6 (Dense)             (None, 64)                2112
#
#  dense_7 (Dense)             (None, 36)                2340
#
# =================================================================
# Total params: 12,132
# Trainable params: 12,132
# Non-trainable params: 0
# _________________________________________________________________

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
optimizer = Adam(learning_rate = 0.001)
model1.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history1 = model1.fit(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model1 = Sequential()
model1.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True))
model1.add(LSTM(32, return_sequences = False))
model1.add(Dense(64))
model1.add(Dense(36, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.001)
model1.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history1 = model1.fit(X, y, epochs = 75, batch_size = 16)
# Out:
# Epoch 1/75
# 218/218 [==============================] - 7s 14ms/step - loss: 2.9080 - accuracy: 0.1666
# Epoch 2/75
# 218/218 [==============================] - 4s 18ms/step - loss: 1.7264 - accuracy: 0.4364
# Epoch 3/75
# 218/218 [==============================] - 4s 17ms/step - loss: 1.4189 - accuracy: 0.5384
# Epoch 4/75
# 218/218 [==============================] - 3s 14ms/step - loss: 1.3009 - accuracy: 0.5814
# Epoch 5/75
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1930 - accuracy: 0.6061
# Epoch 6/75
# 218/218 [==============================] - 3s 16ms/step - loss: 1.1393 - accuracy: 0.6145
# Epoch 7/75
# 218/218 [==============================] - 4s 19ms/step - loss: 1.1236 - accuracy: 0.6280
# Epoch 8/75
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0763 - accuracy: 0.6372
# Epoch 9/75
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0354 - accuracy: 0.6498
# Epoch 10/75
# 218/218 [==============================] - 3s 14ms/step - loss: 1.0197 - accuracy: 0.6498
# Epoch 11/75
# 218/218 [==============================] - 4s 18ms/step - loss: 1.0076 - accuracy: 0.6648
# Epoch 12/75
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9912 - accuracy: 0.6590
# Epoch 13/75
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9789 - accuracy: 0.6630
# Epoch 14/75
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9623 - accuracy: 0.6725
# Epoch 15/75
# 218/218 [==============================] - 3s 16ms/step - loss: 0.9584 - accuracy: 0.6679
# Epoch 16/75
# 218/218 [==============================] - 4s 19ms/step - loss: 0.9479 - accuracy: 0.6725
# Epoch 17/75
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9320 - accuracy: 0.6794
# Epoch 18/75
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9266 - accuracy: 0.6754
# Epoch 19/75
# 218/218 [==============================] - 3s 14ms/step - loss: 0.9015 - accuracy: 0.6886
# Epoch 20/75
# 218/218 [==============================] - 4s 19ms/step - loss: 0.9052 - accuracy: 0.6866
# Epoch 21/75
# 218/218 [==============================] - 6s 27ms/step - loss: 0.8954 - accuracy: 0.6897
# Epoch 22/75
# 218/218 [==============================] - 6s 26ms/step - loss: 0.8852 - accuracy: 0.6903
# Epoch 23/75
# 218/218 [==============================] - 8s 35ms/step - loss: 0.8855 - accuracy: 0.6863
# Epoch 24/75
# 218/218 [==============================] - 5s 24ms/step - loss: 0.8785 - accuracy: 0.6874
# Epoch 25/75
# 218/218 [==============================] - 4s 19ms/step - loss: 0.8699 - accuracy: 0.7024
# Epoch 26/75
# 218/218 [==============================] - 8s 37ms/step - loss: 0.8679 - accuracy: 0.6946
# Epoch 27/75
# 218/218 [==============================] - 6s 29ms/step - loss: 0.8533 - accuracy: 0.7067
# Epoch 28/75
75
# 218/218 [==============================] - 3s 14ms/step - loss: 0.6874 - accuracy: 0.7552
# Epoch 62/75
# 218/218 [==============================] - 4s 17ms/step - loss: 0.6649 - accuracy: 0.7693
# Epoch 63/75
# 218/218 [==============================] - 4s 18ms/step - loss: 0.6583 - accuracy: 0.7673
# Epoch 64/75
# 218/218 [==============================] - 3s 13ms/step - loss: 0.6493 - accuracy: 0.7673
# Epoch 65/75
# 218/218 [==============================] - 3s 14ms/step - loss: 0.6634 - accuracy: 0.7667
# Epoch 66/75
# 218/218 [==============================] - 3s 14ms/step - loss: 0.6256 - accuracy: 0.7785
# Epoch 67/75
# 218/218 [==============================] - 4s 19ms/step - loss: 0.6448 - accuracy: 0.7639
# Epoch 68/75
# 218/218 [==============================] - 3s 15ms/step - loss: 0.6295 - accuracy: 0.7693
# Epoch 69/75
# 218/218 [==============================] - 3s 14ms/step - loss: 0.6299 - accuracy: 0.7719
# Epoch 70/75
# 218/218 [==============================] - 4s 18ms/step - loss: 0.6269 - accuracy: 0.7756
# Epoch 71/75
# 218/218 [==============================] - 4s 17ms/step - loss: 0.6121 - accuracy: 0.7805
# Epoch 72/75
# 218/218 [==============================] - 4s 17ms/step - loss: 0.6052 - accuracy: 0.7840
# Epoch 73/75
# 218/218 [==============================] - 3s 13ms/step - loss: 0.5994 - accuracy: 0.7857
# Epoch 74/75
# 218/218 [==============================] - 3s 14ms/step - loss: 0.6177 - accuracy: 0.7854
# Epoch 75/75
# 218/218 [==============================] - 3s 14ms/step - loss: 0.5936 - accuracy: 0.7897

# %%
model1.save('/content/gdrive/MyDrive/DSLSC/Models_2/Model1_10.h5')

# %% [markdown]
# ### Keras tuner \#2

# %%
#!rm -rf /content/best_hyperparams_2

# %% [markdown]
# Now we use the keras tuner in order to find the best dropout combination.

# %%
# 12 different combinations
def build_model_2(hp):
  model = Sequential()
  model.add(LSTM(units = 16, input_shape = (seq_len, n_feats), return_sequences = True))
  model.add(Dropout(hp.Float('dropout_lstm_1', min_value = 0.0, max_value = 0.2, step = 0.2)))
  model.add(LSTM(units = 32, return_sequences = False))
  model.add(Dropout(hp.Float('dropout_lstm_2', min_value = 0.0, max_value = 0.2, step = 0.2)))
  model.add(Dense(units = 64))
  model.add(Dropout(hp.Float('dropout_dense', min_value = 0.0, max_value = 0.4, step = 0.2)))
  model.add(Dense(36, activation = 'softmax'))
  
  optimizer = Adam(learning_rate = 0.001)
  model.compile(optimizer =  optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
tuner_2 = GridSearch(
  build_model_2,
  objective = 'val_loss',
  executions_per_trial = 1,
  directory = '/content',
  project_name = 'best_hyperparams_2'
)

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
# Grid search
tuner_2.search(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
# Retrieve best hyperparameters and final model
best_hp = tuner_2.get_best_hyperparameters()[0]
best_model = tuner_2.hypermodel.build(best_hp)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 10, 16)            1408
#
#  dropout_3 (Dropout)         (None, 10, 16)            0
#
#  lstm_3 (LSTM)               (None, 32)                6272
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 64)                2112
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 36)                2340
#
# =================================================================
# Total params: 12,132
# Trainable params: 12,132
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's try this model.

# %% [markdown]
# ### Model 2

# %%
model2 = Sequential()
model2.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True))
model2.add(Dropout(0.2))
model2.add(LSTM(32, return_sequences = False))
model2.add(Dropout(0.2))
model2.add(Dense(64))
model2.add(Dropout(0.4))
model2.add(Dense(36, activation = 'softmax'))
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 10, 16)            1408
#
#  dropout_6 (Dropout)         (None, 10, 16)            0
#
#  lstm_5 (LSTM)               (None, 32)                6272
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 64)                2112
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 36)                2340
#
# =================================================================
# Total params: 12,132
# Trainable params: 12,132
# Non-trainable params: 0
# _________________________________________________________________

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
optimizer = Adam(learning_rate = 0.001)
model2.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history2 = model2.fit(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model2 = Sequential()
model2.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True))
model2.add(Dropout(0.2))
model2.add(LSTM(32, return_sequences = False))
model2.add(Dropout(0.2))
model2.add(Dense(64))
model2.add(Dropout(0.4))
model2.add(Dense(36, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.001)
model2.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history2 = model2.fit(X, y, epochs = 175, batch_size = 16)
# Out:
# Epoch 1/175
# 218/218 [==============================] - 19s 28ms/step - loss: 3.2376 - accuracy: 0.1031
# Epoch 2/175
# 218/218 [==============================] - 8s 39ms/step - loss: 2.1893 - accuracy: 0.3085
# Epoch 3/175
# 218/218 [==============================] - 8s 37ms/step - loss: 1.8301 - accuracy: 0.3824
# Epoch 4/175
# 218/218 [==============================] - 10s 47ms/step - loss: 1.6597 - accuracy: 0.4398
# Epoch 5/175
# 218/218 [==============================] - 6s 25ms/step - loss: 1.5270 - accuracy: 0.4829
# Epoch 6/175
# 218/218 [==============================] - 8s 35ms/step - loss: 1.4376 - accuracy: 0.5134
# Epoch 7/175
# 218/218 [==============================] - 8s 37ms/step - loss: 1.3897 - accuracy: 0.5326
# Epoch 8/175
# 218/218 [==============================] - 8s 35ms/step - loss: 1.3383 - accuracy: 0.5366
# Epoch 9/175
# 218/218 [==============================] - 9s 42ms/step - loss: 1.3038 - accuracy: 0.5616
# Epoch 10/175
# 218/218 [==============================] - 7s 31ms/step - loss: 1.2787 - accuracy: 0.5677
# Epoch 11/175
# 218/218 [==============================] - 7s 31ms/step - loss: 1.2557 - accuracy: 0.5697
# Epoch 12/175
# 218/218 [==============================] - 6s 26ms/step - loss: 1.2060 - accuracy: 0.5895
# Epoch 13/175
# 218/218 [==============================] - 4s 20ms/step - loss: 1.1788 - accuracy: 0.6053
# Epoch 14/175
# 218/218 [==============================] - 4s 19ms/step - loss: 1.1770 - accuracy: 0.6047
# Epoch 15/175
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1432 - accuracy: 0.6148
# Epoch 16/175
# 218/218 [==============================] - 3s 14ms/step - loss: 1.1698 - accuracy: 0.6102
# Epoch 17/175
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1344 - accuracy: 0.6165
# Epoch 18/175
# 218/218 [==============================] - 4s 20ms/step - loss: 1.1017 - accuracy: 0.6240
# Epoch 19/175
# 218/218 [==============================] - 3s 15ms/step - loss: 1.1072 - accuracy: 0.6286
# Epoch 20/175
# 218/218 [==============================] - 4s 19ms/step - loss: 1.0953 - accuracy: 0.6280
# Epoch 21/175
# 218/218 [==============================] - 3s 15ms/step - loss: 1.0852 - accuracy: 0.6277
# Epoch 22/175
# 218/218 [==============================] - 4s 20ms/step - loss: 1.0919 - accuracy: 0.6257
# Epoch 23/175
# 218/218 [==============================] - 3s 16ms/step - loss: 1.0707 - accuracy: 0.6423
# Epoch 24/175
# 218/218 [==============================] - 3s 15ms/step - loss: 1.
# 218/218 [==============================] - 3s 15ms/step - loss: 0.4456 - accuracy: 0.8558
# Epoch 174/175
# 218/218 [==============================] - 3s 14ms/step - loss: 0.4255 - accuracy: 0.8558
# Epoch 175/175
# 218/218 [==============================] - 3s 16ms/step - loss: 0.4363 - accuracy: 0.8521

# %%
model2.save('/content/gdrive/MyDrive/DSLSC/Models_2/Model2_10.h5')

# %% [markdown]
# ### Keras tuner \#3

# %%
#!rm -rf /content/best_hyperparams_3

# %% [markdown]
# Now we use the keras tuner in order to find the best regularizers combination.

# %%
# 64 different combinations
def build_model_3(hp):
  model = Sequential()
  model.add(LSTM(units = 16, input_shape = (seq_len, n_feats), return_sequences = True, 
                 kernel_regularizer = regularizers.l2(hp.Choice('kernel_regularizer_lstm_1', values = [0.0, 0.01])),
                 bias_regularizer = regularizers.l2(hp.Choice('bias_regularizer_lstm_1', values = [0.0, 0.01]))))
  model.add(Dropout(0.2))
  model.add(LSTM(units = 32, return_sequences = False,
                 kernel_regularizer = regularizers.l2(hp.Choice('kernel_regularizer_lstm_2', values = [0.0, 0.01])),
                 bias_regularizer = regularizers.l2(hp.Choice('bias_regularizer_lstm_2', values = [0.0, 0.01]))))
  model.add(Dropout(0.2))
  model.add(Dense(units = 64,
                  kernel_regularizer = regularizers.l2(hp.Choice('kernel_regularizer_dense', values = [0.0, 0.01])),
                  bias_regularizer = regularizers.l2(hp.Choice('bias_regularizer_dense', values = [0.0, 0.01]))))
  model.add(Dropout(0.4))
  model.add(Dense(36, activation = 'softmax'))
  
  optimizer = Adam(learning_rate = 0.001)
  model.compile(optimizer =  optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
tuner_3 = GridSearch(
  build_model_3,
  objective = 'val_loss',
  executions_per_trial = 1,
  directory = '/content',
  project_name = 'best_hyperparams_3'
)

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
# Grid search
tuner_3.search(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
# Retrieve best hyperparameters and final model
best_hp = tuner_3.get_best_hyperparameters()[0]
best_model = tuner_3.hypermodel.build(best_hp)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 10, 16)            1408
#
#  dropout_3 (Dropout)         (None, 10, 16)            0
#
#  lstm_3 (LSTM)               (None, 32)                6272
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 64)                2112
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 36)                2340
#
# =================================================================
# Total params: 12,132
# Trainable params: 12,132
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's try this model.

# %% [markdown]
# ### Model 3

# %%
model3 = Sequential()
model3.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True, bias_regularizer = regularizers.l2(0.01)))
model3.add(Dropout(0.2))
model3.add(LSTM(32, return_sequences = False))
model3.add(Dropout(0.2))
model3.add(Dense(64))
model3.add(Dropout(0.4))
model3.add(Dense(36, activation = 'softmax'))
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 10, 16)            1408
#
#  dropout_6 (Dropout)         (None, 10, 16)            0
#
#  lstm_5 (LSTM)               (None, 32)                6272
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 64)                2112
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 36)                2340
#
# =================================================================
# Total params: 12,132
# Trainable params: 12,132
# Non-trainable params: 0
# _________________________________________________________________

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
optimizer = Adam(learning_rate = 0.001)
model3.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history3 = model3.fit(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history3.history['accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model3 = Sequential()
model3.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True, bias_regularizer = regularizers.l2(0.01)))
model3.add(Dropout(0.2))
model3.add(LSTM(32, return_sequences = False))
model3.add(Dropout(0.2))
model3.add(Dense(64))
model3.add(Dropout(0.4))
model3.add(Dense(36, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.001)
model3.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

200
# 218/218 [==============================] - 3s 15ms/step - loss: 0.4325 - accuracy: 0.8555
# Epoch 181/200
# 218/218 [==============================] - 3s 15ms/step - loss: 0.4038 - accuracy: 0.8647
# Epoch 182/200
# 218/218 [==============================] - 4s 17ms/step - loss: 0.4253 - accuracy: 0.8627
# Epoch 183/200
# 218/218 [==============================] - 4s 20ms/step - loss: 0.4191 - accuracy: 0.8567
# Epoch 184/200
# 218/218 [==============================] - 3s 15ms/step - loss: 0.4272 - accuracy: 0.8633
# Epoch 185/200
# 218/218 [==============================] - 3s 15ms/step - loss: 0.4349 - accuracy: 0.8538
# Epoch 186/200
# 218/218 [==============================] - 4s 17ms/step - loss: 0.4147 - accuracy: 0.8630
# Epoch 187/200
# 218/218 [==============================] - 4s 20ms/step - loss: 0.4182 - accuracy: 0.8618
# Epoch 188/200
# 218/218 [==============================] - 3s 15ms/step - loss: 0.4233 - accuracy: 0.8615
# Epoch 189/200
# 218/218 [==============================] - 3s 15ms/step - loss: 0.4290 - accuracy: 0.8552
# Epoch 190/200
# 218/218 [==============================] - 3s 15ms/step - loss: 0.4141 - accuracy: 0.8644
# Epoch 191/200
# 218/218 [==============================] - 4s 20ms/step - loss: 0.3993 - accuracy: 0.8595
# Epoch 192/200
# 218/218 [==============================] - 4s 17ms/step - loss: 0.3822 - accuracy: 0.8730
# Epoch 193/200
# 218/218 [==============================] - 3s 15ms/step - loss: 0.4184 - accuracy: 0.8638
# Epoch 194/200
# 218/218 [==============================] - 3s 15ms/step - loss: 0.3996 - accuracy: 0.8656
# Epoch 195/200
# 218/218 [==============================] - 4s 19ms/step - loss: 0.4073 - accuracy: 0.8633
# Epoch 196/200
# 218/218 [==============================] - 4s 18ms/step - loss: 0.3893 - accuracy: 0.8768
# Epoch 197/200
# 218/218 [==============================] - 3s 16ms/step - loss: 0.3927 - accuracy: 0.8687
# Epoch 198/200
# 218/218 [==============================] - 3s 15ms/step - loss: 0.4036 - accuracy: 0.8621
# Epoch 199/200
# 218/218 [==============================] - 4s 18ms/step - loss: 0.4208 - accuracy: 0.8624
# Epoch 200/200
# 218/218 [==============================] - 4s 19ms/step - loss: 0.4133 - accuracy: 0.8578

# %%
model3.save('/content/gdrive/MyDrive/DSLSC/Models_2/Model3_10.h5')

# %% [markdown]
# ### Model 4

# %% [markdown]
# Now we may try increasing the batch_size to 32.

# %%
model4 = Sequential()
model4.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True, bias_regularizer = regularizers.l2(0.01)))
model4.add(Dropout(0.2))
model4.add(LSTM(32, return_sequences = False))
model4.add(Dropout(0.2))
model4.add(Dense(64))
model4.add(Dropout(0.4))
model4.add(Dense(36, activation = 'softmax'))
model4.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 10, 16)            1408
#
#  dropout_12 (Dropout)        (None, 10, 16)            0
#
#  lstm_9 (LSTM)               (None, 32)                6272
#
#  dropout_13 (Dropout)        (None, 32)                0
#
#  dense_8 (Dense)             (None, 64)                2112
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_9 (Dense)             (None, 36)                2340
#
# =================================================================
# Total params: 12,132
# Trainable params: 12,132
# Non-trainable params: 0
# _________________________________________________________________

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
optimizer = Adam(learning_rate = 0.001)
model4.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history4 = model4.fit(X_train, y_train, epochs = 200, batch_size = 32, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history4.history['accuracy'])
plt.plot(history4.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model4 = Sequential()
model4.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True, bias_regularizer = regularizers.l2(0.01)))
model4.add(Dropout(0.2))
model4.add(LSTM(32, return_sequences = False))
model4.add(Dropout(0.2))
model4.add(Dense(64))
model4.add(Dropout(0.4))
model4.add(Dense(36, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.001)
model4.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history4 = model4.fit(X, y, epochs = 225, batch_size = 32)
# Out:
# Epoch 1/225
# 109/109 [==============================] - 5s 11ms/step - loss: 3.5002 - accuracy: 0.0824
# Epoch 2/225
# 109/109 [==============================] - 1s 12ms/step - loss: 2.9614 - accuracy: 0.1502
# Epoch 3/225
# 109/109 [==============================] - 2s 18ms/step - loss: 2.5392 - accuracy: 0.2347
# Epoch 4/225
# 109/109 [==============================] - 2s 17ms/step - loss: 2.0465 - accuracy: 0.3548
# Epoch 5/225
# 109/109 [==============================] - 2s 15ms/step - loss: 1.8399 - accuracy: 0.4076
# Epoch 6/225
# 109/109 [==============================] - 1s 12ms/step - loss: 1.7267 - accuracy: 0.4413
# Epoch 7/225
# 109/109 [==============================] - 1s 12ms/step - loss: 1.6214 - accuracy: 0.4774
# Epoch 8/225
# 109/109 [==============================] - 1s 12ms/step - loss: 1.5259 - accuracy: 0.4987
# Epoch 9/225
# 109/109 [==============================] - 1s 12ms/step - loss: 1.4801 - accuracy: 0.5119
# Epoch 10/225
# 109/109 [==============================] - 2s 14ms/step - loss: 1.4361 - accuracy: 0.5200
# Epoch 11/225
# 109/109 [==============================] - 2s 16ms/step - loss: 1.3598 - accuracy: 0.5516
# Epoch 12/225
# 109/109 [==============================] - 2s 19ms/step - loss: 1.3306 - accuracy: 0.5527
# Epoch 13/225
# 109/109 [==============================] - 2s 20ms/step - loss: 1.2749 - accuracy: 0.5820
# Epoch 14/225
# 109/109 [==============================] - 2s 17ms/step - loss: 1.2765 - accuracy: 0.5745
# Epoch 15/225
# 109/109 [==============================] - 1s 13ms/step - loss: 1.2572 - accuracy: 0.5829
# Epoch 16/225
# 109/109 [==============================] - 1s 11ms/step - loss: 1.2179 - accuracy: 0.5863
# Epoch 17/225
# 109/109 [==============================] - 1s 12ms/step - loss: 1.2188 - accuracy: 0.5961
# Epoch 18/225
# 109/109 [==============================] - 1s 12ms/step - loss: 1.1829 - accuracy: 0.5998
# Epoch 19/225
# 109/109 [==============================] - 1s 12ms/step - loss: 1.1535 - accuracy: 0.6254
# Epoch 20/225
# 109/109 [==============================] - 1s 12ms/step - loss: 1.1470 - accuracy: 0.6107
# Epoch 21/225
# 109/109 [==============================] - 1s 11ms/step - loss: 1.1289 - accuracy: 0.6260
# Epoch 22/225
# 109/109 [==============================] - 1s 12ms/step - loss: 1.1285 - accuracy: 0.6168
# Epoch 23/225
# 109/109 [==============================] - 2s 17ms/step - loss: 1.1027 - accuracy: 0.6323
# Epoch 24/225
# 109/109 [==============================] - 2s 17ms/step - loss: 1.1095 - accuracy: 0.6317
# Epoch 25/225
# 109/109 [==============================] - 2s 15ms/step - loss: 1.0758 - accuracy: 0.6438
# Epoch 26/225
# 109/109 [==============================] - 1s 12ms/step - loss: 1.0900 - accuracy: 0.6314
225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5922 - accuracy: 0.8055
# Epoch 150/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.6004 - accuracy: 0.7966
# Epoch 151/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5834 - accuracy: 0.7986
# Epoch 152/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5825 - accuracy: 0.8015
# Epoch 153/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5790 - accuracy: 0.8038
# Epoch 154/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5657 - accuracy: 0.7995
# Epoch 155/225
# 109/109 [==============================] - 2s 15ms/step - loss: 0.5580 - accuracy: 0.8127
# Epoch 156/225
# 109/109 [==============================] - 2s 16ms/step - loss: 0.5719 - accuracy: 0.8081
# Epoch 157/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.5471 - accuracy: 0.8182
# Epoch 158/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5604 - accuracy: 0.8075
# Epoch 159/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5674 - accuracy: 0.8058
# Epoch 160/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5480 - accuracy: 0.8144
# Epoch 161/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5470 - accuracy: 0.8024
# Epoch 162/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5634 - accuracy: 0.8072
# Epoch 163/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5487 - accuracy: 0.8136
# Epoch 164/225
# 109/109 [==============================] - 1s 11ms/step - loss: 0.5560 - accuracy: 0.7972
# Epoch 165/225
# 109/109 [==============================] - 1s 13ms/step - loss: 0.5719 - accuracy: 0.8104
# Epoch 166/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.5592 - accuracy: 0.8115
# Epoch 167/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.5344 - accuracy: 0.8184
# Epoch 168/225
# 109/109 [==============================] - 1s 13ms/step - loss: 0.5344 - accuracy: 0.8161
# Epoch 169/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5426 - accuracy: 0.8093
# Epoch 170/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5553 - accuracy: 0.8095
# Epoch 171/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5483 - accuracy: 0.8104
# Epoch 172/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5375 - accuracy: 0.8147
# Epoch 173/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5613 - accuracy: 0.8118
# Epoch 174/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5386 - accuracy: 0.8199
# Epoch 175/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5291 - accuracy: 0.8179
# Epoch 176/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.5490 - accuracy: 0.8098
# Epoch 177/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.5368 - accuracy: 0.8184
# Epoch 178/225
# 109/109 [==============================] - 2s 14ms/step - loss: 0.5448 - accuracy: 0.8199
# Epoch 179/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5363 - accuracy: 0.8115
# Epoch 180/225
# 109/109 [==============================] - 1s 13ms/step - loss: 0.5305 - accuracy: 0.8219
# Epoch 181/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.5021 - accuracy: 0.8251
# Epoch 182/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.5215 - accuracy: 0.8222
# Epoch 183/225
# 109/109 [==============================] - 2s 14ms/step - loss: 0.5162 - accuracy: 0.8253
# Epoch 184/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5270 - accuracy: 0.8213
# Epoch 185/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.5108 - accuracy: 0.8216
# Epoch 186/225
# 109/109 [==============================] - 2s 16ms/step - loss: 0.5331 - accuracy: 0.8173
# Epoch 187/225
# 109/109 [==============================] - 2s 15ms/step - loss: 0.5173 - accuracy: 0.8282
# Epoch 188/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5262 - accuracy: 0.8230
# Epoch 189/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5268 - accuracy: 0.8179
# Epoch 190/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5157 - accuracy: 0.8288
# Epoch 191/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5163 - accuracy: 0.8205
# Epoch 192/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5052 - accuracy: 0.8279
# Epoch 193/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5081 - accuracy: 0.8253
# Epoch 194/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5089 - accuracy: 0.8213
# Epoch 195/225
# 109/109 [==============================] - 2s 15ms/step - loss: 0.5019 - accuracy: 0.8271
# Epoch 196/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.4979 - accuracy: 0.8331
# Epoch 197/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.5175 - accuracy: 0.8196
# Epoch 198/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5282 - accuracy: 0.8199
# Epoch 199/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5069 - accuracy: 0.8334
# Epoch 200/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4989 - accuracy: 0.8314
# Epoch 201/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5412 - accuracy: 0.8153
# Epoch 202/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5018 - accuracy: 0.8291
# Epoch 203/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5066 - accuracy: 0.8259
# Epoch 204/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5079 - accuracy: 0.8253
# Epoch 205/225
# 109/109 [==============================] - 2s 14ms/step - loss: 0.5117 - accuracy: 0.8216
# Epoch 206/225
# 109/109 [==============================] - 2s 16ms/step - loss: 0.4967 - accuracy: 0.8394
# Epoch 207/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.5111 - accuracy: 0.8213
# Epoch 208/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4957 - accuracy: 0.8288
# Epoch 209/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4865 - accuracy: 0.8357
# Epoch 210/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4950 - accuracy: 0.8348
# Epoch 211/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4851 - accuracy: 0.8296
# Epoch 212/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4908 - accuracy: 0.8357
# Epoch 213/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4914 - accuracy: 0.8314
# Epoch 214/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4831 - accuracy: 0.8380
# Epoch 215/225
# 109/109 [==============================] - 2s 14ms/step - loss: 0.4633 - accuracy: 0.8414
# Epoch 216/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.4771 - accuracy: 0.8380
# Epoch 217/225
# 109/109 [==============================] - 2s 17ms/step - loss: 0.4844 - accuracy: 0.8380
# Epoch 218/225
# 109/109 [==============================] - 1s 13ms/step - loss: 0.4993 - accuracy: 0.8348
# Epoch 219/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.5064 - accuracy: 0.8245
# Epoch 220/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4931 - accuracy: 0.8268
# Epoch 221/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4968 - accuracy: 0.8357
# Epoch 222/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4883 - accuracy: 0.8365
# Epoch 223/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4691 - accuracy: 0.8386
# Epoch 224/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4667 - accuracy: 0.8469
# Epoch 225/225
# 109/109 [==============================] - 1s 12ms/step - loss: 0.4574 - accuracy: 0.8437

# %%
model4.save('/content/gdrive/MyDrive/DSLSC/Models_2/Model4_10.h5')

# %% [markdown]
# ## Testing

# %% [markdown]
# Finally, we load our models in order to evaluate them on the test-set.

# %% [markdown]
# ### Model 0

# %%
model0 = load_model('/content/gdrive/MyDrive/DSLSC/Models_2/Model0_10.h5')

# %%
y_pred = model0.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 18/18 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74        14
#            1       0.65      0.61      0.63        28
#            2       0.74      0.91      0.81        43
#            3       0.50      0.58      0.54        26
#            4       0.50      0.50      0.50        12
#            5       0.92      0.86      0.89        14
#            6       0.69      0.83      0.75        58
#            7       0.00      0.00      0.00         1
#            8       0.00      0.00      0.00         3
#            9       0.00      0.00      0.00        22
#           10       0.73      0.96      0.83        23
#           11       0.50      0.44      0.47         9
#           12       0.00      0.00      0.00         2
#           13       0.47      0.41      0.44        17
#           14       0.22      0.36      0.28        11
#           15       0.73      0.73      0.73        15
#           16       0.73      0.73      0.73        15
#           17       0.45      0.36      0.40        14
#           18       0.64      0.78      0.70         9
#           19       0.41      0.64      0.50        11
#           20       0.00      0.00      0.00         2
#           21       0.37      0.54      0.44        13
#           22       0.63      0.71      0.67        17
#           23       1.00      0.59      0.74        17
#           24       0.67      0.59      0.62        17
#           25       0.92      0.86      0.89        14
#           26       0.00      0.00      0.00         5
#           27       0.00      0.00      0.00         2
#           28       0.52      0.67      0.59        18
#           29       0.27      0.21      0.24        14
#           30       0.00      0.00      0.00         6
#           31       0.87      0.87      0.87        15
#           32       0.62      0.47      0.53        17
#           33       0.00      0.00      0.00         7
#           34       0.44      0.70      0.54        20
#           35       0.58      0.65      0.61        17
#
#     accuracy                           0.61       548
#    macro avg       0.46      0.48      0.46       548
# weighted avg       0.57      0.61      0.59       548
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.7992700729927007
# 0.8905109489051095

# %% [markdown]
# ### Model 1

# %%
model1 = load_model('/content/gdrive/MyDrive/DSLSC/Models_2/Model1_10.h5')

# %%
y_pred = model1.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 18/18 [==============================] - 1s 7ms/step
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        14
#            1       0.39      0.57      0.46        28
#            2       0.88      0.84      0.86        43
#            3       0.84      0.81      0.82        26
#            4       0.70      0.58      0.64        12
#            5       1.00      0.79      0.88        14
#            6       0.62      0.78      0.69        58
#            7       0.00      0.00      0.00         1
#            8       0.14      0.33      0.20         3
#            9       1.00      0.64      0.78        22
#           10       0.81      0.96      0.88        23
#           11       0.29      0.78      0.42         9
#           12       1.00      0.50      0.67         2
#           13       1.00      0.18      0.30        17
#           14       0.38      0.45      0.42        11
#           15       0.93      0.87      0.90        15
#           16       1.00      0.53      0.70        15
#           17       0.41      0.50      0.45        14
#           18       0.86      0.67      0.75         9
#           19       0.57      0.36      0.44        11
#           20       0.00      0.00      0.00         2
#           21       0.80      0.62      0.70        13
#           22       0.64      0.82      0.72        17
#           23       1.00      0.29      0.45        17
#           24       0.67      0.47      0.55        17
#           25       0.92      0.86      0.89        14
#           26       0.67      0.40      0.50         5
#           27       0.00      0.00      0.00         2
#           28       0.44      0.89      0.59        18
#           29       0.50      0.50      0.50        14
#           30       0.25      0.33      0.29         6
#           31       0.79      1.00      0.88        15
#           32       0.62      0.47      0.53        17
#           33       0.00      0.00      0.00         7
#           34       0.46      0.55      0.50        20
#           35       0.85      0.65      0.73        17
#
#     accuracy                           0.65       548
#    macro avg       0.62      0.55      0.55       548
# weighted avg       0.70      0.65      0.65       548
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.8193430656934306
# 0.8923357664233577

# %% [markdown]
# ### Model 2

# %%
model2 = load_model('/content/gdrive/MyDrive/DSLSC/Models_2/Model2_10.h5')

# %%
y_pred = model2.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 18/18 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89        14
#            1       0.78      0.75      0.76        28
#            2       0.87      0.95      0.91        43
#            3       0.85      0.88      0.87        26
#            4       0.82      0.75      0.78        12
#            5       1.00      1.00      1.00        14
#            6       0.88      0.84      0.86        58
#            7       0.00      0.00      0.00         1
#            8       0.67      0.67      0.67         3
#            9       1.00      0.82      0.90        22
#           10       0.92      1.00      0.96        23
#           11       0.70      0.78      0.74         9
#           12       1.00      0.50      0.67         2
#           13       0.61      0.65      0.63        17
#           14       0.70      0.64      0.67        11
#           15       1.00      0.93      0.97        15
#           16       1.00      0.87      0.93        15
#           17       0.78      0.50      0.61        14
#           18       0.67      0.67      0.67         9
#           19       0.89      0.73      0.80        11
#           20       0.00      0.00      0.00         2
#           21       0.50      0.62      0.55        13
#           22       0.68      0.88      0.77        17
#           23       1.00      0.94      0.97        17
#           24       0.92      0.65      0.76        17
#           25       1.00      0.86      0.92        14
#           26       0.67      0.80      0.73         5
#           27       1.00      0.50      0.67         2
#           28       0.67      0.67      0.67        18
#           29       0.67      0.86      0.75        14
#           30       0.40      0.33      0.36         6
#           31       0.75      1.00      0.86        15
#           32       0.73      0.65      0.69        17
#           33       0.00      0.00      0.00         7
#           34       0.56      0.90      0.69        20
#           35       0.78      0.82      0.80        17
#
#     accuracy                           0.80       548
#    macro avg       0.73      0.70      0.71       548
# weighted avg       0.80      0.80      0.79       548
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.9087591240875912
# 0.9416058394160584

# %% [markdown]
# ### Model 3

# %%
model3 = load_model('/content/gdrive/MyDrive/DSLSC/Models_2/Model3_10.h5')

# %%
y_pred = model3.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 18/18 [==============================] - 3s 8ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83        14
#            1       0.92      0.86      0.89        28
#            2       0.95      0.95      0.95        43
#            3       0.93      0.96      0.94        26
#            4       0.83      0.83      0.83        12
#            5       0.78      1.00      0.88        14
#            6       0.94      0.84      0.89        58
#            7       0.00      0.00      0.00         1
#            8       1.00      0.67      0.80         3
#            9       0.95      0.91      0.93        22
#           10       0.77      1.00      0.87        23
#           11       0.86      0.67      0.75         9
#           12       0.00      0.00      0.00         2
#           13       0.61      0.82      0.70        17
#           14       0.86      0.55      0.67        11
#           15       0.94      1.00      0.97        15
#           16       0.93      0.93      0.93        15
#           17       0.68      0.93      0.79        14
#           18       1.00      0.67      0.80         9
#           19       0.83      0.91      0.87        11
#           20       1.00      0.50      0.67         2
#           21       0.60      0.69      0.64        13
#           22       0.64      0.94      0.76        17
#           23       1.00      0.94      0.97        17
#           24       0.78      0.41      0.54        17
#           25       1.00      0.93      0.96        14
#           26       1.00      0.80      0.89         5
#           27       1.00      0.50      0.67         2
#           28       0.67      0.78      0.72        18
#           29       0.71      0.71      0.71        14
#           30       1.00      0.67      0.80         6
#           31       0.94      1.00      0.97        15
#           32       0.83      0.59      0.69        17
#           33       0.00      0.00      0.00         7
#           34       0.67      0.90      0.77        20
#           35       0.88      0.88      0.88        17
#
#     accuracy                           0.83       548
#    macro avg       0.79      0.73      0.75       548
# weighted avg       0.84      0.83      0.83       548
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.9178832116788321
# 0.948905109489051

# %% [markdown]
# ### Model 4

# %%
model4 = load_model('/content/gdrive/MyDrive/DSLSC/Models_2/Model4_10.h5')

# %%
y_pred = model4.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 18/18 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        14
#            1       0.85      0.79      0.81        28
#            2       0.89      0.95      0.92        43
#            3       0.83      0.96      0.89        26
#            4       0.77      0.83      0.80        12
#            5       0.93      1.00      0.97        14
#            6       0.84      0.90      0.87        58
#            7       0.00      0.00      0.00         1
#            8       0.67      0.67      0.67         3
#            9       1.00      0.86      0.93        22
#           10       0.79      1.00      0.88        23
#           11       0.78      0.78      0.78         9
#           12       1.00      0.50      0.67         2
#           13       0.67      0.82      0.74        17
#           14       0.75      0.55      0.63        11
#           15       1.00      0.93      0.97        15
#           16       1.00      0.87      0.93        15
#           17       0.91      0.71      0.80        14
#           18       1.00      0.67      0.80         9
#           19       0.89      0.73      0.80        11
#           20       0.00      0.00      0.00         2
#           21       0.59      0.77      0.67        13
#           22       0.67      0.94      0.78        17
#           23       1.00      0.88      0.94        17
#           24       0.88      0.41      0.56        17
#           25       0.93      1.00      0.97        14
#           26       1.00      0.80      0.89         5
#           27       1.00      0.50      0.67         2
#           28       0.61      0.78      0.68        18
#           29       0.71      0.71      0.71        14
#           30       0.57      0.67      0.62         6
#           31       0.93      0.93      0.93        15
#           32       0.73      0.65      0.69        17
#           33       1.00      0.14      0.25         7
#           34       0.67      0.90      0.77        20
#           35       1.00      0.76      0.87        17
#
#     accuracy                           0.82       548
#    macro avg       0.80      0.73      0.74       548
# weighted avg       0.84      0.82      0.82       548
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.9178832116788321
# 0.9543795620437956
