# %% [markdown]
# # Preliminary operations

# %% [markdown]
# We import the libraries and the drive environment.

# %%
# !pip install folium
# !pip install geopandas
# !pip install keras-tuner --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.5.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.10/dist-packages (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.27.1)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)

# %%
# Utility
from google.colab import drive
import pandas as pd
import numpy as np
from shutil import copyfile, copy
import datetime
import urllib.request
import os
import json
import matplotlib.pyplot as plt

# Geo
import folium
import geopandas as gpd

# Scikit-learn
from sklearn.metrics import classification_report, confusion_matrix, top_k_accuracy_score
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# Keras
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Input, Dropout
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import regularizers
import keras_tuner
from kerastuner.tuners import RandomSearch, GridSearch

seq_len = 5
n_feats = 5

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Loading data

# %%
df = pd.read_csv('/content/gdrive/MyDrive/DSLSC/motoscooter_movimento_new.csv')

# %%
df.columns
# Out:
# Index(['provider_id', 'lat', 'lng', 'created_at', 'distance', 'placename',
#        'placelat', 'placelon', 'lat&lng', 'prevObservation', 'nextObservation',
#        'nextCreated_at', 'nextDistance', 'nextTimeDiff', 'prevCreated_at',
#        'prevDistance', 'prevTimeDiff', 'samePlace', 'type'],
#       dtype='object')

# %%
df['created_at'] =  pd.to_datetime(df['created_at'], format = '%Y%m%d %H:%M:%S')
df['nextCreated_at'] =  pd.to_datetime(df['nextCreated_at'], format = '%Y%m%d %H:%M:%S')
df['prevCreated_at'] =  pd.to_datetime(df['prevCreated_at'], format = '%Y%m%d %H:%M:%S')
# Remove waiting long e-scooters
df = df[df['type'] != 'waiting long']

# %% [markdown]
# Now we order the dataframe by provider and we order each provider by time. This way, we will have sequences of consecutive pick-up/drop-off synchronized for each provider_id.

# %%
groups = df.groupby('provider_id')
ordered_df = []
for name, group in groups:
  ordered_df.append((pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True))

# %%
combined_df = pd.concat(ordered_df)

# %%
combined_df
# Out:
#     provider_id      lat      lng          created_at    distance  placename  \
# 0           2.0  45.4599  9.20633 2019-12-06 01:25:20  143.437209      356.0
# 1           2.0  45.4622  9.19374 2019-12-06 01:40:22  214.500848      354.0
# 2           2.0  45.4621  9.19375 2019-12-06 18:40:20  205.745441      354.0
# 3           2.0  45.4411  9.18597 2019-12-06 19:40:24   95.513288      204.0
# 4           2.0  45.4411  9.18597 2019-12-06 20:10:24   95.513288      204.0
# ..          ...      ...      ...                 ...         ...        ...
# 41       1754.0  45.4567  9.14835 2019-12-07 06:55:08   73.915845      307.0
# 42       1754.0  45.4567  9.14835 2019-12-07 18:55:14   73.915845      307.0
# 43       1754.0  45.4565  9.14819 2019-12-07 19:10:08   57.395490      307.0
# 44       1754.0  45.4565  9.14819 2019-12-08 14:25:08   57.395490      307.0
# 45       1754.0  45.4567  9.14828 2019-12-08 14:40:08   75.265120      307.0
#
#     placelat  placelon             lat&lng     prevObservation  \
# 0   45.46075   9.20495  (45.4599, 9.20633)                 NaN
# 1   45.46075   9.19555  (45.4622, 9.19374)  (45.4599, 9.20633)
# 2   45.46075   9.19555  (45.4621, 9.19375)  (45.4621, 9.19375)
# 3   45.44195   9.18615  (45.4411, 9.18597)  (45.4621, 9.19375)
# 4   45.44195   9.18615  (45.4411, 9.18597)  (45.4411, 9.18597)
# ..       ...       ...                 ...                 ...
# 41  45.45605   9.14855  (45.4567, 9.14835)  (45.4566, 9.14827)
# 42  45.45605   9.14855  (45.4567, 9.14835)  (45.4567, 9.14835)
# 43  45.45605   9.14855  (45.4565, 9.14819)  (45.4567, 9.14835)
# 44  45.45605   9.14855  (45.4565, 9.14819)  (45.4565, 9.14819)
# 45  45.45605   9.14855  (45.4567, 9.14828)  (45.4565, 9.14819)
#
#        nextObservation      nextCreated_at  nextDistance  nextTimeDiff  \
# 0   (45.4622, 9.19374) 2019-12-06 01:40:22   1017.327131     15.033333
# 1   (45.4621, 9.19375) 2019-12-06 01:55:23     11.141565     15.016667
# 2   (45.4411, 9.18597) 2019-12-06 19:40:24   2411.994485     60.066667
# 3   (45.4411, 9.18597) 2019-12-06 19:55:25      0.000000     15.016667
# 4   (45.4721, 9.18426) 2019-12-06 20:55:22   3447.956963     44.966667
# ..                 ...                 ...           ...           ...
# 41  (45.4567, 9.14835) 2019-12-07 07:10:09      0.000000     15.016667
# 42  (45.4565, 9.14819) 2019-12-07 19:10:08     25.509056     14.900000
# 43  (45.4565, 9.14819) 2019-12-07 19:25:09      0.000000     15.016667
# 44  (45.4567, 9.14828) 2019-12-08 14:40:08     23.316224     15.000000
# 45  (45.4567, 9.14832) 2019-12-08 14:55:10      3.128709     15.033333
#
#         prevCreated_at  prevDistance  prevTimeDiff  samePlace  \
# 0                  NaT      0.000000      0.000000        0.0
# 1  2019-12-06 01:25:20   1017.327131     15.033333        0.0
# 2  2019-12-06 18:25:21      0.000000     14.983333        0.0
# 3  2019-12-06 18:40:20   2411.994485     60.066667        0.0
# 4  2019-12-06 19:55:25      0.000000     14.983333        0.0
# ..                 ...           ...           ...        ...
# 41 2019-12-07 06:25:08     12.754525     30.000000        0.0
# 42 2019-12-07 18:40:08      0.000000     15.100000        0.0
# 43 2019-12-07 18:55:14     25.509056     14.900000        0.0
# 44 2019-12-08 14:10:10      0.000000     14.966667        0.0
# 45 2019-12-08 14:25:08     23.316224     15.000000        0.0
#
#                     type
# 0   first seen / pick-up
# 1               drop-off
# 2        pick-up outlier
# 3       drop-off outlier
# 4                pick-up
# ..                   ...
# 41              drop-off
# 42               pick-up
# 43              drop-off
# 44               pick-up
# 45              drop-off
#
# [81568 rows x 19 columns]

# %% [markdown]
# The sorting done above allows us to correctly associate, for each sample, the pick-up points with the drop-off points.

# %%
pickup = ['first seen / pick-up', 'pick-up', 'pick-up outlier']
dropoff = ['last seen / drop-off', 'drop-off', 'drop-off outlier']
# Create 2 different dataframes: one for pick-up and one for drop-off
df_p = combined_df[combined_df['type'].isin(pickup)]
df_d = combined_df[combined_df['type'].isin(dropoff)]

# %% [markdown]
# The 2 dataframes are ordered by provider_id and each provider_id is ordered by time. They are syncrhonized, so that for example the first row is both the pick-up point and the drop-off point of the same scooter, in respectively df_p and df_d.

# %%
df_p = df_p[['provider_id', 'created_at', 'placename', 'placelon', 'placelat']].reset_index(drop = True)
df_d = df_d[['created_at', 'placename', 'placelon', 'placelat']].reset_index(drop = True)
# The placename and the coordinates of the drop-off observation are our target
df_p['target'] = df_d['placename']
df_p['target_lon'] = df_d['placelon']
df_p['target_lat'] = df_d['placelat']
df = df_p.copy()

# %% [markdown]
# We also may create a variable indicating if it's saturday or sunday.

# %%
df['is_weekend'] = df['created_at'].apply(lambda x: 1 if x.weekday() >= 5 else 0)

# %%
df
# Out:
#        provider_id          created_at  placename  placelon  placelat  target  \
# 0              2.0 2019-12-06 01:25:20      356.0   9.20495  45.46075   354.0
# 1              2.0 2019-12-06 18:40:20      354.0   9.19555  45.46075   204.0
# 2              2.0 2019-12-06 20:10:24      204.0   9.18615  45.44195   426.0
# 3              2.0 2019-12-07 00:25:20      426.0   9.18615  45.47015   503.0
# 4              2.0 2019-12-07 08:40:16      503.0   9.20025  45.47955   503.0
# ...            ...                 ...        ...       ...       ...     ...
# 40779       1754.0 2019-12-07 01:55:08      307.0   9.14855  45.45605   307.0
# 40780       1754.0 2019-12-07 02:40:09      307.0   9.14855  45.45605   307.0
# 40781       1754.0 2019-12-07 06:25:08      307.0   9.14855  45.45605   307.0
# 40782       1754.0 2019-12-07 18:55:14      307.0   9.14855  45.45605   307.0
# 40783       1754.0 2019-12-08 14:25:08      307.0   9.14855  45.45605   307.0
#
#        target_lon  target_lat  is_weekend
# 0         9.19555    45.46075           0
# 1         9.18615    45.44195           0
# 2         9.18615    45.47015           0
# 3         9.20025    45.47955           1
# 4         9.20025    45.47955           1
# ...           ...         ...         ...
# 40779     9.14855    45.45605           1
# 40780     9.14855    45.45605           1
# 40781     9.14855    45.45605           1
# 40782     9.14855    45.45605           1
# 40783     9.14855    45.45605           1
#
# [40784 rows x 9 columns]

# %% [markdown]
# # Zone prediction \#2 (5 e-scooters)

# %% [markdown]
# The goal of this task is to build a prediction model in order to know in advance the drop-off zone of a sequence of scooters (with probability attached). Here we perform a classification task on all the Milan NIL, i.e. with a higher level of granularity.

# %% [markdown]
# ## Pre-processing

# %%
gdf = gpd.GeoDataFrame(df, crs = 'EPSG:4326', geometry = gpd.points_from_xy(df.placelon, df.placelat))

# %%
milan_nil = gpd.read_file("/content/gdrive/MyDrive/DSLSC/NIL_E0.zip")

# %%
# Ensuring the crs is the same
if gdf.crs != milan_nil.crs:
  milan_nil = milan_nil.to_crs(gdf.crs)

# %%
# Spatial join between the zones and scooters GeoDataFrames
zones_with_scooters_gdf = gpd.sjoin(milan_nil, gdf, predicate = 'contains')
# Group the GeoDataFrame by zone ID and count the number of scooters in each zone
scooter_counts_by_zone = zones_with_scooters_gdf.groupby('NIL').size()
# Get the IDs of the zones with scooters
zones_with_scooters_ids = scooter_counts_by_zone.index
# Filter the zones GeoDataFrame in order to remove the zones without scooters
zones_gdf = milan_nil[milan_nil['NIL'].isin(zones_with_scooters_ids)]
zones_gdf = zones_gdf.reset_index(drop = True)

# %%
city = zones_gdf.copy()
city['newNIL'] = zones_gdf['NIL']
for i in range(len(city)):
  if(city['NIL'][i] == 'BOVISA'):
    city['NIL'][i] = 'FARINI'
    city['newNIL'][i] = 'FARINI'
  elif(city['NIL'][i] == 'CITTA\' STUDI'):
    city['NIL'][i] = 'BUENOS AIRES - VENEZIA'
    city['newNIL'][i] = 'BUENOS AIRES - VENEZIA'
  elif(city['NIL'][i] == 'GIARDINI PORTA VENEZIA'):
    city['NIL'][i] = 'GUASTALLA'
    city['newNIL'][i] = 'GUASTALLA'
  elif(city['NIL'][i] == 'QT 8'):
    city['NIL'][i] = 'VILLAPIZZONE'
    city['newNIL'][i] = 'VILLAPIZZONE'
city = city.to_crs(epsg = 4326).dissolve(by = 'newNIL')
# Out:
# <ipython-input-52-471b6c4ccb41>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['NIL'][i] = 'VILLAPIZZONE'
# <ipython-input-52-471b6c4ccb41>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['newNIL'][i] = 'VILLAPIZZONE'
# <ipython-input-52-471b6c4ccb41>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['NIL'][i] = 'BUENOS AIRES - VENEZIA'
# <ipython-input-52-471b6c4ccb41>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['newNIL'][i] = 'BUENOS AIRES - VENEZIA'
# <ipython-input-52-471b6c4ccb41>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['NIL'][i] = 'FARINI'
# <ipython-input-52-471b6c4ccb41>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['newNIL'][i] = 'FARINI'
# <ipython-input-52-471b6c4ccb41>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['NIL'][i] = 'GUASTALLA'
# <ipython-input-52-471b6c4ccb41>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['newNIL'][i] = 'GUASTALLA'

# %%
# Plot the quarters polygons
ax = city.plot(edgecolor = 'k', facecolor = 'none', figsize = (15, 10))
gdf.plot(ax = ax, color = "blue")
ax.set_title('E-scooter positions within Milan NILs\n')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Loop over the quarters polygons and add the name as text
for idx, row in city.iterrows():
  ax.annotate(text = row['NIL'], xy = row['geometry'].centroid.coords[0], ha = 'center', fontsize = 8)

# Set the axis limits
ax.set_xlim(9.105, 9.24)
ax.set_ylim(45.425, 45.515)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()

plt.savefig('Milan NILs.png', bbox_inches = 'tight', dpi = 300)

# %%
zones_with_scooters_gdf.reset_index(drop = True, inplace = True)

# %%
zones_with_scooters_gdf['NIL'].unique()
# Out:
# array(['QT 8', 'S. SIRO', 'GHISOLFA', 'GIAMBELLINO', 'S. CRISTOFORO',
#        'TIBALDI', 'EX OM - MORIVIONE', 'FARINI', 'UMBRIA - MOLISE',
#        "CITTA' STUDI", 'SELINUNTE', 'GUASTALLA', 'BRERA', 'DUOMO',
#        'SCALO ROMANA', 'MAGENTA - S. VITTORE', 'VILLAPIZZONE', 'BOVISA',
#        'DERGANO', 'PORTELLO', 'TRE TORRI', 'PARCO SEMPIONE',
#        'GIARDINI PORTA VENEZIA', 'TORTONA', 'NAVIGLI', 'XXII MARZO',
#        'BUENOS AIRES - VENEZIA', 'CENTRALE', 'GRECO', 'LORETO',
#        'MACIACHINI - MAGGIOLINA', 'ISOLA', 'SARPI',
#        'DE ANGELI - MONTE ROSA', 'WASHINGTON', 'BANDE NERE',
#        'PORTA ROMANA', 'VIGENTINA', 'TICINESE', 'PAGANO',
#        'GARIBALDI REPUBBLICA'], dtype=object)

# %%
keyList = list(zones_with_scooters_gdf['NIL'].unique())
place_dict = {key: [] for key in keyList}
for i in range(0, len(zones_with_scooters_gdf)):
  if not isinstance(zones_with_scooters_gdf['placename'][i], str):
    place_dict[zones_with_scooters_gdf['NIL'][i]].append(zones_with_scooters_gdf['placename'][i])

# %%
for key, value in place_dict.items():
  value = list(set(value))
  place_dict[key] = value

# %%
for i in range(0, len(df)):
  for key, value in place_dict.items():
    if df['target'][i] in value:
      df['target'][i] = key
      break
# Out:
# <ipython-input-58-b555a8282ce4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][i] = key

# %%
df = df[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend', 'target']].reset_index(drop = True)

# %%
df
# Out:
#        provider_id          created_at  placelon  placelat  is_weekend  \
# 0              2.0 2019-12-06 01:25:20   9.20495  45.46075           0
# 1              2.0 2019-12-06 18:40:20   9.19555  45.46075           0
# 2              2.0 2019-12-06 20:10:24   9.18615  45.44195           0
# 3              2.0 2019-12-07 00:25:20   9.18615  45.47015           1
# 4              2.0 2019-12-07 08:40:16   9.20025  45.47955           1
# ...            ...                 ...       ...       ...         ...
# 40779       1754.0 2019-12-07 01:55:08   9.14855  45.45605           1
# 40780       1754.0 2019-12-07 02:40:09   9.14855  45.45605           1
# 40781       1754.0 2019-12-07 06:25:08   9.14855  45.45605           1
# 40782       1754.0 2019-12-07 18:55:14   9.14855  45.45605           1
# 40783       1754.0 2019-12-08 14:25:08   9.14855  45.45605           1
#
#            target
# 0           DUOMO
# 1         TIBALDI
# 2           BRERA
# 3        CENTRALE
# 4        CENTRALE
# ...           ...
# 40779  BANDE NERE
# 40780  BANDE NERE
# 40781  BANDE NERE
# 40782  BANDE NERE
# 40783  BANDE NERE
#
# [40784 rows x 6 columns]

# %% [markdown]
# Let's check the zones with few e-scooters and aggregate them to the nearest zone.

# %%
groups = df.groupby('target')
for name, group in groups:
  if(len(group) < 100):
    print(name)
# Out:
# BOVISA
# CITTA' STUDI
# GIARDINI PORTA VENEZIA
# QT 8

# %%
for i in range(len(df)):
  if(df['target'][i] == 'BOVISA'):
    df['target'][i] = 'FARINI'
  elif(df['target'][i] == 'CITTA\' STUDI'):
    df['target'][i] = 'BUENOS AIRES - VENEZIA'
  elif(df['target'][i] == 'GIARDINI PORTA VENEZIA'):
    df['target'][i] = 'GUASTALLA'
  elif(df['target'][i] == 'QT 8'):
    df['target'][i] = 'VILLAPIZZONE'
# Out:
# <ipython-input-62-0e99215fbd33>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][i] = 'GUASTALLA'
# <ipython-input-62-0e99215fbd33>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][i] = 'VILLAPIZZONE'
# <ipython-input-62-0e99215fbd33>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][i] = 'FARINI'
# <ipython-input-62-0e99215fbd33>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][i] = 'BUENOS AIRES - VENEZIA'

# %%
# We discard samples in a way that there are only multiple of seq_len
ordered_df = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len == 0):
    ordered_df.append(df_)
  else:
    df_ = df_[:-((len(df_))%seq_len)]
    ordered_df.append(df_)

# %%
combined_df = pd.concat(ordered_df)

# %%
combined_df
# Out:
#       provider_id          created_at  placelon  placelat  is_weekend  \
# 0          1342.0 2019-12-02 00:10:11   9.13915  45.46545           0
# 1          1285.0 2019-12-02 00:25:11   9.13915  45.46545           0
# 2          1342.0 2019-12-02 00:40:09   9.13915  45.46545           0
# 3          1373.0 2019-12-02 00:40:09   9.14385  45.46545           0
# 4          1098.0 2019-12-02 00:40:09   9.14385  45.46545           0
# ...           ...                 ...       ...       ...         ...
# 1495       1246.0 2019-12-08 23:25:10   9.21435  45.45605           1
# 1496       1395.0 2019-12-08 23:25:10   9.21905  45.45605           1
# 1497       1066.0 2019-12-08 23:25:11   9.22375  45.46075           1
# 1498       1070.0 2019-12-08 23:25:11   9.21435  45.46545           1
# 1499       1262.0 2019-12-08 23:25:13   9.20965  45.46075           1
#
#           target
# 0     BANDE NERE
# 1     BANDE NERE
# 2     BANDE NERE
# 3     BANDE NERE
# 4     BANDE NERE
# ...          ...
# 1495  XXII MARZO
# 1496  XXII MARZO
# 1497  XXII MARZO
# 1498  XXII MARZO
# 1499  XXII MARZO
#
# [40700 rows x 6 columns]

# %%
df = combined_df.reset_index(drop = True)

# %% [markdown]
# ## Preparation

# %%
encoder_id = LabelEncoder()
df['provider_id'] = encoder_id.fit_transform(df['provider_id'])

# %%
encoder_target = LabelEncoder()
df['target'] = encoder_id.fit_transform(df['target'])

# %%
# Converting datetime in unixtime (int)
dates = pd.to_datetime(df['created_at'])
df['created_at'] = dates.astype(int) // 10**9
min_time = min(df['created_at'])
df['created_at'] = df['created_at'] - min_time
#df['created_at'] = df['created_at'] % 86400

# %%
# Test-set = monday
test = df[df['created_at'] < 1575331200 - min_time]
train = df.drop(test.index)
test.reset_index(drop = True, inplace = True)
train.reset_index(drop = True, inplace = True)

# %%
max_test = max(test['created_at'])
train['created_at'] = train['created_at'] - max_test
max_train = max(train['created_at'])
test['created_at'] = test['created_at'] + max_train
# Out:
# <ipython-input-71-1feb4cdfc222>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['created_at'] = test['created_at'] + max_train

# %%
train_test_ordered = pd.concat([train, test], ignore_index = True)

# %%
scaler_0 = MinMaxScaler()
scaler_1 = MinMaxScaler()
scaler_2 = MinMaxScaler()
scaler_3 = MinMaxScaler()

df['provider_id'] = scaler_0.fit_transform(np.array(df['provider_id']).reshape(-1, 1))
train_test_ordered['created_at'] = scaler_1.fit_transform(np.array(train_test_ordered['created_at']).reshape(-1, 1))

train['provider_id'] = scaler_0.transform(np.array(train['provider_id']).reshape(-1, 1))
train['created_at'] = scaler_1.transform(np.array(train['created_at']).reshape(-1, 1))
train['placelon'] = scaler_2.fit_transform(np.array(train['placelon']).reshape(-1, 1))
train['placelat'] = scaler_3.fit_transform(np.array(train['placelat']).reshape(-1, 1))

test['provider_id'] = scaler_0.transform(np.array(test['provider_id']).reshape(-1, 1))
test['created_at'] = scaler_1.transform(np.array(test['created_at']).reshape(-1, 1))
test['placelon'] = scaler_2.transform(np.array(test['placelon']).reshape(-1, 1))
test['placelat'] = scaler_3.transform(np.array(test['placelat']).reshape(-1, 1))
# Out:
# <ipython-input-73-c99ba37fc144>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['provider_id'] = scaler_0.transform(np.array(test['provider_id']).reshape(-1, 1))
# <ipython-input-73-c99ba37fc144>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['created_at'] = scaler_1.transform(np.array(test['created_at']).reshape(-1, 1))
# <ipython-input-73-c99ba37fc144>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['placelon'] = scaler_2.transform(np.array(test['placelon']).reshape(-1, 1))
# <ipython-input-73-c99ba37fc144>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['placelat'] = scaler_3.transform(np.array(test['placelat']).reshape(-1, 1))

# %% [markdown]
# Now we create the validation set, selecting the last 10% of each target. Moreover, we save the array with training + validation for further retraining.

# %%
X = train.copy(deep = True)

# %%
val = pd.DataFrame(columns = train.columns)

for i in range(0, 36):
  to_pick = int((len(train[train['target'] == i]))*0.1)
  rows = train[train['target'] == i].tail(to_pick)
  train = train.drop(rows.index)
  val = pd.concat([val, rows], ignore_index = True)

train.reset_index(drop = True, inplace = True)

# %%
# Now we have to fix the lengths of train, val and test, in the same way as before
groups = train.groupby('target')
ordered_df_train = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_train.append(df_)

groups = val.groupby('target')
ordered_df_val = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_val.append(df_)
    
groups = test.groupby('target')
ordered_df_test = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_test.append(df_)

# Training + validation
groups = X.groupby('target')
ordered_df_X = []
for name, group in groups:
  df_ = (pd.DataFrame(group)).sort_values(by = 'created_at').reset_index(drop = True)
  if(len(group)%seq_len != 0):
    df_ = df_[:-((len(df_))%seq_len)]
  ordered_df_X.append(df_)

# %%
train = pd.concat(ordered_df_train).reset_index(drop = True)
val = pd.concat(ordered_df_val).reset_index(drop = True)
test = pd.concat(ordered_df_test).reset_index(drop = True)
X = pd.concat(ordered_df_X).reset_index(drop = True)

# %%
train
# Out:
#        provider_id  created_at  placelon  placelat  is_weekend  target
# 0         0.851976    0.000000  0.000000  0.384615           0       0
# 1         0.703112    0.000000  0.000000  0.384615           0       0
# 2         0.684609    0.000000  0.111111  0.307692           0       0
# 3         0.516400    0.000000  0.000000  0.384615           0       0
# 4         0.703112    0.001495  0.000000  0.384615           0       0
# ...            ...         ...       ...       ...         ...     ...
# 31470     0.529016    0.772737  0.833333  0.153846           1      35
# 31471     0.993272    0.772742  0.833333  0.384615           1      35
# 31472     0.677040    0.774237  0.833333  0.384615           1      35
# 31473     0.699748    0.775735  0.888889  0.230769           1      35
# 31474     0.539108    0.775740  0.888889  0.384615           1      35
#
# [31475 rows x 6 columns]

# %%
val
# Out:
#       provider_id  created_at  placelon  placelat is_weekend target
# 0        0.791421    0.759279  0.000000  0.307692          1      0
# 1        0.512195    0.759279  0.111111  0.307692          1      0
# 2        0.826745    0.759279  0.000000  0.384615          1      0
# 3        0.767031    0.760773  0.111111  0.307692          1      0
# 4        0.671993    0.765256  0.111111  0.230769          1      0
# ...           ...         ...       ...       ...        ...    ...
# 3415     0.706476    0.853448  0.888889  0.230769          1     35
# 3416     0.535744    0.853452  0.833333  0.307692          1     35
# 3417     0.706476    0.856433  0.888889  0.230769          1     35
# 3418     0.797309    0.856433  0.944444  0.230769          1     35
# 3419     0.601346    0.856434  0.888889  0.384615          1     35
#
# [3420 rows x 6 columns]

# %%
test
# Out:
#       provider_id  created_at  placelon  placelat  is_weekend  target
# 0        0.765349    0.857965  0.000000  0.384615           0       0
# 1        0.730866    0.859460  0.000000  0.384615           0       0
# 2        0.765349    0.860951  0.000000  0.384615           0       0
# 3        0.785534    0.860951  0.055556  0.384615           0       0
# 4        0.619849    0.860951  0.055556  0.384615           0       0
# ...           ...         ...       ...       ...         ...     ...
# 5585     0.717410    0.996976  0.777778  0.538462           0      35
# 5586     0.522288    0.998467  0.888889  0.384615           0      35
# 5587     0.780488    0.999965  0.888889  0.384615           0      35
# 5588     0.737595    0.999965  0.833333  0.384615           0      35
# 5589     0.690496    0.999965  0.833333  0.384615           0      35
#
# [5590 rows x 6 columns]

# %%
X
# Out:
#        provider_id  created_at  placelon  placelat  is_weekend  target
# 0         0.851976    0.000000  0.000000  0.384615           0       0
# 1         0.703112    0.000000  0.000000  0.384615           0       0
# 2         0.684609    0.000000  0.111111  0.307692           0       0
# 3         0.516400    0.000000  0.000000  0.384615           0       0
# 4         0.703112    0.001495  0.000000  0.384615           0       0
# ...            ...         ...       ...       ...         ...     ...
# 34960     0.597981    0.853447  1.000000  0.307692           1      35
# 34961     0.601346    0.853447  0.888889  0.384615           1      35
# 34962     0.706476    0.853448  0.888889  0.230769           1      35
# 34963     0.535744    0.853452  0.833333  0.307692           1      35
# 34964     0.706476    0.856433  0.888889  0.230769           1      35
#
# [34965 rows x 6 columns]

# %%
X_train = np.array((train[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)
y_train = np.array((train['target'])).reshape(-1, seq_len)

X_val = np.array((val[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)
y_val = np.array((val['target'])).reshape(-1, seq_len)

X_test = np.array((test[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)
y_test = np.array((test['target'])).reshape(-1, seq_len)

y = np.array((X['target'])).reshape(-1, seq_len)
X = np.array((X[['provider_id', 'created_at', 'placelon', 'placelat', 'is_weekend']])).reshape(-1, seq_len, n_feats)

# %%
y_train = to_categorical(y_train)[:, 0, :]
y_val = to_categorical(y_val)[:, 0, :]
y_test = to_categorical(y_test)[:, 0, :]
y = to_categorical(y)[:, 0, :]

# %%
X_val = np.asarray(X_val).astype('float32')
y_val = np.asarray(y_val).astype('float32')

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
print(X.shape)
print(y.shape)
# Out:
# (6295, 5, 5)
# (6295, 36)
# (684, 5, 5)
# (684, 36)
# (1118, 5, 5)
# (1118, 36)
# (6993, 5, 5)
# (6993, 36)

# %% [markdown]
# ## Model selection

# %% [markdown]
# We use a RNN LSTM for this task. In this section we start from a basic network and select the best model iteratively.

# %% [markdown]
# ### Model 0

# %%
model0 = Sequential()
model0.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True))
model0.add(LSTM(32, return_sequences = False))
model0.add(Dense(32))
model0.add(Dense(36, activation = 'softmax'))
model0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 16)             1408
#
#  lstm_1 (LSTM)               (None, 32)                6272
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 36)                1188
#
# =================================================================
# Total params: 9,924
# Trainable params: 9,924
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = Adam(learning_rate = 0.0001)
model0.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history0 = model0.fit(X_train, y_train, epochs = 100, batch_size = 16, validation_data = (X_val, y_val))

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history0.history['loss'])
plt.plot(history0.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history0.history['accuracy'])
plt.plot(history0.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model0 = Sequential()
model0.add(LSTM(16, input_shape = (seq_len, n_feats), return_sequences = True))
model0.add(LSTM(32, return_sequences = False))
model0.add(Dense(32))
model0.add(Dense(36, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.0001)
model0.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history0 = model0.fit(X, y, epochs = 100, batch_size = 16)
# Out:
# Epoch 1/100
# 438/438 [==============================] - 8s 8ms/step - loss: 3.5337 - accuracy: 0.0714
# Epoch 2/100
# 438/438 [==============================] - 5s 11ms/step - loss: 3.3328 - accuracy: 0.0881
# Epoch 3/100
# 438/438 [==============================] - 4s 9ms/step - loss: 3.1204 - accuracy: 0.1257
# Epoch 4/100
# 438/438 [==============================] - 4s 9ms/step - loss: 2.6914 - accuracy: 0.2427
# Epoch 5/100
# 438/438 [==============================] - 4s 9ms/step - loss: 2.3799 - accuracy: 0.2927
# Epoch 6/100
# 438/438 [==============================] - 5s 12ms/step - loss: 2.2154 - accuracy: 0.3120
# Epoch 7/100
# 438/438 [==============================] - 4s 9ms/step - loss: 2.1083 - accuracy: 0.3589
# Epoch 8/100
# 438/438 [==============================] - 4s 8ms/step - loss: 2.0277 - accuracy: 0.3800
# Epoch 9/100
# 438/438 [==============================] - 4s 10ms/step - loss: 1.9622 - accuracy: 0.3994
# Epoch 10/100
# 438/438 [==============================] - 4s 10ms/step - loss: 1.9089 - accuracy: 0.4055
# Epoch 11/100
# 438/438 [==============================] - 4s 9ms/step - loss: 1.8625 - accuracy: 0.4296
# Epoch 12/100
# 438/438 [==============================] - 4s 9ms/step - loss: 1.8222 - accuracy: 0.4486
# Epoch 13/100
# 438/438 [==============================] - 5s 12ms/step - loss: 1.7887 - accuracy: 0.4650
# Epoch 14/100
# 438/438 [==============================] - 4s 9ms/step - loss: 1.7591 - accuracy: 0.4783
# Epoch 15/100
# 438/438 [==============================] - 4s 9ms/step - loss: 1.7321 - accuracy: 0.4918
# Epoch 16/100
# 438/438 [==============================] - 4s 10ms/step - loss: 1.7076 - accuracy: 0.5019
# Epoch 17/100
# 438/438 [==============================] - 5s 11ms/step - loss: 1.6844 - accuracy: 0.5069
# Epoch 18/100
# 438/438 [==============================] - 4s 9ms/step - loss: 1.6644 - accuracy: 0.5198
# Epoch 19/100
# 438/438 [==============================] - 4s 9ms/step - loss: 1.6439 - accuracy: 0.5265
# Epoch 20/100
# 438/438 [==============================] - 5s 11ms/step - loss: 1.6266 - accuracy: 0.5278
# Epoch 21/100
# 438/438 [==============================] - 4s 9ms/step - loss: 1
100
# 438/438 [==============================] - 4s 9ms/step - loss: 1.2580 - accuracy: 0.6146
# Epoch 97/100
# 438/438 [==============================] - 4s 10ms/step - loss: 1.2577 - accuracy: 0.6162
# Epoch 98/100
# 438/438 [==============================] - 5s 12ms/step - loss: 1.2557 - accuracy: 0.6179
# Epoch 99/100
# 438/438 [==============================] - 4s 10ms/step - loss: 1.2540 - accuracy: 0.6152
# Epoch 100/100
# 438/438 [==============================] - 4s 9ms/step - loss: 1.2498 - accuracy: 0.6162

# %%
model0.save('/content/gdrive/MyDrive/DSLSC/Models_2/Model0_5.h5')

# %% [markdown]
# ### Keras tuner \#1

# %%
#!rm -rf /content/best_hyperparams_1

# %% [markdown]
# Now we use the keras tuner in order to find the best units combination.

# %%
# 16 different combinations
def build_model_1(hp):
  model = Sequential()
  model.add(LSTM(units = hp.Int('units_lstm_1', min_value = 16, max_value = 32, step = 16),
                  input_shape = (seq_len, n_feats),
                  return_sequences = True))
  model.add(LSTM(units = hp.Int('units_lstm_2', min_value = 32, max_value = 64, step = 32),
                  return_sequences = False))
  model.add(Dense(units = hp.Int('units_dense', min_value = 32, max_value = 64, step = 32)))
  model.add(Dense(36, activation = 'softmax'))
  
  optimizer = Adam(learning_rate = hp.Choice('learning_rate', values = [0.001, 0.0001]))
  model.compile(optimizer =  optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
tuner_1 = GridSearch(
  build_model_1,
  objective = 'val_loss',
  executions_per_trial = 1,
  directory = '/content',
  project_name = 'best_hyperparams_1'
)

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
# Grid search
tuner_1.search(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
# Retrieve best hyperparameters and final model
best_hp = tuner_1.get_best_hyperparameters()[0]
best_model = tuner_1.hypermodel.build(best_hp)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 5, 32)             4864
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 36)                1188
#
# =================================================================
# Total params: 15,428
# Trainable params: 15,428
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's try this model.

# %% [markdown]
# ### Model 1

# %%
model1 = Sequential()
model1.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model1.add(LSTM(32, return_sequences = False))
model1.add(Dense(32))
model1.add(Dense(36, activation = 'softmax'))
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 5, 32)             4864
#
#  lstm_5 (LSTM)               (None, 32)                8320
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 36)                1188
#
# =================================================================
# Total params: 15,428
# Trainable params: 15,428
# Non-trainable params: 0
# _________________________________________________________________

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
optimizer = Adam(learning_rate = 0.001)
model1.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history1 = model1.fit(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model1 = Sequential()
model1.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model1.add(LSTM(32, return_sequences = False))
model1.add(Dense(32))
model1.add(Dense(36, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.001)
model1.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# 438/438 [==============================] - 5s 12ms/step - loss: 0.5315 - accuracy: 0.8321
# Epoch 62/75
# 438/438 [==============================] - 4s 9ms/step - loss: 0.5271 - accuracy: 0.8317
# Epoch 63/75
# 438/438 [==============================] - 4s 10ms/step - loss: 0.5168 - accuracy: 0.8358
# Epoch 64/75
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5148 - accuracy: 0.8371
# Epoch 65/75
# 438/438 [==============================] - 4s 9ms/step - loss: 0.5079 - accuracy: 0.8380
# Epoch 66/75
# 438/438 [==============================] - 4s 9ms/step - loss: 0.4930 - accuracy: 0.8454
# Epoch 67/75
# 438/438 [==============================] - 5s 12ms/step - loss: 0.4865 - accuracy: 0.8464
# Epoch 68/75
# 438/438 [==============================] - 5s 10ms/step - loss: 0.4740 - accuracy: 0.8488
# Epoch 69/75
# 438/438 [==============================] - 4s 10ms/step - loss: 0.4718 - accuracy: 0.8483
# Epoch 70/75
# 438/438 [==============================] - 5s 12ms/step - loss: 0.4693 - accuracy: 0.8530
# Epoch 71/75
# 438/438 [==============================] - 5s 11ms/step - loss: 0.4579 - accuracy: 0.8534
# Epoch 72/75
# 438/438 [==============================] - 4s 10ms/step - loss: 0.4494 - accuracy: 0.8537
# Epoch 73/75
# 438/438 [==============================] - 5s 11ms/step - loss: 0.4459 - accuracy: 0.8579
# Epoch 74/75
# 438/438 [==============================] - 5s 12ms/step - loss: 0.4319 - accuracy: 0.8650
# Epoch 75/75
# 438/438 [==============================] - 4s 10ms/step - loss: 0.4313 - accuracy: 0.8636

# %%
model1.save('/content/gdrive/MyDrive/DSLSC/Models_2/Model1_5.h5')

# %% [markdown]
# ### Keras tuner \#2

# %%
#!rm -rf /content/best_hyperparams_2

# %% [markdown]
# Now we use the keras tuner in order to find the best dropout combination.

# %%
# 12 different combinations
def build_model_2(hp):
  model = Sequential()
  model.add(LSTM(units = 32, input_shape = (seq_len, n_feats), return_sequences = True))
  model.add(Dropout(hp.Float('dropout_lstm_1', min_value = 0.0, max_value = 0.2, step = 0.2)))
  model.add(LSTM(units = 32, return_sequences = False))
  model.add(Dropout(hp.Float('dropout_lstm_2', min_value = 0.0, max_value = 0.2, step = 0.2)))
  model.add(Dense(units = 32))
  model.add(Dropout(hp.Float('dropout_dense', min_value = 0.0, max_value = 0.4, step = 0.2)))
  model.add(Dense(36, activation = 'softmax'))
  
  optimizer = Adam(learning_rate = 0.001)
  model.compile(optimizer =  optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
tuner_2 = GridSearch(
  build_model_2,
  objective = 'val_loss',
  executions_per_trial = 1,
  directory = '/content',
  project_name = 'best_hyperparams_2'
)

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
# Grid search
tuner_2.search(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
# Retrieve best hyperparameters and final model
best_hp = tuner_2.get_best_hyperparameters()[0]
best_model = tuner_2.hypermodel.build(best_hp)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 5, 32)             4864
#
#  dropout_3 (Dropout)         (None, 5, 32)             0
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 36)                1188
#
# =================================================================
# Total params: 15,428
# Trainable params: 15,428
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's try this model.

# %% [markdown]
# ### Model 2

# %%
model2 = Sequential()
model2.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model2.add(Dropout(0.2))
model2.add(LSTM(32, return_sequences = False))
model2.add(Dropout(0.2))
model2.add(Dense(32))
model2.add(Dropout(0.2))
model2.add(Dense(36, activation = 'softmax'))
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 5, 32)             4864
#
#  dropout_6 (Dropout)         (None, 5, 32)             0
#
#  lstm_5 (LSTM)               (None, 32)                8320
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 36)                1188
#
# =================================================================
# Total params: 15,428
# Trainable params: 15,428
# Non-trainable params: 0
# _________________________________________________________________

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
optimizer = Adam(learning_rate = 0.001)
model2.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history2 = model2.fit(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model2 = Sequential()
model2.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model2.add(Dropout(0.2))
model2.add(LSTM(32, return_sequences = False))
model2.add(Dropout(0.2))
model2.add(Dense(32))
model2.add(Dropout(0.2))
model2.add(Dense(36, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.001)
model2.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history2 = model2.fit(X, y, epochs = 175, batch_size = 16)
# Out:
# Epoch 1/175
# 438/438 [==============================] - 11s 14ms/step - loss: 2.9799 - accuracy: 0.1529
# Epoch 2/175
# 438/438 [==============================] - 5s 11ms/step - loss: 2.0698 - accuracy: 0.3318
# Epoch 3/175
# 438/438 [==============================] - 5s 12ms/step - loss: 1.8481 - accuracy: 0.4034
# Epoch 4/175
# 438/438 [==============================] - 6s 13ms/step - loss: 1.7254 - accuracy: 0.4417
# Epoch 5/175
# 438/438 [==============================] - 5s 11ms/step - loss: 1.6588 - accuracy: 0.4673
# Epoch 6/175
# 438/438 [==============================] - 5s 12ms/step - loss: 1.6097 - accuracy: 0.4841
# Epoch 7/175
# 438/438 [==============================] - 8s 18ms/step - loss: 1.5652 - accuracy: 0.5039
# Epoch 8/175
# 438/438 [==============================] - 5s 11ms/step - loss: 1.5239 - accuracy: 0.5187
# Epoch 9/175
# 438/438 [==============================] - 5s 11ms/step - loss: 1.5075 - accuracy: 0.5277
# Epoch 10/175
# 438/438 [==============================] - 6s 14ms/step - loss: 1.4912 - accuracy: 0.5274
# Epoch 11/175
# 438/438 [==============================] - 5s 11ms/step - loss: 1.4680 - accuracy: 0.5320
# Epoch 12/175
# 438/438 [==============================] - 5s 11ms/step - loss: 1.4343 - accuracy: 0.5457
# Epoch 13/175
# 438/438 [==============================] - 6s 14ms/step - loss: 1.4242 - accuracy: 0.5483
# Epoch 14/175
# 438/438 [==============================] - 5s 11ms/step - loss: 1.3952 - accuracy: 0.5526
# Epoch 15/175
# 438/438 [==============================] - 5s 11ms/step - loss: 1.3844 - accuracy: 0.5587
# Epoch 16/175
# 438/438 [==============================] - 6s 14ms/step - loss: 1.3515 - accuracy: 0.5659
# Epoch 17/175
# 438/438 [==============================] - 5s 11ms/step - loss: 1.3043 - accuracy: 0.5864
# Epoch 18/175
# 438/438 [==============================] - 5s 11ms/step - loss: 1.2676 - accuracy: 0.6002
# Epoch 19/175
# 438/438 [==============================] - 6s 14ms/step - loss: 1.2350 - accuracy: 0.6072
# Epoch 20/175
# 438/438 [==============================] - 5s 11ms/step - loss: 1.2195 - accuracy: 0.6085
175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.8015 - accuracy: 0.7486
# Epoch 64/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.8031 - accuracy: 0.7473
# Epoch 65/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7987 - accuracy: 0.7435
# Epoch 66/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.7976 - accuracy: 0.7470
# Epoch 67/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.7942 - accuracy: 0.7502
# Epoch 68/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7907 - accuracy: 0.7465
# Epoch 69/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.7929 - accuracy: 0.7515
# Epoch 70/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.7809 - accuracy: 0.7530
# Epoch 71/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7632 - accuracy: 0.7586
# Epoch 72/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.7834 - accuracy: 0.7548
# Epoch 73/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.7713 - accuracy: 0.7553
# Epoch 74/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7698 - accuracy: 0.7593
# Epoch 75/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.7694 - accuracy: 0.7558
# Epoch 76/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.7432 - accuracy: 0.7586
# Epoch 77/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7520 - accuracy: 0.7683
# Epoch 78/175
# 438/438 [==============================] - 5s 13ms/step - loss: 0.7626 - accuracy: 0.7582
# Epoch 79/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.7403 - accuracy: 0.7651
# Epoch 80/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.7553 - accuracy: 0.7610
# Epoch 81/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.7288 - accuracy: 0.7695
# Epoch 82/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.7376 - accuracy: 0.7688
# Epoch 83/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7459 - accuracy: 0.7616
# Epoch 84/175
# 438/438 [==============================] - 6s 14ms/step - loss: 0.7242 - accuracy: 0.7681
# Epoch 85/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7340 - accuracy: 0.7648
# Epoch 86/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7287 - accuracy: 0.7685
# Epoch 87/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.7283 - accuracy: 0.7686
# Epoch 88/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7200 - accuracy: 0.7739
# Epoch 89/175
# 438/438 [==============================] - 5s 10ms/step - loss: 0.7175 - accuracy: 0.7791
# Epoch 90/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.7239 - accuracy: 0.7699
# Epoch 91/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7192 - accuracy: 0.7742
# Epoch 92/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7010 - accuracy: 0.7718
# Epoch 93/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6991 - accuracy: 0.7802
# Epoch 94/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7006 - accuracy: 0.7775
# Epoch 95/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6875 - accuracy: 0.7816
# Epoch 96/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6886 - accuracy: 0.7844
# Epoch 97/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6966 - accuracy: 0.7836
# Epoch 98/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.7036 - accuracy: 0.7735
# Epoch 99/175
# 438/438 [==============================] - 6s 14ms/step - loss: 0.6942 - accuracy: 0.7771
# Epoch 100/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6762 - accuracy: 0.7904
# Epoch 101/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6769 - accuracy: 0.7842
# Epoch 102/175
# 438/438 [==============================] - 6s 14ms/step - loss: 0.6810 - accuracy: 0.7819
# Epoch 103/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6870 - accuracy: 0.7835
# Epoch 104/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6783 - accuracy: 0.7868
# Epoch 105/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6670 - accuracy: 0.7851
# Epoch 106/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6756 - accuracy: 0.7869
# Epoch 107/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6705 - accuracy: 0.7882
# Epoch 108/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6774 - accuracy: 0.7872
# Epoch 109/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6719 - accuracy: 0.7908
# Epoch 110/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6555 - accuracy: 0.7924
# Epoch 111/175
# 438/438 [==============================] - 6s 14ms/step - loss: 0.6674 - accuracy: 0.7875
# Epoch 112/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6659 - accuracy: 0.7931
# Epoch 113/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6593 - accuracy: 0.7868
# Epoch 114/175
# 438/438 [==============================] - 6s 14ms/step - loss: 0.6461 - accuracy: 0.7945
# Epoch 115/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6561 - accuracy: 0.7886
# Epoch 116/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6467 - accuracy: 0.7987
# Epoch 117/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6483 - accuracy: 0.7945
# Epoch 118/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6518 - accuracy: 0.7938
# Epoch 119/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6397 - accuracy: 0.7935
# Epoch 120/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6318 - accuracy: 0.8007
# Epoch 121/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6415 - accuracy: 0.7968
# Epoch 122/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6388 - accuracy: 0.7977
# Epoch 123/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6204 - accuracy: 0.8011
# Epoch 124/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6264 - accuracy: 0.7997
# Epoch 125/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6374 - accuracy: 0.8022
# Epoch 126/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6103 - accuracy: 0.8017
# Epoch 127/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6301 - accuracy: 0.7998
# Epoch 128/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6237 - accuracy: 0.7967
# Epoch 129/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6307 - accuracy: 0.7985
# Epoch 130/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6215 - accuracy: 0.8075
# Epoch 131/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6218 - accuracy: 0.8042
# Epoch 132/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6175 - accuracy: 0.8078
# Epoch 133/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6098 - accuracy: 0.8115
# Epoch 134/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6100 - accuracy: 0.8091
# Epoch 135/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.6209 - accuracy: 0.8012
# Epoch 136/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6116 - accuracy: 0.8017
# Epoch 137/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6070 - accuracy: 0.8059
# Epoch 138/175
# 438/438 [==============================] - 6s 14ms/step - loss: 0.6029 - accuracy: 0.8062
# Epoch 139/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5811 - accuracy: 0.8158
# Epoch 140/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6039 - accuracy: 0.8038
# Epoch 141/175
# 438/438 [==============================] - 6s 14ms/step - loss: 0.5857 - accuracy: 0.8080
# Epoch 142/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.6064 - accuracy: 0.8069
# Epoch 143/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.6027 - accuracy: 0.8077
# Epoch 144/175
# 438/438 [==============================] - 6s 14ms/step - loss: 0.5968 - accuracy: 0.8062
# Epoch 145/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5886 - accuracy: 0.8131
# Epoch 146/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5868 - accuracy: 0.8138
# Epoch 147/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5997 - accuracy: 0.8122
# Epoch 148/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5770 - accuracy: 0.8091
# Epoch 149/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5823 - accuracy: 0.8062
# Epoch 150/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5872 - accuracy: 0.8090
# Epoch 151/175
# 438/438 [==============================] - 6s 14ms/step - loss: 0.5869 - accuracy: 0.8142
# Epoch 152/175
# 438/438 [==============================] - 5s 13ms/step - loss: 0.5648 - accuracy: 0.8194
# Epoch 153/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5855 - accuracy: 0.8091
# Epoch 154/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5711 - accuracy: 0.8135
# Epoch 155/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5602 - accuracy: 0.8190
# Epoch 156/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5851 - accuracy: 0.8081
# Epoch 157/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5676 - accuracy: 0.8220
# Epoch 158/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5726 - accuracy: 0.8214
# Epoch 159/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5744 - accuracy: 0.8162
# Epoch 160/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5827 - accuracy: 0.8110
# Epoch 161/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5782 - accuracy: 0.8181
# Epoch 162/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5687 - accuracy: 0.8172
# Epoch 163/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5641 - accuracy: 0.8217
# Epoch 164/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5574 - accuracy: 0.8225
# Epoch 165/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5662 - accuracy: 0.8137
# Epoch 166/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5479 - accuracy: 0.8227
# Epoch 167/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5488 - accuracy: 0.8211
# Epoch 168/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5718 - accuracy: 0.8140
# Epoch 169/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5733 - accuracy: 0.8205
# Epoch 170/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5441 - accuracy: 0.8210
# Epoch 171/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5578 - accuracy: 0.8244
# Epoch 172/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5488 - accuracy: 0.8274
# Epoch 173/175
# 438/438 [==============================] - 5s 12ms/step - loss: 0.5441 - accuracy: 0.8308
# Epoch 174/175
# 438/438 [==============================] - 6s 13ms/step - loss: 0.5647 - accuracy: 0.8221
# Epoch 175/175
# 438/438 [==============================] - 5s 11ms/step - loss: 0.5418 - accuracy: 0.8283

# %%
model2.save('/content/gdrive/MyDrive/DSLSC/Models_2/Model2_5.h5')

# %% [markdown]
# ### Keras tuner \#3

# %%
#!rm -rf /content/best_hyperparams_3

# %% [markdown]
# Now we use the keras tuner in order to find the best regularizers combination.

# %%
# 64 different combinations
def build_model_3(hp):
  model = Sequential()
  model.add(LSTM(units = 32, input_shape = (seq_len, n_feats), return_sequences = True, 
                 kernel_regularizer = regularizers.l2(hp.Choice('kernel_regularizer_lstm_1', values = [0.0, 0.01])),
                 bias_regularizer = regularizers.l2(hp.Choice('bias_regularizer_lstm_1', values = [0.0, 0.01]))))
  model.add(Dropout(0.2))
  model.add(LSTM(units = 32, return_sequences = False,
                 kernel_regularizer = regularizers.l2(hp.Choice('kernel_regularizer_lstm_2', values = [0.0, 0.01])),
                 bias_regularizer = regularizers.l2(hp.Choice('bias_regularizer_lstm_2', values = [0.0, 0.01]))))
  model.add(Dropout(0.2))
  model.add(Dense(units = 32,
                  kernel_regularizer = regularizers.l2(hp.Choice('kernel_regularizer_dense', values = [0.0, 0.01])),
                  bias_regularizer = regularizers.l2(hp.Choice('bias_regularizer_dense', values = [0.0, 0.01]))))
  model.add(Dropout(0.2))
  model.add(Dense(36, activation = 'softmax'))
  
  optimizer = Adam(learning_rate = 0.001)
  model.compile(optimizer =  optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])
  return model

# %%
tuner_3 = GridSearch(
  build_model_3,
  objective = 'val_loss',
  executions_per_trial = 1,
  directory = '/content',
  project_name = 'best_hyperparams_3'
)

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
# Grid search
tuner_3.search(X_train, y_train, epochs = 200, batch_size = 16, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
# Retrieve best hyperparameters and final model
best_hp = tuner_3.get_best_hyperparameters()[0]
best_model = tuner_3.hypermodel.build(best_hp)

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 5, 32)             4864
#
#  dropout_3 (Dropout)         (None, 5, 32)             0
#
#  lstm_3 (LSTM)               (None, 32)                8320
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 36)                1188
#
# =================================================================
# Total params: 15,428
# Trainable params: 15,428
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# It's the same as model 2.

# %% [markdown]
# ### Model 4

# %% [markdown]
# Now we may try increasing the batch_size to 32.

# %%
model4 = Sequential()
model4.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model4.add(Dropout(0.2))
model4.add(LSTM(32, return_sequences = False))
model4.add(Dropout(0.2))
model4.add(Dense(32))
model4.add(Dropout(0.2))
model4.add(Dense(36, activation = 'softmax'))
model4.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 5, 32)             4864
#
#  dropout_6 (Dropout)         (None, 5, 32)             0
#
#  lstm_5 (LSTM)               (None, 32)                8320
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 36)                1188
#
# =================================================================
# Total params: 15,428
# Trainable params: 15,428
# Non-trainable params: 0
# _________________________________________________________________

# %%
stop_early = EarlyStopping(monitor = 'val_loss', patience = 30, restore_best_weights = True)

# %%
optimizer = Adam(learning_rate = 0.001)
model4.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history4 = model4.fit(X_train, y_train, epochs = 200, batch_size = 32, validation_data = (X_val, y_val), callbacks = [stop_early])

# %%
plt.figure(figsize = (12, 6))

plt.subplot(1, 2, 1)
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training loss', 'validation loss'])

plt.subplot(1, 2, 2)
plt.plot(history4.history['accuracy'])
plt.plot(history4.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['training accuracy', 'validation accuracy'])

# %% [markdown]
# Now retrain on training + validation and save the model.

# %%
model4 = Sequential()
model4.add(LSTM(32, input_shape = (seq_len, n_feats), return_sequences = True))
model4.add(Dropout(0.2))
model4.add(LSTM(32, return_sequences = False))
model4.add(Dropout(0.2))
model4.add(Dense(32))
model4.add(Dropout(0.2))
model4.add(Dense(36, activation = 'softmax'))

# %%
optimizer = Adam(learning_rate = 0.001)
model4.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

history4 = model4.fit(X, y, epochs = 175, batch_size = 32)
# Out:
# Epoch 1/175
# 219/219 [==============================] - 7s 14ms/step - loss: 3.2270 - accuracy: 0.1074
# Epoch 2/175
# 219/219 [==============================] - 3s 13ms/step - loss: 2.3281 - accuracy: 0.2703
# Epoch 3/175
# 219/219 [==============================] - 2s 10ms/step - loss: 2.0137 - accuracy: 0.3534
# Epoch 4/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.8373 - accuracy: 0.4063
# Epoch 5/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.7560 - accuracy: 0.4297
# Epoch 6/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.7011 - accuracy: 0.4553
# Epoch 7/175
# 219/219 [==============================] - 3s 13ms/step - loss: 1.6567 - accuracy: 0.4676
# Epoch 8/175
# 219/219 [==============================] - 3s 13ms/step - loss: 1.6053 - accuracy: 0.4906
# Epoch 9/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.5893 - accuracy: 0.4889
# Epoch 10/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.5496 - accuracy: 0.5109
# Epoch 11/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.5341 - accuracy: 0.5109
# Epoch 12/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.4991 - accuracy: 0.5237
# Epoch 13/175
# 219/219 [==============================] - 3s 11ms/step - loss: 1.4858 - accuracy: 0.5208
# Epoch 14/175
# 219/219 [==============================] - 3s 14ms/step - loss: 1.4726 - accuracy: 0.5364
# Epoch 15/175
# 219/219 [==============================] - 3s 11ms/step - loss: 1.4523 - accuracy: 0.5391
# Epoch 16/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.4362 - accuracy: 0.5397
# Epoch 17/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.4152 - accuracy: 0.5508
# Epoch 18/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.4097 - accuracy: 0.5518
# Epoch 19/175
# 219/219 [==============================] - 2s 9ms/step - loss: 1.3772 - accuracy: 0.5663
# Epoch 20/175
# 219/219 [==============================] - 3s 14ms/step - loss: 1.3661 - accuracy: 0.5684
# Epoch 21/175
# 219/219 [==============================] - 3s 14ms/step - loss: 1.3430 - accuracy: 0.5757
# Epoch 22/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.3182 - accuracy: 0.5876
# Epoch 23/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.3036 - accuracy: 0.5781
# Epoch 24/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.2720 - accuracy: 0.6003
# Epoch 25/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.2486 - accuracy: 0.6046
# Epoch 26/175
# 219/219 [==============================] - 3s 12ms/step - loss: 1.2174 - accuracy: 0.6122
# Epoch 27/175
# 219/219 [==============================] - 3s 14ms/step - loss: 1.2009 - accuracy: 0.6199
# Epoch 28/175
# 219/219 [==============================] - 2s 11ms/step - loss: 1.1916 - accuracy: 0.6170
# Epoch 29/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.1749 - accuracy: 0.6298
# Epoch 30/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.1601 - accuracy: 0.6313
# Epoch 31/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.1613 - accuracy: 0.6381
# Epoch 32/175
# 219/219 [==============================] - 2s 11ms/step - loss: 1.1389 - accuracy: 0.6422
# Epoch 33/175
# 219/219 [==============================] - 3s 14ms/step - loss: 1.1277 - accuracy: 0.6441
# Epoch 34/175
# 219/219 [==============================] - 3s 16ms/step - loss: 1.1218 - accuracy: 0.6496
# Epoch 35/175
# 219/219 [==============================] - 3s 14ms/step - loss: 1.1009 - accuracy: 0.6492
# Epoch 36/175
# 219/219 [==============================] - 2s 11ms/step - loss: 1.0849 - accuracy: 0.6572
# Epoch 37/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.0844 - accuracy: 0.6552
# Epoch 38/175
# 219/219 [==============================] - 2s 11ms/step - loss: 1.0668 - accuracy: 0.6605
# Epoch 39/175
# 219/219 [==============================] - 3s 14ms/step - loss: 1.0680 - accuracy: 0.6558
# Epoch 40/175
# 219/219 [==============================] - 3s 12ms/step - loss: 1.0699 - accuracy: 0.6647
# Epoch 41/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.0549 - accuracy: 0.6690
# Epoch 42/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.0464 - accuracy: 0.6681
# Epoch 43/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.0420 - accuracy: 0.6700
# Epoch 44/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.0220 - accuracy: 0.6761
# Epoch 45/175
# 219/219 [==============================] - 3s 14ms/step - loss: 1.0283 - accuracy: 0.6747
# Epoch 46/175
# 219/219 [==============================] - 3s 14ms/step - loss: 1.0058 - accuracy: 0.6858
# Epoch 47/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.0176 - accuracy: 0.6785
# Epoch 48/175
# 219/219 [==============================] - 2s 10ms/step - loss: 1.0011 - accuracy: 0.6863
# Epoch 49/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.9922 - accuracy: 0.6827
# Epoch 50/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.9842 - accuracy: 0.6911
# Epoch 51/175
# 219/219 [==============================] - 3s 13ms/step - loss: 0.9809 - accuracy: 0.6885
# Epoch 52/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.9678 - accuracy: 0.6888
# Epoch 53/175
# 219/219 [==============================] - 2s 11ms/step - loss: 0.9531 - accuracy: 0.6943
# Epoch 54/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.9501 - accuracy: 0.6967
# Epoch 55/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.9536 - accuracy: 0.6997
# Epoch 56/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.9352 - accuracy: 0.6983
# Epoch 57/175
# 219/219 [==============================] - 3s 12ms/step - loss: 0.9334 - accuracy: 0.6933
# Epoch 58/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.9292 - accuracy: 0.7061
# Epoch 59/175
# 219/219 [==============================] - 3s 12ms/step - loss: 0.9268 - accuracy: 0.7091
# Epoch 60/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.9303 - accuracy: 0.7087
# Epoch 61/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.9164 - accuracy: 0.7079
# Epoch 62/175
# 219/219 [==============================] - 2s 11ms/step - loss: 0.8935 - accuracy: 0.7094
# Epoch 63/175
# 219/219 [==============================] - 2s 11ms/step - loss: 0.9056 - accuracy: 0.7093
# Epoch 64/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.8908 - accuracy: 0.7119
# Epoch 65/175
# 219/219 [==============================] - 3s 12ms/step - loss: 0.8979 - accuracy: 0.7161
# Epoch 66/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8934 - accuracy: 0.7183
# Epoch 67/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8779 - accuracy: 0.7206
# Epoch 68/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8869 - accuracy: 0.7166
# Epoch 69/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8670 - accuracy: 0.7283
# Epoch 70/175
# 219/219 [==============================] - 3s 13ms/step - loss: 0.8681 - accuracy: 0.7222
# Epoch 71/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.8673 - accuracy: 0.7257
# Epoch 72/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8518 - accuracy: 0.7260
# Epoch 73/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8544 - accuracy: 0.7312
# Epoch 74/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8507 - accuracy: 0.7277
# Epoch 75/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8580 - accuracy: 0.7273
# Epoch 76/175
# 219/219 [==============================] - 3s 12ms/step - loss: 0.8509 - accuracy: 0.7297
# Epoch 77/175
# 219/219 [==============================] - 3s 15ms/step - loss: 0.8444 - accuracy: 0.7322
# Epoch 78/175
# 219/219 [==============================] - 3s 12ms/step - loss: 0.8307 - accuracy: 0.7309
# Epoch 79/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8246 - accuracy: 0.7354
# Epoch 80/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8272 - accuracy: 0.7406
# Epoch 81/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8331 - accuracy: 0.7330
# Epoch 82/175
# 219/219 [==============================] - 2s 11ms/step - loss: 0.8226 - accuracy: 0.7405
# Epoch 83/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.8295 - accuracy: 0.7340
# Epoch 84/175
# 219/219 [==============================] - 3s 13ms/step - loss: 0.8130 - accuracy: 0.7440
# Epoch 85/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8069 - accuracy: 0.7502
# Epoch 86/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8017 - accuracy: 0.7450
# Epoch 87/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7957 - accuracy: 0.7456
# Epoch 88/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.8070 - accuracy: 0.7406
# Epoch 89/175
# 219/219 [==============================] - 3s 13ms/step - loss: 0.7979 - accuracy: 0.7490
# Epoch 90/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.7861 - accuracy: 0.7469
# Epoch 91/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7915 - accuracy: 0.7450
# Epoch 92/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7999 - accuracy: 0.7455
# Epoch 93/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7727 - accuracy: 0.7532
# Epoch 94/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7862 - accuracy: 0.7522
# Epoch 95/175
# 219/219 [==============================] - 2s 11ms/step - loss: 0.7611 - accuracy: 0.7593
# Epoch 96/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.7764 - accuracy: 0.7497
# Epoch 97/175
# 219/219 [==============================] - 3s 12ms/step - loss: 0.7588 - accuracy: 0.7608
# Epoch 98/175
# 219/219 [==============================] - 3s 13ms/step - loss: 0.7699 - accuracy: 0.7529
# Epoch 99/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.7738 - accuracy: 0.7589
# Epoch 100/175
# 219/219 [==============================] - 2s 11ms/step - loss: 0.7580 - accuracy: 0.7620
# Epoch 101/175
# 219/219 [==============================] - 3s 13ms/step - loss: 0.7543 - accuracy: 0.7533
# Epoch 102/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.7567 - accuracy: 0.7600
# Epoch 103/175
# 219/219 [==============================] - 2s 11ms/step - loss: 0.7691 - accuracy: 0.7492
# Epoch 104/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7490 - accuracy: 0.7632
# Epoch 105/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7599 - accuracy: 0.7585
# Epoch 106/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7490 - accuracy: 0.7645
# Epoch 107/175
# 219/219 [==============================] - 3s 12ms/step - loss: 0.7435 - accuracy: 0.7661
# Epoch 108/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.7457 - accuracy: 0.7622
# Epoch 109/175
# 219/219 [==============================] - 3s 12ms/step - loss: 0.7445 - accuracy: 0.7610
# Epoch 110/175
# 219/219 [==============================] - 2s 11ms/step - loss: 0.7252 - accuracy: 0.7723
# Epoch 111/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7434 - accuracy: 0.7638
# Epoch 112/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7385 - accuracy: 0.7632
# Epoch 113/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7424 - accuracy: 0.7605
# Epoch 114/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.7345 - accuracy: 0.7739
# Epoch 115/175
# 219/219 [==============================] - 3s 13ms/step - loss: 0.7205 - accuracy: 0.7669
# Epoch 116/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7406 - accuracy: 0.7643
# Epoch 117/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7146 - accuracy: 0.7746
# Epoch 118/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.7060 - accuracy: 0.7722
# Epoch 119/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0
175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.6231 - accuracy: 0.7924
# Epoch 168/175
# 219/219 [==============================] - 2s 11ms/step - loss: 0.6327 - accuracy: 0.7959
# Epoch 169/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.6219 - accuracy: 0.8002
# Epoch 170/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.6358 - accuracy: 0.7922
# Epoch 171/175
# 219/219 [==============================] - 3s 14ms/step - loss: 0.6147 - accuracy: 0.8031
# Epoch 172/175
# 219/219 [==============================] - 2s 11ms/step - loss: 0.6160 - accuracy: 0.8034
# Epoch 173/175
# 219/219 [==============================] - 2s 11ms/step - loss: 0.6426 - accuracy: 0.7931
# Epoch 174/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.6123 - accuracy: 0.8031
# Epoch 175/175
# 219/219 [==============================] - 2s 10ms/step - loss: 0.6071 - accuracy: 0.8025

# %%
model4.save('/content/gdrive/MyDrive/DSLSC/Models_2/Model4_5.h5')

# %% [markdown]
# ## Testing

# %% [markdown]
# Finally, we load our models in order to evaluate them on the test-set.

# %% [markdown]
# ### Model 0

# %%
model0 = load_model('/content/gdrive/MyDrive/DSLSC/Models_2/Model0_5.h5')

# %%
y_pred = model0.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 35/35 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81        28
#            1       0.54      0.68      0.60        56
#            2       0.74      0.80      0.77        87
#            3       0.40      0.62      0.49        53
#            4       0.76      0.52      0.62        25
#            5       0.88      0.72      0.79        29
#            6       0.57      0.76      0.65       117
#            7       0.00      0.00      0.00         3
#            8       0.00      0.00      0.00         6
#            9       0.75      0.07      0.12        44
#           10       0.66      0.94      0.77        47
#           11       0.50      0.39      0.44        18
#           12       1.00      0.50      0.67         4
#           13       0.26      0.15      0.19        34
#           14       0.30      0.26      0.28        23
#           15       0.68      0.68      0.68        31
#           16       0.71      0.77      0.74        31
#           17       0.46      0.38      0.42        29
#           18       0.55      0.58      0.56        19
#           19       0.27      0.50      0.35        22
#           20       0.00      0.00      0.00         5
#           21       0.32      0.50      0.39        26
#           22       0.54      0.57      0.56        35
#           23       0.95      0.57      0.71        35
#           24       0.42      0.50      0.46        34
#           25       0.95      0.72      0.82        29
#           26       0.78      0.70      0.74        10
#           27       1.00      0.20      0.33         5
#           28       0.39      0.50      0.44        36
#           29       0.26      0.25      0.25        28
#           30       0.00      0.00      0.00        13
#           31       0.88      0.71      0.79        31
#           32       0.43      0.34      0.38        35
#           33       0.00      0.00      0.00        15
#           34       0.50      0.66      0.57        41
#           35       0.53      0.47      0.50        34
#
#     accuracy                           0.56      1118
#    macro avg       0.53      0.46      0.47      1118
# weighted avg       0.57      0.56      0.54      1118
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.7432915921288015
# 0.8389982110912343

# %% [markdown]
# ### Model 1

# %%
model1 = load_model('/content/gdrive/MyDrive/DSLSC/Models_2/Model1_5.h5')

# %%
y_pred = model1.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 35/35 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        28
#            1       0.64      0.64      0.64        56
#            2       0.71      0.86      0.78        87
#            3       0.71      0.55      0.62        53
#            4       0.89      0.64      0.74        25
#            5       1.00      0.76      0.86        29
#            6       0.75      0.70      0.72       117
#            7       0.00      0.00      0.00         3
#            8       0.27      0.50      0.35         6
#            9       0.84      0.86      0.85        44
#           10       0.90      0.91      0.91        47
#           11       0.48      0.61      0.54        18
#           12       0.67      0.50      0.57         4
#           13       0.52      0.32      0.40        34
#           14       0.50      0.48      0.49        23
#           15       0.69      0.94      0.79        31
#           16       0.92      0.77      0.84        31
#           17       0.59      0.59      0.59        29
#           18       0.53      0.53      0.53        19
#           19       0.57      0.59      0.58        22
#           20       0.75      0.60      0.67         5
#           21       0.41      0.54      0.47        26
#           22       0.63      0.89      0.74        35
#           23       0.91      0.86      0.88        35
#           24       0.68      0.56      0.61        34
#           25       0.90      0.90      0.90        29
#           26       0.70      0.70      0.70        10
#           27       0.00      0.00      0.00         5
#           28       0.53      0.56      0.54        36
#           29       0.54      0.68      0.60        28
#           30       0.55      0.46      0.50        13
#           31       0.55      0.84      0.67        31
#           32       0.49      0.54      0.51        35
#           33       0.00      0.00      0.00        15
#           34       0.59      0.46      0.52        41
#           35       0.55      0.53      0.54        34
#
#     accuracy                           0.67      1118
#    macro avg       0.60      0.60      0.60      1118
# weighted avg       0.67      0.67      0.67      1118

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.813953488372093
# 0.8765652951699463

# %% [markdown]
# ### Model 2

# %%
model2 = load_model('/content/gdrive/MyDrive/DSLSC/Models_2/Model2_5.h5')

# %%
y_pred = model2.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 35/35 [==============================] - 1s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.67      0.93      0.78        28
#            1       0.83      0.70      0.76        56
#            2       0.83      0.90      0.86        87
#            3       0.83      0.85      0.84        53
#            4       0.85      0.88      0.86        25
#            5       0.97      1.00      0.98        29
#            6       0.80      0.87      0.83       117
#            7       0.00      0.00      0.00         3
#            8       0.67      0.33      0.44         6
#            9       0.87      0.91      0.89        44
#           10       0.82      0.96      0.88        47
#           11       0.80      0.67      0.73        18
#           12       1.00      0.50      0.67         4
#           13       0.73      0.65      0.69        34
#           14       0.86      0.52      0.65        23
#           15       0.96      0.87      0.92        31
#           16       0.94      0.94      0.94        31
#           17       0.63      0.66      0.64        29
#           18       0.54      0.68      0.60        19
#           19       0.65      0.59      0.62        22
#           20       0.60      0.60      0.60         5
#           21       0.58      0.69      0.63        26
#           22       0.61      0.89      0.72        35
#           23       0.94      0.86      0.90        35
#           24       0.77      0.50      0.61        34
#           25       0.93      0.93      0.93        29
#           26       0.86      0.60      0.71        10
#           27       0.00      0.00      0.00         5
#           28       0.59      0.61      0.60        36
#           29       0.52      0.57      0.54        28
#           30       0.50      0.62      0.55        13
#           31       0.88      0.90      0.89        31
#           32       0.69      0.71      0.70        35
#           33       0.00      0.00      0.00        15
#           34       0.75      0.73      0.74        41
#           35       0.88      0.68      0.77        34
#
#     accuracy                           0.77      1118
#    macro avg       0.70      0.67      0.68      1118
# weighted avg       0.77      0.77      0.76      1118

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.8738819320214669
# 0.9105545617173524

# %% [markdown]
# ### Model 4

# %%
model4 = load_model('/content/gdrive/MyDrive/DSLSC/Models_2/Model4_5.h5')

# %%
y_pred = model4.predict(X_test)
y_pred_ = np.argmax(y_pred, axis = 1)
y_test_ = np.argmax(y_test, axis = 1)
print(classification_report(y_test_, y_pred_))
# Out:
# 35/35 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91        28
#            1       0.76      0.73      0.75        56
#            2       0.82      0.86      0.84        87
#            3       0.82      0.77      0.80        53
#            4       0.76      0.76      0.76        25
#            5       1.00      1.00      1.00        29
#            6       0.80      0.87      0.84       117
#            7       0.00      0.00      0.00         3
#            8       0.50      0.67      0.57         6
#            9       0.95      0.91      0.93        44
#           10       0.79      0.94      0.85        47
#           11       0.77      0.56      0.65        18
#           12       0.67      0.50      0.57         4
#           13       0.73      0.56      0.63        34
#           14       0.65      0.65      0.65        23
#           15       0.88      0.90      0.89        31
#           16       0.90      0.90      0.90        31
#           17       0.56      0.79      0.66        29
#           18       0.59      0.68      0.63        19
#           19       0.71      0.68      0.70        22
#           20       0.50      0.20      0.29         5
#           21       0.53      0.69      0.60        26
#           22       0.70      0.89      0.78        35
#           23       1.00      0.80      0.89        35
#           24       0.81      0.38      0.52        34
#           25       0.97      1.00      0.98        29
#           26       1.00      0.70      0.82        10
#           27       0.00      0.00      0.00         5
#           28       0.59      0.64      0.61        36
#           29       0.42      0.39      0.41        28
#           30       0.89      0.62      0.73        13
#           31       0.91      0.94      0.92        31
#           32       0.67      0.63      0.65        35
#           33       0.64      0.60      0.62        15
#           34       0.67      0.78      0.72        41
#           35       0.71      0.74      0.72        34
#
#     accuracy                           0.77      1118
#    macro avg       0.71      0.68      0.69      1118
# weighted avg       0.77      0.77      0.76      1118
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test_, y_pred_)
plt.imshow(cm, cmap = plt.cm.Blues)
plt.xlabel('Ground truth')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(top_k_accuracy_score(y_test_, y_pred, k = 2))
print(top_k_accuracy_score(y_test_, y_pred, k = 3))
# Out:
# 0.8676207513416816
# 0.9087656529516994
